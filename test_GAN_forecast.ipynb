# %%
# Demo script to load and plot cGAN forecast data.

from datetime import datetime

# These are the functions that you can use:
from show_forecasts.show_cGAN import load_GAN_forecast, plot_GAN_forecast, plot_GAN_ensemble
from show_forecasts.show_cGAN import plot_GAN_threshold_chance, plot_GAN_local_histograms
from show_forecasts.data_utils import print_locations

# %%
# Where the forecasts are downloaded to
#data_dir = '/home/c/cooperf/IFS/ICPAC_data/operational/GAN_forecasts'
data_dir = '/Users/cooperf/Documents/WFP/data/ICPAC_operational/Jurre_brishti/forecasts'

# The date that the forecast was initialised
forecast_init_date = datetime(year=2024, month=5, day=21)
# Pick today instead:
#forecast_init_date = datetime.now()

# %%
# Load the GAN forecast
data = load_GAN_forecast(forecast_init_date, data_dir)

# %%
# Plot the GAN forecast
plot_GAN_forecast(data)

# %%
# Plot just one time: Options are 6, 12, 18, 0 or 'all'.
# style options: None (default), 'ICPAC', 'ICPAC_heavy', 'KMD', 'EMI', 'EMI_heavy'
# plot_units can be 'mm/h' (default), 'mm/6h', 'mm/day' or 'mm/week'
# region can be 'ICPAC', 'Kenya', 'South Sudan', 'Rwanda', 'Burundi', 'Djibouti',
#               'Eritrea', 'Ethiopia', 'Sudan', 'Somalia', 'Tanzania', 'Uganda'
# A file name can be specified using file_name="my_file.pdf". File types can be
#               png, jpg or pdf.
plot_GAN_forecast(data, valid_time_start_hour=12, style='KMD', plot_units='mm/6h', region='Kenya')

# %%
# Plot the rainfall over 24 hours
plot_GAN_forecast(data, accumulation_time='24h', style='KMD',
                  plot_units='mm/day', region='Kenya')

# %%
# Plot the full ensemble
#   valid_time_start_hour=6 - The hour the valid time starts at. Can either be 6, 12, 18 or 0 UTC.
plot_GAN_ensemble(data, valid_time_start_hour=18, style='KMD', plot_units='mm/6h', region='Kenya')

# %%
# Plot the chance of rainfall at a rate above a specified threshold.
#   threshold=2             - We'll plot the chance of rainfall above this threshold rate. The
#                             default is 2 mm/h. The units of threshold is set by plot_units.
#   plot_units='mm/h'       - Can be 'mm/h' (default), 'mm/6h', 'mm/day' or 'mm/week'
#   valid_time_start_hour=6 - The hour the valid time starts at. Can either be 6, 12, 18 or 0 UTC or 'all'.
plot_GAN_threshold_chance(data, threshold=5, plot_units='mm/6h', valid_time_start_hour='all',
                          show_percentages=False, region='Kenya')

# %%
plot_GAN_threshold_chance(data, threshold=2, plot_units='mm/6h', valid_time_start_hour='0',
                          show_percentages=False, region='Kenya')

# %%
# Prints the named locations available for making histograms
# All locations are listed in the file show_forecasts/shapes/locations.py
#   Optionally restrict the country to one of 'Kenya', 'South Sudan', 'Rwanda',
#   'Burundi', 'Djibouti', 'Eritrea', 'Ethiopia', 'Sudan', 'Somalia',
#   'Tanzania', 'Uganda'
print_locations('Kenya')
# Out:
# Abarati, Kenya, (-0.56313N, 39.71151E)
# Achivwa, Kenya, (-3.76667N, 39.15E)
# Ada, Kenya, (-4.20155N, 39.0952E)
# Ahero, Kenya, (-0.17462N, 34.9163E)
# Ainamoi, Kenya, (-0.29414N, 35.27377E)
# Air Base, Kenya, (-1.27009N, 36.86034E)
# Aisere, Kenya, (0.22546N, 34.68413E)
# Aitong, Kenya, (-1.18333N, 35.25E)
# Ajao, Kenya, (2.96219N, 39.68869E)
# Akala, Kenya, (-0.05979N, 34.42651E)
# Akelo's Village, Kenya, (-0.63333N, 34.58333E)
# Alalei, Kenya, (2.25037N, 35.02912E)
# Alinjur, Kenya, (-0.03113N, 40.4563E)
# Amagoro, Kenya, (0.63042N, 34.32081E)
# Amakura, Kenya, (0.56842N, 34.27365E)
# Ambira, Kenya, (0.17677N, 34.27619E)
# Amboseli Safari Camp, Kenya, (-2.66839N, 37.2738E)
# Anasa, Kenya, (-2.51607N, 40.30724E)
# Andiwo's Village, Kenya, (-0.51667N, 34.7E)
# Aneko, Kenya, (-0.92777N, 34.14222E)
# Angama Mara, Kenya, (-1.27379N, 34.97013E)
# Angata Naado, Kenya, (-1.2505N, 35.99257E)
# Anglogitat, Kenya, (1.95913N, 35.39335E)
# Angorangora, Kenya, (2.63469N, 35.40046E)
# Anio, Kenya, (3.33194N, 39.79139E)
# Ankish, Kenya, (-1.95189N, 40.85304E)
# Anyieka, Kenya, (0.23333N, 34.26667E)
# Arabia, Kenya, (3.52541N, 41.49908E)
# Arabuko, Kenya, (-3.256N, 39.97445E)
# Archers Post, Kenya, (0.64397N, 37.67519E)
# Arda Dadaja, Kenya, (2.90873N, 41.05517E)
# Arithi, Kenya, (-2.51269N, 40.32172E)
# Arosen, Kenya, (-1.95N, 40.71667E)
# Arwos, Kenya, (0.20522N, 35.22778E)
# Asawo, Kenya, (-0.32866N, 35.00756E)
# Asembo, Kenya, (-0.18332N, 34.38605E)
# Ashuwei, Kenya, (-1.94151N, 41.32196E)
# Assa, Kenya, (-2.05644N, 39.43028E)
# Athi, Kenya, (-2.26667N, 38.06667E)
# Athi River, Kenya, (-1.4563N, 36.97826E)
# Athinai, Kenya, (-0.06667N, 35.98333E)
# Awach, Kenya, (-0.09348N, 34.47948E)
# Awach Tende, Kenya, (-0.48333N, 34.61667E)
# Awasi, Kenya, (-0.16143N, 35.07245E)
# Awendo, Kenya, (-0.5N, 34.4E)
# Awino, Kenya, (-0.53985N, 34.43077E)
# Awundo's Village, Kenya, (-0.63734N, 34.59051E)
# Ayugis, Kenya, (-0.73333N, 34.58333E)
# Baba Dogo, Kenya, (-1.24N, 36.9E)
# Bahakanda, Kenya, (-4.26018N, 39.33914E)
# Bahati, Kenya, (-1.42773N, 40.00316E)
# Bahati Settlement, Kenya, (-0.1435N, 36.17048E)
# Bajumwali, Kenya, (-2.07743N, 41.13398E)
# Bale, Kenya, (-1.22779N, 39.96487E)
# Balesa Bor, Kenya, (2.23204N, 37.91758E)
# Balguda, Kenya, (-1.46865N, 39.82255E)
# Bamba, Kenya, (-3.53782N, 39.52513E)
# Bamburi, Kenya, (-4.0N, 39.71667E)
# Bamburi Beach, Kenya, (-3.98822N, 39.73678E)
# Banane, Kenya, (0.5035N, 38.66202E)
# Bandari, Kenya, (-3.4736N, 39.52993E)
# Bandari la Salama, Kenya, (-3.78048N, 39.70449E)
# Bande, Kenya, (-1.03638N, 34.19742E)
# Banga, Kenya, (-4.09679N, 39.2392E)
# Banissa, Kenya, (3.94102N, 40.34248E)
# Banja, Kenya, (0.03816N, 34.8278E)
# Banya, Kenya, (-3.91667N, 39.63333E)
# Bar Olengo, Kenya, (0.0N, 34.2E)
# Bara Hoyo, Kenya, (-3.93333N, 39.76667E)
# Baragoi, Kenya, (1.78398N, 36.78597E)
# Baragulu, Kenya, (0.0275N, 34.31611E)
# Barani, Kenya, (-3.5832N, 39.83846E)
# Baraton, Kenya, (0.2467N, 35.0778E)
# Barchuma Guda, Kenya, (1.38333N, 38.21667E)
# Bargoni, Kenya, (-2.04785N, 40.78661E)
# Baricho, Kenya, (-3.10298N, 39.78383E)
# Barigito, Kenya, (-0.93333N, 36.86667E)
# Baringo, Kenya, (0.46667N, 35.96667E)
# Barkowino, Kenya, (-0.12523N, 34.26252E)
# Bartabwa, Kenya, (0.83796N, 35.80966E)
# Bartimaro, Kenya, (-2.3N, 36.76667E)
# Bartolimo, Kenya, (0.68328N, 35.81896E)
# Barwesa, Kenya, (0.71667N, 35.73333E)
# Bata, Kenya, (-1.36667N, 41.23333E)
# Batani, Kenya, (-3.89118N, 39.60131E)
# Baure, Kenya, (-1.72297N, 40.96457E)
# Bavigito, Kenya, (-0.93333N, 36.86667E)
# Baymo, Kenya, (-1.92617N, 40.13481E)
# Bazo, Kenya, (-4.66667N, 39.21667E)
# Belewa, Kenya, (-3.95N, 39.63333E)
# Bellevue, Kenya, (-0.23279N, 36.71645E)
# Bengoni, Kenya, (-3.63333N, 39.43333E)
# Bfunbe, Kenya, (-2.19243N, 40.19315E)
# Bibitoli, Kenya, (-2.87706N, 39.88542E)
# Bili, Kenya, (-0.5961N, 39.69709E)
# Bilisa, Kenya, (-2.22199N, 40.12811E)
# Biretwo, Kenya, (0.54453N, 35.5418E)
# Birithia, Kenya, (-0.52391N, 36.94395E)
# Bisadi, Kenya, (-1.7698N, 39.96496E)
# Biyamathow, Kenya, (0.61342N, 40.41001E)
# Bodhei, Kenya, (-1.85991N, 40.71624E)
# Bofu, Kenya, (-3.96667N, 39.43333E)
# Bokoni, Kenya, (-1.37052N, 40.0047E)
# Bole, Kenya, (-0.54895N, 39.69064E)
# Bologonja Springs, Kenya, (-1.633167N, 35.236333E)
# Boma, Kenya, (-0.66927N, 37.33993E)
# Boma Upande, Kenya, (-3.0754N, 40.11291E)
# Bomani, Kenya, (-3.87083N, 39.73467E)
# Bomas of Kenya, Kenya, (-1.33675N, 36.76998E)
# Bomet, Kenya, (-0.78129N, 35.34156E)
# Bondeni, Kenya, (-1.61261N, 40.08295E)
# Bondo, Kenya, (0.23861N, 34.26944E)
# Bongonoko, Kenya, (-0.76667N, 39.8E)
# Bongwe Village, Kenya, (-4.28748N, 39.55314E)
# Bonyunyu, Kenya, (-0.52286N, 34.88453E)
# Bora Imani, Kenya, (-2.2N, 40.86667E)
# Boro, Kenya, (0.08307N, 34.23638E)
# Boyami, Kenya, (-4.29638N, 39.48516E)
# Boyani, Kenya, (-2.99638N, 39.75505E)
# Brackenhurst, Kenya, (-1.099252N, 36.650218E)
# Bubesa, Kenya, (-2.02931N, 40.1586E)
# Bubisa, Kenya, (2.70039N, 38.09496E)
# Bububu, Kenya, (-1.75626N, 40.10049E)
# Buito, Kenya, (-2.41497N, 40.39013E)
# Buji Albati, Kenya, (-2.96181N, 39.81956E)
# Bujwane, Kenya, (0.11667N, 34.03333E)
# Bukangasi, Kenya, (0.08333N, 34.03333E)
# Bukoma, Kenya, (0.06667N, 33.95E)
# Bukotwavi, Kenya, (-2.82094N, 39.99117E)
# Bulbul, Kenya, (-1.3357N, 36.67695E)
# Bulemia, Kenya, (0.11667N, 34.0E)
# Bulla Pesa, Kenya, (0.34284N, 37.56934E)
# Bulungo, Kenya, (0.01667N, 34.1E)
# Buluto Chopi, Kenya, (-2.06959N, 39.57648E)
# Bulwani, Kenya, (0.01N, 34.01245E)
# Bumala, Kenya, (0.3036N, 34.20142E)
# Bumburia, Kenya, (-0.53333N, 34.86667E)
# Bumudondo, Kenya, (0.06667N, 34.03333E)
# Buna, Kenya, (2.78921N, 39.50038E)
# Bunaba, Kenya, (0.06667N, 33.96667E)
# Bungoma, Kenya, (0.5635N, 34.56055E)
# Bungule, Kenya, (-3.84699N, 38.66774E)
# Bunyore, Kenya, (0.08333N, 34.61667E)
# Bur Mayo, Kenya, (2.98333N, 40.26667E)
# Bura, Kenya, (-3.49974N, 38.32177E)
# Burani, Kenya, (-4.24646N, 39.34962E)
# Burgich, Kenya, (1.96667N, 35.08333E)
# Burji, Kenya, (3.51667N, 39.06667E)
# Burnt Forest, Kenya, (0.21539N, 35.43163E)
# Busa, Kenya, (-4.1329N, 39.07051E)
# Busho, Kenya, (-3.89962N, 39.07214E)
# Busia, Kenya, (0.46005N, 34.11169E)
# Busike, Kenya, (0.02725N, 33.99103E)
# Bute Helu, Kenya, (2.83586N, 39.85094E)
# Butere, Kenya, (0.20636N, 34.49348E)
# Butsotso, Kenya, (0.35385N, 34.69801E)
# Butula, Kenya, (0.34195N, 34.33597E)
# Bwaga Macho, Kenya, (-4.54143N, 39.13865E)
# Bwagamoyo, Kenya, (-3.95N, 39.63333E)
# Chakama, Kenya, (-3.081551N, 39.657897E)
# Chala, Kenya, (-3.30893N, 37.71775E)
# Chamari, Kenya, (-1.52598N, 39.89293E)
# Chamwanamuma, Kenya, (-2.50734N, 40.29542E)
# Chanani, Kenya, (-1.55823N, 40.05352E)
# Changamwe, Kenya, (-4.01659N, 39.62893E)
# Chawia, Kenya, (-3.48093N, 38.35259E)
# Chebara, Kenya, (0.88765N, 35.50631E)
# Cheberen, Kenya, (0.23125N, 35.83402E)
# Chebiemit, Kenya, (0.85269N, 35.5008E)
# Cheboin, Kenya, (0.29394N, 35.53179E)
# Cheburua, Kenya, (2.03221N, 35.20995E)
# Chegeini, Kenya, (-1.05N, 36.91667E)
# Chegilet, Kenya, (0.82807N, 35.60102E)
# Chehe, Kenya, (-0.41423N, 37.19391E)
# Chelebei, Kenya, (0.82007N, 34.56849E)
# Chelelemuk, Kenya, (0.69167N, 34.35917E)
# Chemaner, Kenya, (-0.80375N, 35.48598E)
# Chemasiri, Kenya, (0.73583N, 34.39361E)
# Chematu, Kenya, (-1.58333N, 38.36667E)
# Chemogoch, Kenya, (0.0204N, 35.93957E)
# Chemoigut, Kenya, (0.67995N, 36.2163E)
# Chemosit, Kenya, (-0.49004N, 35.16685E)
# Chemususu, Kenya, (0.10522N, 35.61608E)
# Chemuswo, Kenya, (0.34291N, 35.11877E)
# Chengo, Kenya, (-3.85N, 39.7E)
# Chepareria, Kenya, (1.30774N, 35.2039E)
# Chepkesin, Kenya, (0.89315N, 35.88372E)
# Chepkono, Kenya, (1.25112N, 35.23921E)
# Chepkorio, Kenya, (0.37894N, 35.54074E)
# Chepkum, Kenya, (0.98043N, 35.61289E)
# Chepropro, Kenya, (2.04733N, 35.34418E)
# Cheptiret, Kenya, (0.33626N, 35.3634E)
# Cheptongei, Kenya, (0.94247N, 35.51419E)
# Chepunyal, Kenya, (1.5N, 35.16667E)
# Cheronge, Kenya, (-0.45N, 36.96667E)
# Chesikaki, Kenya, (0.8012N, 34.50672E)
# Chesogon, Kenya, (1.30511N, 35.62896E)
# Chesoi, Kenya, (1.06564N, 35.5911E)
# Chewani, Kenya, (-1.43609N, 40.02167E)
# Chewele, Kenya, (-1.17417N, 39.96688E)
# Chiananda, Kenya, (-0.41667N, 37.63333E)
# Chiba, Kenya, (-0.68435N, 37.33993E)
# Chieko, Kenya, (-1.15N, 36.63333E)
# Chiffiri, Kenya, (-1.29405N, 39.70801E)
# Chiga, Kenya, (-0.09836N, 34.84396E)
# Chingwede, Kenya, (-4.49573N, 39.4395E)
# Chiokarige, Kenya, (-0.2758N, 37.92342E)
# Chiromo, Kenya, (-1.279443N, 36.811162E)
# Chirte Hiyesa, Kenya, (-2.11667N, 39.65E)
# Chirufa, Kenya, (-2.05471N, 39.46073E)
# Choba, Kenya, (2.42609N, 38.04091E)
# Choke, Kenya, (-3.35844N, 38.38809E)
# Cholechole, Kenya, (-2.3965N, 40.44581E)
# Chomboni, Kenya, (-1.98333N, 37.41667E)
# Chomo, Kenya, (-0.88518N, 36.86544E)
# Chonye, Kenya, (-3.78059N, 39.67906E)
# Choroget, Kenya, (0.39782N, 35.57983E)
# Chui, Kenya, (-0.6629N, 37.01214E)
# Chuini, Kenya, (-4.61801N, 39.16991E)
# Chuka, Kenya, (-0.33316N, 37.64588E)
# Chukia, Kenya, (-3.49194N, 38.60137E)
# Chulaimbo, Kenya, (-0.03871N, 34.63363E)
# Chundwa, Kenya, (-2.07851N, 41.11458E)
# Chura, Kenya, (-1.21712N, 36.68971E)
# Chyulu Hills, Kenya, (-2.66757N, 37.87949E)
# Coast General Hospital, Kenya, (-4.045097N, 39.663391E)
# Cokereria, Kenya, (-0.42756N, 36.34358E)
# Copra, Kenya, (-4.43921N, 39.48852E)
# Corner Ya Daudi, Kenya, (-2.29068N, 40.26414E)
# Daba, Kenya, (-1.57301N, 39.48081E)
# Dabel, Kenya, (3.08889N, 39.27417E)
# Dabida, Kenya, (-3.41542N, 38.29232E)
# Dad Dogh, Kenya, (0.75801N, 40.77981E)
# Dadaab, Kenya, (0.08171N, 40.313987E)
# Dadaj-Bula, Kenya, (0.53671N, 40.87706E)
# Dadechadera, Kenya, (-2.08293N, 39.45534E)
# Dagamra, Kenya, (-3.18376N, 39.93839E)
# Dagoretti, Kenya, (-1.3N, 36.76667E)
# Dakacha, Kenya, (-3.0092N, 39.80339E)
# Dakawachu, Kenya, (-2.68112N, 39.62428E)
# Dalu, Kenya, (-2.37318N, 40.1478E)
# Damasa, Kenya, (3.15972N, 41.32564E)
# Dambale, Kenya, (-3.7N, 39.26667E)
# Dandora, Kenya, (-1.25743N, 36.90357E)
# Dandora Phase 4, Kenya, (-1.24275N, 36.90001E)
# Dandu, Kenya, (3.42297N, 39.8799E)
# Danisa, Kenya, (-2.27893N, 40.13458E)
# Dar es Salaam, Kenya, (-1.65223N, 41.55379E)
# Darajani, Kenya, (-2.58696N, 38.11638E)
# Darasha ya Mawe, Kenya, (-0.43333N, 35.68333E)
# Daruka-Karicho, Kenya, (-2.29065N, 40.22946E)
# Dawsonville, Kenya, (-0.28333N, 36.05E)
# Debani, Kenya, (0.1N, 34.0E)
# Dembwa, Kenya, (-3.4487N, 38.36376E)
# Denge, Kenya, (-4.06667N, 39.15E)
# Desagut, Kenya, (-2.0594N, 39.39417E)
# Dianga, Kenya, (-0.93333N, 34.53333E)
# Diani, Kenya, (-4.27189N, 39.56888E)
# Diani Beach, Kenya, (-4.27774N, 39.59413E)
# Dibe Dungicha, Kenya, (-2.24459N, 39.673E)
# Dida, Kenya, (-3.42598N, 39.80441E)
# Dida Warede, Kenya, (-2.4187N, 40.39944E)
# Dif, Kenya, (0.99515N, 40.96147E)
# Difatha, Kenya, (-0.55N, 37.4E)
# Digira, Kenya, (-1.1N, 40.85E)
# Digo, Kenya, (-4.23333N, 39.18333E)
# Dilmanyaley, Kenya, (0.89019N, 39.561E)
# Dindiri, Kenya, (-3.72748N, 39.80094E)
# Dodori, Kenya, (-1.9N, 41.06667E)
# Dololo, Kenya, (-2.9082N, 39.87578E)
# Don Dol, Kenya, (0.39608N, 37.16299E)
# Doonholm, Kenya, (-1.28333N, 36.86667E)
# Dudi, Kenya, (-0.8N, 34.58333E)
# Dueadera, Kenya, (-1.11667N, 40.1E)
# Dukana, Kenya, (3.99762N, 37.27232E)
# Duldul, Kenya, (-1.91667N, 40.73333E)
# Dulukiza, Kenya, (-3.3854N, 39.63209E)
# Dumbuie, Kenya, (-4.1137N, 39.35005E)
# Dumi, Kenya, (-2.26164N, 40.13427E)
# Dundani, Kenya, (-4.08284N, 39.19456E)
# Dundori, Kenya, (-0.2519N, 36.23641E)
# Dungicha, Kenya, (-3.48333N, 39.61667E)
# Duruma, Kenya, (-4.55N, 39.08333E)
# Duwayo, Kenya, (-1.69972N, 40.08213E)
# Dwa, Kenya, (-2.4N, 38.01667E)
# Dzirive, Kenya, (-4.59306N, 39.16659E)
# Dzitsuhe, Kenya, (-2.87187N, 39.97236E)
# East Kakangutu, Kenya, (-0.43993N, 34.95557E)
# Eastleigh, Kenya, (-1.26667N, 36.85E)
# Eburemia, Kenya, (0.11667N, 34.05E)
# Ebusonga, Kenya, (0.10868N, 34.10401E)
# Ege, Kenya, (-2.24124N, 40.10684E)
# Egerton, Kenya, (-0.36667N, 35.93004E)
# Ekarakara, Kenya, (-0.9703N, 37.47425E)
# Ekaru, Kenya, (-1.2N, 36.7E)
# Ekerenyo, Kenya, (-0.52955N, 34.98983E)
# El Ben, Kenya, (2.31667N, 40.2E)
# El Dera, Kenya, (0.59645N, 38.83929E)
# El Jera, Kenya, (-1.66667N, 39.6E)
# El Wak, Kenya, (2.80922N, 40.92885E)
# Elaa, Kenya, (-1.16667N, 40.78333E)
# Elangata Wuas, Kenya, (-1.89098N, 36.58825E)
# Elburgon, Kenya, (-0.30392N, 35.81144E)
# Eldama Ravine, Kenya, (0.05158N, 35.73078E)
# Eldoret, Kenya, (0.52036N, 35.26992E)
# Elisha, Kenya, (-0.91667N, 34.53333E)
# Elmenteita, Kenya, (-0.48697N, 36.1575E)
# Elmolo Village, Kenya, (2.76107N, 36.72218E)
# Emali, Kenya, (-2.08033N, 37.47202E)
# Emasatsi, Kenya, (0.15N, 34.65E)
# Emausi, Kenya, (-1.54168N, 40.04543E)
# Embakasi, Kenya, (-1.3N, 36.91667E)
# Embu, Kenya, (-0.53112N, 37.4506E)
# Emdin, Kenya, (0.2N, 35.25E)
# Emining, Kenya, (0.14208N, 35.88923E)
# Emmaloba, Kenya, (0.02195N, 34.55897E)
# Empakasi, Kenya, (-1.3N, 36.91667E)
# Ena, Kenya, (-0.47328N, 37.55361E)
# Endarasha, Kenya, (-0.28333N, 35.78333E)
# Endebess, Kenya, (1.07959N, 34.85651E)
# Enengipire, Kenya, (-0.68116N, 35.91098E)
# Enguli, Kenya, (-1.93333N, 37.36667E)
# Enkokidongoi, Kenya, (-2.53333N, 36.81667E)
# Enkorika, Kenya, (-1.96686N, 36.92115E)
# Entasekera, Kenya, (-1.852N, 35.84928E)
# Entontol, Kenya, (-0.88417N, 36.0215E)
# Enzai, Kenya, (-1.84093N, 37.31518E)
# Eoret Narasha, Kenya, (-1.09624N, 35.92284E)
# Eotoud, Kenya, (-0.91755N, 35.61217E)
# Esageri, Kenya, (0.01664N, 35.8261E)
# Escarpment, Kenya, (-1.00971N, 36.61869E)
# Eshu, Kenya, (-4.41352N, 39.34707E)
# Etago, Kenya, (-0.89838N, 34.65819E)
# Ewaso Ng'iro, Kenya, (-1.15602N, 35.76004E)
# Ewaso Ngiro, Kenya, (-1.148004N, 35.756033E)
# Fafsula, Kenya, (-1.15N, 40.01667E)
# Famuni, Kenya, (-4.51687N, 39.41445E)
# Fanjua, Kenya, (-1.66066N, 40.12245E)
# Faza, Kenya, (-2.05604N, 41.11184E)
# Figini, Kenya, (-3.37459N, 38.38847E)
# Finno, Kenya, (3.38219N, 41.41588E)
# Fort Hall, Kenya, (-0.71667N, 37.15E)
# Fort Ternan, Kenya, (-0.20014N, 35.34255E)
# Frere Town, Kenya, (-4.02479N, 39.6936E)
# Fundisa, Kenya, (-2.93045N, 40.09305E)
# Fundisa Kibaoni, Kenya, (-2.93995N, 40.13655E)
# Funyula, Kenya, (0.27878N, 34.11869E)
# Funzi, Kenya, (-4.57887N, 39.43791E)
# Furaha, Kenya, (-2.48175N, 40.21023E)
# Gabani, Kenya, (-1.71737N, 40.12126E)
# Gabisi, Kenya, (-1.63164N, 39.92543E)
# Gacharage, Kenya, (-0.7396N, 36.8219E)
# Gacharageini, Kenya, (-0.62522N, 36.86183E)
# Gacharaigu, Kenya, (-0.7N, 37.01667E)
# Gacharu, Kenya, (-0.61004N, 37.22667E)
# Gachatha, Kenya, (-0.49281N, 36.94132E)
# Gachege, Kenya, (-0.90544N, 36.80362E)
# Gachie, Kenya, (-1.21667N, 36.78333E)
# Gachika, Kenya, (-0.97022N, 36.76548E)
# Gachirero, Kenya, (-0.55N, 37.05E)
# Gachocho, Kenya, (-0.78105N, 36.99124E)
# Gachoiri, Kenya, (-0.98752N, 36.72495E)
# Gachoka, Kenya, (-0.61925N, 37.5335E)
# Gachugi, Kenya, (-0.95N, 36.91667E)
# Gachuku, Kenya, (-0.52106N, 37.11699E)
# Gacogu, Kenya, (-0.71667N, 37.41667E)
# Gaichanjiru, Kenya, (-0.89013N, 37.05934E)
# Gaikundo, Kenya, (-0.53333N, 37.0E)
# Gaikuyu, Kenya, (-0.40172N, 37.14562E)
# Gaitega, Kenya, (-0.73333N, 37.13333E)
# Gaithege, Kenya, (-1.0N, 36.9E)
# Gakanga, Kenya, (-0.44143N, 36.83224E)
# Gakarara, Kenya, (-0.89523N, 37.00168E)
# Gakira, Kenya, (-0.68327N, 37.02422E)
# Gakoe, Kenya, (-0.66574N, 37.0781E)
# Gakong, Kenya, (2.02742N, 35.52747E)
# Gakui, Kenya, (-0.88297N, 37.01191E)
# Gakuo, Kenya, (-0.56903N, 37.33144E)
# Gakurwe, Kenya, (-0.43333N, 37.35E)
# Gakuyu, Kenya, (-0.65N, 37.05E)
# Gakwegore, Kenya, (-0.41667N, 37.58333E)
# Galafahi, Kenya, (0.1N, 34.0E)
# Galanema, Kenya, (-3.7248N, 39.7009E)
# Galili, Kenya, (-2.3368N, 40.21522E)
# Galu, Kenya, (-4.34641N, 39.56314E)
# Gamba, Kenya, (-2.36577N, 40.32134E)
# Gambogi, Kenya, (-0.00088N, 34.73961E)
# Ganda, Kenya, (-3.21667N, 40.06894E)
# Gandini, Kenya, (-4.29361N, 39.14785E)
# Ganze, Kenya, (-3.54304N, 39.69275E)
# Ganzoni, Kenya, (-3.91667N, 39.63333E)
# Garabugoya, Kenya, (-2.03515N, 39.41893E)
# Garashi, Kenya, (-3.13318N, 39.89174E)
# Garba, Kenya, (0.38447N, 37.59007E)
# Garba Tula, Kenya, (0.53392N, 38.51878E)
# Garissa, Kenya, (-0.45275N, 39.64601E)
# Garsegaba, Kenya, (-1.57136N, 40.16751E)
# Garsen, Kenya, (-2.26645N, 40.10975E)
# Gas, Kenya, (3.06522N, 36.82755E)
# Gatab, Kenya, (2.6426N, 36.92992E)
# Gatakaini, Kenya, (-0.83333N, 36.78333E)
# Gatamaiyu, Kenya, (-1.0N, 36.73333E)
# Gatanga, Kenya, (-0.93968N, 36.96667E)
# Gatangara, Kenya, (-0.71667N, 36.95E)
# Gatara, Kenya, (-0.73535N, 36.88254E)
# Gatare, Kenya, (-0.73234N, 36.76775E)
# Gategi, Kenya, (-0.75097N, 37.42554E)
# Gatei, Kenya, (-0.97732N, 36.89873E)
# Gateiguru, Kenya, (-0.86837N, 36.88636E)
# Gathage, Kenya, (-1.04303N, 36.88793E)
# Gathagi, Kenya, (-1.05692N, 36.91192E)
# Gathaithi, Kenya, (-0.43333N, 37.2E)
# Gathambi, Kenya, (-0.46667N, 37.2E)
# Gathanga, Kenya, (-1.18333N, 36.8E)
# Gathangwi, Kenya, (-0.96524N, 36.96796E)
# Gathanje, Kenya, (-1.08949N, 36.78155E)
# Gathanji, Kenya, (-1.08259N, 36.76795E)
# Gatharaini, Kenya, (-1.21735N, 36.90122E)
# Gathegia, Kenya, (-1.01667N, 36.8E)
# Gatheri, Kenya, (-0.78697N, 37.0278E)
# Gatheru, Kenya, (-0.7326N, 37.06828E)
# Gathethu, Kenya, (-0.4113N, 37.15426E)
# Gathiga, Kenya, (-1.21806N, 36.73739E)
# Gathigio, Kenya, (-0.8N, 37.06667E)
# Gathigiriri, Kenya, (-0.69095N, 37.40817E)
# Gathima, Kenya, (-1.03333N, 36.75E)
# Gathinja, Kenya, (-0.71667N, 37.01667E)
# Gathiriga, Kenya, (-0.9587N, 36.73953E)
# Gathiru, Kenya, (-0.75168N, 37.02736E)
# Gathiruini, Kenya, (-1.02493N, 36.80552E)
# Gathithina, Kenya, (-1.21667N, 36.68333E)
# Gathuga, Kenya, (-1.0N, 36.8E)
# Gathugu, Kenya, (-1.00394N, 36.81155E)
# Gathukeini, Kenya, (-0.63477N, 37.06695E)
# Gathumbi, Kenya, (-0.53323N, 36.90552E)
# Gathundia, Kenya, (-0.25N, 36.28333E)
# Gathungururu, Kenya, (-0.55N, 37.01667E)
# Gathuthi, Kenya, (-0.49177N, 36.88548E)
# Gathuthuma, Kenya, (-0.43333N, 37.21667E)
# Gatiabai, Kenya, (-1.2326N, 36.66709E)
# Gatiaini, Kenya, (-0.77883N, 36.82285E)
# Gatiiguru, Kenya, (-1.06276N, 36.89103E)
# Gatimu, Kenya, (-1.15794N, 36.64917E)
# Gatina, Kenya, (-0.55N, 37.13333E)
# Gatissa, Kenya, (-0.58333N, 37.18333E)
# Gatithi, Kenya, (-0.58333N, 37.2E)
# Gatitu, Kenya, (-1.00605N, 36.84175E)
# Gatitu B, Kenya, (-1.01907N, 36.8468E)
# Gatuanibu, Kenya, (-1.19227N, 36.68155E)
# Gatugi One, Kenya, (-0.51667N, 36.96667E)
# Gatugi Two, Kenya, (-0.53333N, 36.96667E)
# Gatukuyu, Kenya, (-0.98413N, 36.96517E)
# Gatumbi, Kenya, (-0.45N, 37.35E)
# Gatumbiru, Kenya, (-0.46538N, 36.86654E)
# Gatundu, Kenya, (-1.05N, 36.9E)
# Gatunduri, Kenya, (-0.48312N, 37.47742E)
# Gatunga, Kenya, (-0.10095N, 38.01081E)
# Gatunganga, Kenya, (-0.41231N, 37.04637E)
# Gatunguru, Kenya, (-0.89403N, 36.84154E)
# Gatura, Kenya, (-0.54122N, 37.03612E)
# Gaturi, Kenya, (-0.45N, 36.85E)
# Gaturiri, Kenya, (-0.5N, 37.11667E)
# Gatuto, Kenya, (-0.57147N, 37.30337E)
# Gatuya, Kenya, (-0.53333N, 37.21667E)
# Gatuyaini, Kenya, (-0.54607N, 36.93376E)
# Gatwamba, Kenya, (-1.01667N, 36.7E)
# Gatwe, Kenya, (-0.43333N, 37.23333E)
# Gazi, Kenya, (-4.42402N, 39.50588E)
# Gede, Kenya, (-3.30341N, 40.01602E)
# Geitwa, Kenya, (-0.62711N, 37.08047E)
# Gekuuri, Kenya, (-0.45142N, 37.55877E)
# Gendia, Kenya, (-0.4N, 34.66667E)
# Gerarsa, Kenya, (-2.04547N, 39.47681E)
# Gethemu, Kenya, (-0.50911N, 37.51736E)
# Ghalamani, Kenya, (-1.3935N, 39.9984E)
# Giachamwengi, Kenya, (-0.45661N, 36.94833E)
# Giachumi, Kenya, (-1.06667N, 36.78333E)
# Giagatika, Kenya, (-0.48333N, 37.08333E)
# Giagithu, Kenya, (-1.09871N, 36.85314E)
# Giaitu, Kenya, (-0.48571N, 37.09876E)
# Giakaibii, Kenya, (-0.41667N, 37.15E)
# Giakibii, Kenya, (-0.41667N, 37.15E)
# Giathieko, Kenya, (-1.09167N, 36.82525E)
# Giathugu One, Kenya, (-0.58333N, 37.1E)
# Giathugu Two, Kenya, (-0.58333N, 37.08333E)
# Gichage, Kenya, (-0.33012N, 35.85E)
# Gichagiini, Kenya, (-0.81012N, 36.89882E)
# Gicharani, Kenya, (-1.27616N, 36.66459E)
# Gicheha, Kenya, (-1.02183N, 36.91179E)
# Gichera, Kenya, (-0.44652N, 37.60168E)
# Gicheru, Kenya, (-1.1804N, 36.55299E)
# Gichiche, Kenya, (-0.43346N, 37.58694E)
# Gichichi, Kenya, (-0.574N, 36.93202E)
# Gichiengo, Kenya, (-0.94263N, 36.61762E)
# Gichira, Kenya, (-0.46667N, 37.01667E)
# Gichocho, Kenya, (-1.14045N, 36.83097E)
# Gichongo, Kenya, (-1.26667N, 36.68333E)
# Gichoto, Kenya, (-1.27853N, 36.65145E)
# Gichugu, Kenya, (-0.81667N, 37.1E)
# Gichuru, Kenya, (-1.16398N, 36.66724E)
# Gikambura, Kenya, (-1.28067N, 36.64445E)
# Gikandu, Kenya, (-0.72213N, 37.09481E)
# Gikaru, Kenya, (-1.2N, 36.7E)
# Gikigie, Kenya, (-0.73333N, 36.83333E)
# Gikoe, Kenya, (-0.63698N, 36.92988E)
# Gikomora, Kenya, (-0.81667N, 37.03333E)
# Gikondi, Kenya, (-0.60634N, 37.06796E)
# Gikui, Kenya, (-0.93333N, 36.91667E)
# Gikunguru, Kenya, (-0.78333N, 37.05E)
# Gikure, Kenya, (-0.96975N, 36.84419E)
# Gikuu, Kenya, (-0.71618N, 37.23135E)
# Gilgil, Kenya, (-0.48972N, 36.31201E)
# Giriama, Kenya, (-3.8175N, 39.59699E)
# Giriftu, Kenya, (2.00039N, 39.75191E)
# Gitare, Kenya, (-0.39832N, 37.55683E)
# Gitaro, Kenya, (-0.73333N, 37.06667E)
# Gitaru, Kenya, (-1.23333N, 36.68333E)
# Gitathi-ini, Kenya, (-0.43333N, 36.93333E)
# Gitero, Kenya, (-0.44984N, 36.93588E)
# Githagara, Kenya, (-0.76667N, 37.01667E)
# Githagoya, Kenya, (-0.66216N, 37.21954E)
# Githakwa, Kenya, (-0.46603N, 36.90011E)
# Githamba, Kenya, (-1.06667N, 36.81667E)
# Githambo, Kenya, (-0.71093N, 36.88455E)
# Githanga, Kenya, (-0.61667N, 37.06667E)
# Githega, Kenya, (-1.07842N, 36.69151E)
# Githembe, Kenya, (-0.8519N, 37.05398E)
# Githerere, Kenya, (-0.48333N, 36.86667E)
# Githiga, Kenya, (-0.7N, 36.93333E)
# Githiga A, Kenya, (-1.08693N, 36.73405E)
# Githiga B, Kenya, (-1.09261N, 36.75568E)
# Githigui, Kenya, (-1.05N, 36.91667E)
# Githima, Kenya, (-0.82404N, 37.00429E)
# Githioro, Kenya, (-0.46849N, 36.49944E)
# Githirioni, Kenya, (-1.02301N, 36.65353E)
# Githiru, Kenya, (-0.45N, 37.01667E)
# Githoito, Kenya, (-0.97341N, 36.65509E)
# Githumu, Kenya, (-0.83035N, 36.91592E)
# Githunguchu, Kenya, (-1.02358N, 36.92737E)
# Githunguri, Kenya, (-1.04722N, 36.90206E)
# Githurai, Kenya, (0.65392N, 35.49738E)
# Githuri, Kenya, (-0.70214N, 37.1861E)
# Githuya, Kenya, (-1.0N, 36.91667E)
# Gitige, Kenya, (-0.73333N, 37.03333E)
# Gitiha, Kenya, (-1.06295N, 36.69469E)
# Gitithia, Kenya, (-1.06667N, 36.7E)
# Gititu, Kenya, (-1.03333N, 36.81667E)
# Gitombo, Kenya, (-1.05056N, 36.82816E)
# Gituamba, Kenya, (-0.76974N, 37.15054E)
# Gituandaga, Kenya, (0.15887N, 36.31082E)
# Gitugi, Kenya, (-0.65194N, 37.02122E)
# Gitugu, Kenya, (-0.6799N, 36.93106E)
# Gitui, Kenya, (-0.74544N, 37.0536E)
# Gitumbi, Kenya, (-0.45378N, 37.26906E)
# Gitura, Kenya, (-0.9164N, 37.11684E)
# Gituru, Kenya, (-0.99536N, 36.9009E)
# Gituto, Kenya, (-0.72455N, 37.01037E)
# Gitwamba, Kenya, (-0.98333N, 36.7E)
# Gitwe, Kenya, (-0.95N, 36.81514E)
# Gitweku, Kenya, (-0.7N, 36.96667E)
# Godanabio, Kenya, (-2.55523N, 40.1974E)
# Godo, Kenya, (-4.53288N, 39.03835E)
# Godoma, Kenya, (-4.40766N, 39.27711E)
# Gojam, Kenya, (-1.38088N, 39.80128E)
# Golbanti, Kenya, (-2.45518N, 40.19235E)
# Golini, Kenya, (-4.15744N, 39.46683E)
# Golo, Kenya, (-3.93333N, 39.61667E)
# Gomesa, Kenya, (-2.34635N, 40.21607E)
# Gongoni, Kenya, (-3.82718N, 39.76301E)
# Gonja, Kenya, (-4.55487N, 39.07373E)
# Goroba, Kenya, (-0.63333N, 35.65E)
# Gors, Kenya, (-0.56667N, 34.73333E)
# Goshi, Kenya, (-3.45681N, 39.4178E)
# Gotani, Kenya, (-3.78233N, 39.54086E)
# Gubanargesa, Kenya, (-2.31738N, 40.17498E)
# Gulanze, Kenya, (-4.1916N, 39.20618E)
# Gura Gura, Kenya, (-1.06667N, 36.88333E)
# Gutati, Kenya, (-2.04873N, 39.24594E)
# Habaswein, Kenya, (1.01659N, 39.49122E)
# Habul, Kenya, (-0.51667N, 40.91667E)
# Hadu, Kenya, (-2.83888N, 39.97767E)
# Hagadera, Kenya, (0.00281N, 40.3787E)
# Haluabagala, Kenya, (-2.85N, 39.66667E)
# Handampia, Kenya, (-1.5974N, 40.06086E)
# Handarako, Kenya, (-1.78333N, 39.35E)
# Handege, Kenya, (-0.97155N, 36.85864E)
# Hara, Kenya, (0.9283N, 39.89153E)
# Hara Hurile, Kenya, (4.05713N, 40.26332E)
# Haridfi, Kenya, (-0.58333N, 40.81667E)
# Haruru, Kenya, (-1.31667N, 40.18333E)
# Hatha-ini, Kenya, (-0.5N, 36.9E)
# Heho, Kenya, (-0.84199N, 37.12176E)
# Heni Village, Kenya, (-0.78286N, 36.55674E)
# Henzamwenye, Kenya, (-4.47359N, 39.195E)
# Hewani, Kenya, (-2.23416N, 40.17808E)
# Hidio, Kenya, (-2.23324N, 40.73079E)
# Higlet, Kenya, (-1.06667N, 40.31667E)
# Hindi, Kenya, (-2.17838N, 40.81878E)
# Hola, Kenya, (-1.49448N, 40.06117E)
# Holili, Kenya, (-3.37694N, 37.63779E)
# Homa Bay, Kenya, (-0.52731N, 34.45714E)
# Homa Lime Kowuor, Kenya, (-0.43091N, 34.47475E)
# Huguini, Kenya, (-0.48783N, 36.85834E)
# Huho-ini, Kenya, (-0.4516N, 36.87006E)
# Huhoini, Kenya, (-0.51667N, 37.01667E)
# Huma Lime, Kenya, (-0.42444N, 34.47175E)
# Hungai, Kenya, (2.2383N, 40.19462E)
# Ianzoni, Kenya, (-1.68333N, 37.31667E)
# Iboona, Kenya, (0.0429N, 34.64968E)
# Ichachiri, Kenya, (-0.9908N, 36.87848E)
# Ichagachiru, Kenya, (-0.43876N, 36.8559E)
# Ichagaki, Kenya, (-0.81073N, 37.08734E)
# Ichamara, Kenya, (-0.55N, 37.08333E)
# Ichichi, Kenya, (-0.7043N, 36.84383E)
# Idokho, Kenya, (0.05N, 34.0E)
# Idsowe, Kenya, (-2.29569N, 40.1228E)
# Igikiro, Kenya, (-0.81667N, 37.18333E)
# Ihigaini, Kenya, (-0.78333N, 37.08333E)
# Ihinga, Kenya, (-0.76667N, 37.0E)
# Ihithe, Kenya, (-0.48134N, 36.86517E)
# Ihuririo, Kenya, (-0.5504N, 36.86878E)
# Ihururu, Kenya, (-0.41667N, 36.88333E)
# Ihwa, Kenya, (-0.42584N, 36.86794E)
# Ihwagi, Kenya, (-0.44496N, 37.14765E)
# Iiuni, Kenya, (-1.68726N, 37.33131E)
# Ijara, Kenya, (-1.59517N, 40.51444E)
# Ikalaasa, Kenya, (-1.53344N, 37.67145E)
# Ikalyoni, Kenya, (-1.76187N, 37.37896E)
# Ikanga, Kenya, (-3.71468N, 39.48346E)
# Ikinu, Kenya, (-1.10804N, 36.79161E)
# Ikonge, Kenya, (-0.53174N, 35.02677E)
# Ikoo, Kenya, (-1.17617N, 38.17167E)
# Ikuma, Kenya, (-1.0N, 36.86667E)
# Ikumbi, Kenya, (-0.78831N, 36.89794E)
# Ikundu, Kenya, (-0.77164N, 37.14805E)
# Ikutha, Kenya, (-2.06656N, 38.17808E)
# Ilbisil, Kenya, (-2.09798N, 36.79411E)
# Ildamat, Kenya, (-0.95966N, 36.07723E)
# Ileret, Kenya, (4.31115N, 36.2257E)
# Ilkabere, Kenya, (-0.96417N, 41.05E)
# Ilpartimaro, Kenya, (-2.27059N, 36.71173E)
# Imale, Kenya, (-2.1512N, 38.28157E)
# Iminuet, Kenya, (-0.85N, 35.48333E)
# Inyokoni, Kenya, (-1.79205N, 37.40416E)
# Irangi, Kenya, (-0.35N, 39.48333E)
# Iregi, Kenya, (-0.76667N, 37.1E)
# Iriguini, Kenya, (-0.8N, 36.96667E)
# Iruri, Kenya, (-0.35791N, 37.09003E)
# Ishiara, Kenya, (-0.45056N, 37.78948E)
# Isibania, Kenya, (-1.23943N, 34.47922E)
# Isiolo, Kenya, (0.35462N, 37.58218E)
# Isoge/Kineni, Kenya, (-0.77377N, 35.05351E)
# Issas, Kenya, (0.71263N, 35.82745E)
# Isuvya, Kenya, (-1.55N, 37.26667E)
# Itaga, Kenya, (-0.8N, 37.03333E)
# Iten, Kenya, (0.65392N, 35.49738E)
# Itetani, Kenya, (-1.58816N, 37.38588E)
# Ithaithi, Kenya, (-0.46667N, 37.06667E)
# Ithanji, Kenya, (-0.53333N, 37.05E)
# Ithareni, Kenya, (-0.5N, 37.31667E)
# Ithekahuno, Kenya, (-0.50882N, 37.04546E)
# Ithemboni, Kenya, (-1.64951N, 37.45175E)
# Ithenguri, Kenya, (-0.46667N, 36.96667E)
# Itheru, Kenya, (-0.8N, 37.11667E)
# Ithoku, Kenya, (-1.83333N, 38.56667E)
# Ithumba, Kenya, (-2.19586N, 38.39812E)
# Itiati, Kenya, (-0.41667N, 37.1E)
# Itugururu, Kenya, (-0.41667N, 37.71667E)
# Itumbe, Kenya, (-0.704167N, 34.806833E)
# Itundu, Kenya, (-0.41449N, 37.18448E)
# Ituramiro, Kenya, (-0.94509N, 36.7835E)
# Iuani, Kenya, (-1.72965N, 37.52327E)
# Iyego, Kenya, (-0.66667N, 36.98333E)
# Jaba Dimtu, Kenya, (2.88306N, 41.04501E)
# Jalalaluma, Kenya, (-2.40799N, 40.35917E)
# Jaleny Village, Kenya, (-0.96876N, 34.43499E)
# Jambe, Kenya, (-4.60387N, 39.16836E)
# Jamhuri, Kenya, (-1.73054N, 40.08946E)
# Jamhuri Park, Kenya, (-1.3N, 36.76667E)
# Jamji, Kenya, (-0.47775N, 35.18684E)
# Janoni, Kenya, (-0.56667N, 38.51667E)
# Jara, Kenya, (-1.93333N, 39.03333E)
# Jarabuni, Kenya, (-3.63118N, 39.73964E)
# Jebrok, Kenya, (0.01772N, 34.76074E)
# Jego, Kenya, (-4.64726N, 39.18933E)
# Jera, Kenya, (0.28504N, 34.26677E)
# Jeuri, Kenya, (-3.87104N, 39.79162E)
# Jila, Kenya, (-3.42171N, 39.53472E)
# Jilole, Kenya, (-1.89533N, 40.25481E)
# Jilore, Kenya, (-3.18333N, 39.9E)
# Jimbo, Kenya, (-4.6771N, 39.21446E)
# Jipe, Kenya, (-2.1588N, 40.89217E)
# Jirikokole, Kenya, (-2.94817N, 39.76913E)
# Jiweni, Kenya, (-4.25908N, 39.1935E)
# Jomvu, Kenya, (-3.98545N, 39.61416E)
# Jomvu Kuu, Kenya, (-3.97811N, 39.58844E)
# Jora, Kenya, (-3.83963N, 38.6461E)
# Jorore, Kenya, (-4.28125N, 39.45977E)
# Josam Investments plots, Kenya, (-1.68612N, 36.87003E)
# Josephs, Kenya, (-0.60334N, 34.57115E)
# Juja, Kenya, (-1.10148N, 37.0132E)
# Jumba la Mtwana, Kenya, (-3.95N, 39.76667E)
# Junda, Kenya, (-4.016415N, 39.707164E)
# Junja, Kenya, (-2.08333N, 40.76667E)
# Junju, Kenya, (-3.84929N, 39.75116E)
# Kaagogi, Kenya, (-0.43333N, 36.9E)
# Kaani, Kenya, (-1.51384N, 37.3602E)
# Kaathene, Kenya, (0.23333N, 37.93333E)
# Kabage, Kenya, (-0.40436N, 36.82127E)
# Kabaloamet, Kenya, (1.24908N, 35.63769E)
# Kabare, Kenya, (-0.50669N, 37.3231E)
# Kabarnet, Kenya, (0.49194N, 35.74303E)
# Kabartonjo, Kenya, (0.63035N, 35.79575E)
# Kabaru, Kenya, (-0.28047N, 37.15656E)
# Kabati, Kenya, (-0.95241N, 37.10704E)
# Kabebero, Kenya, (-0.54984N, 36.86945E)
# Kabete, Kenya, (-1.25891N, 36.72778E)
# Kabianga, Kenya, (-0.4457N, 35.1382E)
# Kabiboni, Kenya, (-3.00526N, 40.00701E)
# Kabieni, Kenya, (-3.87598N, 39.59319E)
# Kabimoi, Kenya, (0.02394N, 35.78457E)
# Kabisaga, Kenya, (0.43357N, 35.10934E)
# Kabiyet, Kenya, (0.40453N, 35.08605E)
# Kabluk, Kenya, (0.56723N, 35.66554E)
# Kabochu, Kenya, (-1.18438N, 36.66835E)
# Kabola, Kenya, (-0.83333N, 34.53333E)
# Kabondo, Kenya, (-0.45356N, 34.88022E)
# Kabonge, Kenya, (-0.5N, 37.21667E)
# Kabongwa, Kenya, (0.21588N, 35.15743E)
# Kabuchai, Kenya, (0.65011N, 34.56261E)
# Kabuku, Kenya, (-1.15708N, 36.67041E)
# Kacheliba, Kenya, (1.4805N, 35.01207E)
# Kachini, Kenya, (-4.43448N, 39.13395E)
# Kachon, Kenya, (2.56612N, 34.96154E)
# Kadenge, Kenya, (0.02085N, 34.18507E)
# Kadimu, Kenya, (-0.06561N, 34.14348E)
# Kadzandani, Kenya, (-2.90279N, 39.97137E)
# Kadzeweni, Kenya, (-3.65N, 39.48333E)
# Kadzinuni, Kenya, (-3.7452N, 39.81062E)
# Kaembekaesha, Kenya, (-3.06667N, 40.1E)
# Kagaa, Kenya, (-0.75N, 36.96667E)
# Kagaare, Kenya, (-0.43037N, 37.56254E)
# Kaganda, Kenya, (-0.75194N, 36.95258E)
# Kagarii, Kenya, (-0.55778N, 37.01024E)
# Kagene, Kenya, (0.04549N, 37.68676E)
# Kagere, Kenya, (-0.50677N, 36.94514E)
# Kagicha, Kenya, (-0.60166N, 36.9012E)
# Kagio, Kenya, (-0.62482N, 37.25551E)
# Kagioini, Kenya, (-0.48333N, 36.9E)
# Kagira, Kenya, (-0.85167N, 37.00145E)
# Kagododoya, Kenya, (2.70755N, 35.08491E)
# Kagondo, Kenya, (-1.26667N, 36.7E)
# Kagongo, Kenya, (-1.13333N, 36.83333E)
# Kagonye, Kenya, (-0.52346N, 36.90534E)
# Kagumo, Kenya, (-0.73333N, 37.0E)
# Kagumoini, Kenya, (-0.98333N, 36.9E)
# Kagundu, Kenya, (-0.76019N, 36.85768E)
# Kagunduini, Kenya, (-0.85434N, 37.0415E)
# Kagurumo, Kenya, (-0.85N, 37.1E)
# Kaguthi, Kenya, (-0.88183N, 36.96066E)
# Kagwathi, Kenya, (-0.46667N, 36.91667E)
# Kagwe, Kenya, (-1.0038N, 36.74469E)
# Kagwongo, Kenya, (-0.98333N, 36.73333E)
# Kahaaro, Kenya, (-0.53333N, 37.05E)
# Kahaini, Kenya, (-0.84337N, 37.17148E)
# Kaharati, Kenya, (-0.84298N, 37.14943E)
# Kaharo, Kenya, (-0.73864N, 36.90154E)
# Kahawa, Kenya, (-1.18333N, 36.91667E)
# Kahiga, Kenya, (-0.43763N, 37.04181E)
# Kahigaini, Kenya, (-0.4N, 36.86667E)
# Kahithe, Kenya, (-0.73333N, 36.98333E)
# Kahuguini, Kenya, (-1.03845N, 36.91176E)
# Kahuhia, Kenya, (-0.70935N, 37.04292E)
# Kahuho, Kenya, (-1.21435N, 36.67545E)
# Kahuro, Kenya, (-0.74816N, 37.00832E)
# Kahuti, Kenya, (-0.71351N, 36.96568E)
# Kaiboi, Kenya, (0.41344N, 35.01981E)
# Kailembwa, Kenya, (-2.20079N, 38.06088E)
# Kaimba, Kenya, (-1.20398N, 36.67209E)
# Kaimu, Kenya, (-1.16667N, 38.0E)
# Kainyunyok, Kenya, (2.54212N, 35.31584E)
# Kairi, Kenya, (-1.08333N, 36.83333E)
# Kairi Ka Igamba, Kenya, (-0.91667N, 36.88333E)
# Kairo, Kenya, (-0.60931N, 36.86997E)
# Kairuri, Kenya, (-0.42485N, 37.44697E)
# Kairuthi, Kenya, (-0.53323N, 36.88768E)
# Kaiyaba, Kenya, (-0.47475N, 37.08811E)
# Kajiado, Kenya, (-1.85238N, 36.77683E)
# Kajinga, Kenya, (-1.2N, 36.68333E)
# Kajire, Kenya, (-3.51757N, 38.6077E)
# Kakalet, Kenya, (2.62619N, 35.4725E)
# Kakalia, Kenya, (-1.61397N, 37.37483E)
# Kakamega, Kenya, (0.288819N, 34.75047E)
# Kakangani, Kenya, (-2.41667N, 37.98333E)
# Kakayuni, Kenya, (-1.36598N, 37.34564E)
# Kakem, Kenya, (2.97426N, 35.34968E)
# Kakomani, Kenya, (-3.84578N, 39.63296E)
# Kakoneni, Kenya, (-3.17271N, 39.86077E)
# Kakujukwol, Kenya, (2.84861N, 35.91199E)
# Kakuma, Kenya, (3.71363N, 34.8572E)
# Kakunike, Kenya, (-0.77081N, 38.35178E)
# Kakunio, Kenya, (-1.91791N, 38.18445E)
# Kakuyuni, Kenya, (-3.21667N, 40.0E)
# Kalaluwe, Kenya, (-2.97125N, 39.73907E)
# Kalamba, Kenya, (-1.86826N, 37.5122E)
# Kalandini, Kenya, (-0.17387N, 34.36621E)
# Kalasa, Kenya, (-1.53333N, 37.66667E)
# Kalawa, Kenya, (-1.36555N, 38.03868E)
# Kalema, Kenya, (-1.79664N, 36.06174E)
# Kali, Kenya, (-1.63365N, 37.38332E)
# Kalii, Kenya, (-2.1N, 37.76667E)
# Kalimaruk, Kenya, (2.13448N, 35.49627E)
# Kalimbui, Kenya, (-1.1N, 37.96667E)
# Kalimoni, Kenya, (-1.11616N, 37.00908E)
# Kalitini, Kenya, (-0.98333N, 38.25E)
# Kalivu, Kenya, (-2.00833N, 38.08817E)
# Kalkacha, Kenya, (-1.5N, 39.99123E)
# Kalobeyei, Kenya, (3.77159N, 34.6229E)
# Kalodeke, Kenya, (2.14753N, 34.96163E)
# Kalokol, Kenya, (3.52113N, 35.83294E)
# Kaloleni, Kenya, (-1.3N, 36.85E)
# Kalomwai, Kenya, (2.23514N, 35.35121E)
# Kalongoleputh, Kenya, (2.58105N, 35.88391E)
# Kalulini, Kenya, (-2.34295N, 38.00069E)
# Kaluluini, Kenya, (-2.1N, 38.28333E)
# Kalundu, Kenya, (-1.35741N, 38.00832E)
# Kamacharia, Kenya, (-0.60164N, 36.98954E)
# Kamae, Kenya, (-0.84698N, 36.6367E)
# Kamaende, Kenya, (-0.36401N, 37.85685E)
# Kamahia, Kenya, (-1.02771N, 36.71352E)
# Kamakoiwa, Kenya, (0.77788N, 34.78961E)
# Kamale, Kenya, (-2.74636N, 39.99196E)
# Kamamut, Kenya, (0.43056N, 34.99647E)
# Kamandura, Kenya, (-1.13943N, 36.63546E)
# Kamarabuyon, Kenya, (0.48333N, 36.18333E)
# Kamarr, Kenya, (0.26667N, 36.01667E)
# Kamathuri, Kenya, (-0.56667N, 37.23333E)
# Kamatu, Kenya, (-0.5N, 37.1E)
# Kambaa, Kenya, (-0.99101N, 36.65394E)
# Kambara, Kenya, (-1.08333N, 36.85E)
# Kambi ya Munyu, Kenya, (-2.31667N, 37.91667E)
# Kambini, Kenya, (-4.54961N, 39.08633E)
# Kambirua, Kenya, (-0.74268N, 37.19717E)
# Kambu, Kenya, (-2.59459N, 38.0758E)
# Kamburu, Kenya, (-1.02735N, 36.74236E)
# Kameichiri, Kenya, (-0.65186N, 37.30576E)
# Kamira, Kenya, (-0.81667N, 37.05E)
# Kamirithu, Kenya, (-1.11399N, 36.62794E)
# Kamleza, Kenya, (-3.4607N, 37.69258E)
# Kamnunguuawa, Kenya, (1.96667N, 35.13333E)
# Kamondo, Kenya, (-1.09977N, 36.77481E)
# Kampi Ya Juu, Kenya, (0.33333N, 37.56667E)
# Kampi Ya Njemi, Kenya, (-0.97817N, 36.7998E)
# Kampi Ya Samaki, Kenya, (0.61104N, 36.02204E)
# Kampi Ya Sheikh Omar, Kenya, (0.33333N, 37.55E)
# Kampi ya Bibi, Kenya, (-3.41182N, 38.03182E)
# Kampi ya Kerenzeni, Kenya, (-2.91667N, 40.13333E)
# Kamuchege, Kenya, (-0.67595N, 37.38049E)
# Kamuchoni, Kenya, (-0.58333N, 37.03333E)
# Kamudi, Kenya, (-0.65N, 39.8E)
# Kamuga, Kenya, (-0.2N, 34.5E)
# Kamugeno, Kenya, (-0.81667N, 35.11667E)
# Kamuguga, Kenya, (-1.20986N, 36.66527E)
# Kamuiru, Kenya, (-0.49048N, 37.2236E)
# Kamukabi, Kenya, (-0.76667N, 36.93333E)
# Kamulu, Kenya, (-1.36667N, 38.03333E)
# Kamune, Kenya, (-0.60019N, 37.01733E)
# Kamungu, Kenya, (-0.86667N, 37.08333E)
# Kamunono, Kenya, (2.14623N, 35.31615E)
# Kamunyaka, Kenya, (-0.90508N, 36.78994E)
# Kamunyuini, Kenya, (-1.0N, 36.91667E)
# Kamusinga, Kenya, (0.7938N, 34.70654E)
# Kamuthwa, Kenya, (-1.51366N, 37.64816E)
# Kamuyu, Kenya, (-0.41667N, 36.91667E)
# Kamwangi, Kenya, (-1.19716N, 36.69847E)
# Kamwaura, Kenya, (-0.43333N, 35.58333E)
# Kamwenja, Kenya, (-0.39738N, 36.91617E)
# Kanamkemer, Kenya, (3.10125N, 35.6015E)
# Kanaodon, Kenya, (2.51667N, 35.38333E)
# Kandara, Kenya, (-0.9N, 37.0E)
# Kandegenye, Kenya, (-0.75N, 37.01667E)
# Kandogo, Kenya, (-1.05551N, 36.86469E)
# Kandolo, Kenya, (-1.96667N, 37.36667E)
# Kandongu, Kenya, (-0.66007N, 37.2885E)
# Kangai, Kenya, (-0.6238N, 37.30044E)
# Kangaita, Kenya, (-0.49724N, 36.99491E)
# Kangare, Kenya, (-0.79569N, 36.8813E)
# Kangaru, Kenya, (-0.63316N, 37.25339E)
# Kangema, Kenya, (-0.68333N, 36.96667E)
# Kangenga, Kenya, (-0.78333N, 37.1E)
# Kangeta, Kenya, (0.27506N, 37.88594E)
# Kangethia, Kenya, (-0.47028N, 37.55013E)
# Kango, Kenya, (-0.46667N, 38.11667E)
# Kangocho, Kenya, (-0.50595N, 37.16566E)
# Kangoru, Kenya, (-0.53333N, 37.05E)
# Kangoya, Kenya, (-1.16667N, 36.81667E)
# Kangundo, Kenya, (-1.29792N, 37.34705E)
# Kangunyi, Kenya, (-0.96667N, 36.78333E)
# Kaningo, Kenya, (-0.81667N, 38.53333E)
# Kanja, Kenya, (-0.37856N, 37.52947E)
# Kanjai, Kenya, (-1.04559N, 36.79476E)
# Kanjonja, Kenya, (-1.74348N, 40.12145E)
# Kanjora, Kenya, (-0.40942N, 36.88032E)
# Kanjuki, Kenya, (-0.34087N, 37.83339E)
# Kanjuku, Kenya, (-0.95N, 36.88333E)
# Kanunga, Kenya, (-0.83333N, 36.88333E)
# Kanwe-Mayi, Kenya, (-2.44752N, 40.47056E)
# Kanyama, Kenya, (-0.47329N, 37.09986E)
# Kanyamgoni, Kenya, (-0.87503N, 34.59434E)
# Kanyao, Kenya, (1.78788N, 35.05246E)
# Kanyariri, Kenya, (-1.24689N, 36.71085E)
# Kanyarkwat, Kenya, (1.26066N, 34.91347E)
# Kanyekine, Kenya, (-0.12445N, 37.67272E)
# Kanyenyaine, Kenya, (-0.68559N, 36.89183E)
# Kanyinya, Kenya, (-0.41906N, 36.84188E)
# Kanyongo, Kenya, (-1.24223N, 36.72596E)
# Kanyoni, Kenya, (-0.92696N, 36.86138E)
# Kanyore, Kenya, (-1.06667N, 36.73333E)
# Kanyuira, Kenya, (-0.65N, 36.9E)
# Kanywambora, Kenya, (-0.46293N, 37.7195E)
# Kaongo, Kenya, (-0.03645N, 37.7231E)
# Kap Sarok, Kenya, (-0.29677N, 35.0566E)
# Kapangani, Kenya, (-2.82072N, 39.58127E)
# Kapchebelel, Kenya, (0.29084N, 35.56579E)
# Kapchepkor, Kenya, (0.62511N, 35.81383E)
# Kapcherop, Kenya, (1.04107N, 35.3225E)
# Kapchorwa, Kenya, (0.18862N, 35.53223E)
# Kapedo, Kenya, (1.17453N, 36.03901E)
# Kapenguria, Kenya, (1.23333N, 35.11667E)
# Kapkalelwa, Kenya, (0.37195N, 35.71973E)
# Kapkiam, Kenya, (0.66048N, 35.779E)
# Kapkures Primary School, Kenya, (-0.43655N, 35.09449E)
# Kapok, Kenya, (-4.25301N, 39.57237E)
# Kapsabet, Kenya, (0.20387N, 35.105E)
# Kapsakwony, Kenya, (0.84033N, 34.71489E)
# Kapsamonget, Kenya, (-0.31667N, 35.21667E)
# Kapsaos, Kenya, (-0.31678N, 35.3424E)
# Kapsoit, Kenya, (-0.32027N, 35.21831E)
# Kapsokwony, Kenya, (0.85222N, 34.70194E)
# Kapsowar, Kenya, (0.9789N, 35.55854E)
# Kapsuset, Kenya, (-0.40394N, 35.22441E)
# Kaptama, Kenya, (0.88683N, 34.76857E)
# Kaptarakwa, Kenya, (0.46465N, 35.54112E)
# Kaptebengwet, Kenya, (-0.58333N, 35.31667E)
# Kapteren, Kenya, (0.56263N, 35.47923E)
# Kaption, Kenya, (0.69798N, 35.73644E)
# Kaptumo, Kenya, (0.07093N, 35.06988E)
# Kapturwo, Kenya, (0.65827N, 35.69004E)
# Kaputir, Kenya, (2.08312N, 35.46514E)
# Karaba, Kenya, (-0.7716N, 37.36603E)
# Karaba Special Camp, Kenya, (-0.73333N, 37.43333E)
# Karaine, Kenya, (-0.45N, 37.25E)
# Karangi, Kenya, (-0.83333N, 36.8E)
# Karare, Kenya, (-0.32266N, 39.55081E)
# Karatina, Kenya, (-0.99481N, 36.75695E)
# Karembu, Kenya, (-1.03333N, 36.9E)
# Karenge, Kenya, (-1.01667N, 36.78333E)
# Karero, Kenya, (-1.91667N, 36.7E)
# Kareti, Kenya, (-0.86832N, 37.01765E)
# Karfi, Kenya, (10.3687N, 8.64839E)
# Kargi, Kenya, (2.50679N, 37.57563E)
# Karia, Kenya, (-0.43333N, 37.38333E)
# Kariaini, Kenya, (-0.81667N, 36.98333E)
# Kariara, Kenya, (-0.61017N, 37.14277E)
# Kariguini, Kenya, (-0.48333N, 36.95E)
# Kariko, Kenya, (-0.57685N, 36.88016E)
# Kariku, Kenya, (-0.95N, 36.91667E)
# Karima, Kenya, (-0.68993N, 37.32823E)
# Karimamwaro, Kenya, (-0.88333N, 37.01667E)
# Karimani, Kenya, (-3.41755N, 39.46109E)
# Karindi, Kenya, (-0.57834N, 37.00796E)
# Karinga, Kenya, (-1.03333N, 36.78333E)
# Karingaini, Kenya, (-0.53333N, 37.06667E)
# Karingare, Kenya, (-0.4713N, 37.50635E)
# Kariobangi, Kenya, (-1.25N, 36.88333E)
# Karirau, Kenya, (-0.66667N, 37.0E)
# Kariru, Kenya, (-0.49115N, 37.35628E)
# Kariua, Kenya, (-0.84467N, 36.96907E)
# Karogoto, Kenya, (-0.5N, 37.1E)
# Karota, Kenya, (-1.79649N, 40.03741E)
# Karua, Kenya, (-0.8N, 37.18333E)
# Karuamgi, Kenya, (-0.55N, 37.45E)
# Karuari, Kenya, (-0.5N, 37.71667E)
# Karugia, Kenya, (-0.9N, 37.11667E)
# Karugutu, Kenya, (-0.88333N, 36.83333E)
# Karumandi, Kenya, (-0.45N, 37.35E)
# Karuna, Kenya, (0.7336N, 35.48445E)
# Karundu, Kenya, (-0.57658N, 37.10014E)
# Karunga, Kenya, (-1.15N, 36.81667E)
# Karunge, Kenya, (-0.65754N, 36.98396E)
# Karungu, Kenya, (-0.849626N, 34.149998E)
# Karura, Kenya, (-1.22609N, 36.78159E)
# Karura Kanyungu, Kenya, (-1.19977N, 36.72519E)
# Karuri, Kenya, (-0.7N, 37.18333E)
# Karuru One, Kenya, (-0.73333N, 37.05E)
# Karuru Two, Kenya, (-0.73333N, 37.03333E)
# Karurumo, Kenya, (-0.6859N, 36.83183E)
# Karweti, Kenya, (-1.05N, 36.81667E)
# Kasafari, Kenya, (-0.48668N, 37.69729E)
# Kasagini, Kenya, (-4.0852N, 39.14028E)
# Kasaini, Kenya, (-1.45237N, 37.26711E)
# Kasala, Kenya, (-2.13818N, 38.26673E)
# Kasei, Kenya, (1.97343N, 35.20563E)
# Kashani, Kenya, (-3.95N, 39.7E)
# Kasidi, Kenya, (-3.88333N, 39.6E)
# Kasikeu, Kenya, (-1.94806N, 37.385E)
# Kasikini, Kenya, (-2.95112N, 39.74294E)
# Kasiokoni, Kenya, (-1.71016N, 38.70487E)
# Kasioni, Kenya, (-0.55N, 38.01667E)
# Kasisit, Kenya, (0.637N, 35.82716E)
# Kasyelia, Kenya, (-1.92426N, 38.24131E)
# Katabui, Kenya, (3.75413N, 35.82954E)
# Kataier, Kenya, (2.35706N, 34.94599E)
# Katelembo, Kenya, (-1.51873N, 37.20816E)
# Katene, Kenya, (-1.75038N, 38.44084E)
# Kathaiya, Kenya, (-0.5N, 37.33333E)
# Kathangari, Kenya, (-0.47307N, 37.4406E)
# Kathangariri, Kenya, (-0.41112N, 37.4491E)
# Kathare, Kenya, (-0.52229N, 37.24889E)
# Kathari, Kenya, (-0.39433N, 37.60155E)
# Katheka, Kenya, (-1.17936N, 37.33599E)
# Kathekani, Kenya, (-2.62034N, 38.1563E)
# Kathenaugi, Kenya, (-0.1N, 38.15E)
# Kathugu, Kenya, (-0.47972N, 37.58243E)
# Kathungu, Kenya, (-1.8N, 38.53333E)
# Kathungure, Kenya, (-0.4247N, 37.6244E)
# Katothya, Kenya, (-1.23514N, 37.72517E)
# Katsaka Kairu, Kenya, (-2.33868N, 40.36852E)
# Katulani, Kenya, (-1.52625N, 37.64144E)
# Katulye, Kenya, (-1.79236N, 37.38301E)
# Katundani, Kenya, (-4.01355N, 39.47367E)
# Kau, Kenya, (-2.48743N, 40.43866E)
# Kaufumbani, Kenya, (-4.64767N, 39.22369E)
# Kaumoni, Kenya, (-1.73503N, 37.5761E)
# Kauretangthuro, Kenya, (2.53923N, 35.96602E)
# Kauriong, Kenya, (2.09399N, 35.09534E)
# Kauro, Kenya, (1.05258N, 37.71086E)
# Kavonge, Kenya, (-1.34098N, 38.03569E)
# Kavote, Kenya, (-0.43037N, 37.30921E)
# Kavuluni, Kenya, (-3.34097N, 39.65867E)
# Kavumbu, Kenya, (-1.52325N, 37.4276E)
# Kawaida, Kenya, (-1.14639N, 36.7598E)
# Kawanjaro, Kenya, (-0.46667N, 37.55E)
# Kawelu, Kenya, (-1.77298N, 38.21738E)
# Kaweru, Kenya, (-0.65N, 37.1E)
# Kayafungo, Kenya, (-3.78333N, 39.51667E)
# Kazoli, Kenya, (-3.93333N, 39.61667E)
# Kebenet, Kenya, (-0.44733N, 35.07874E)
# Kebetwa, Kenya, (1.16263N, 35.64539E)
# Kedong, Kenya, (-1.05N, 36.56667E)
# Kedowa, Kenya, (-0.23299N, 35.55621E)
# Keekorok, Kenya, (-1.58715N, 35.23521E)
# Kegaa, Kenya, (-0.43333N, 37.56667E)
# Kelokelo, Kenya, (-1.61288N, 40.07214E)
# Kenani, Kenya, (-2.81667N, 38.41667E)
# Kendu Bay, Kenya, (-0.359579N, 34.639994E)
# Kenegut, Kenya, (-0.26903N, 35.22417E)
# Kenplains, Kenya, (-1.51195N, 37.04063E)
# Kenyatta University, Kenya, (-1.282031N, 36.811752E)
# Kenze, Kenya, (-1.67075N, 38.56761E)
# Kereita, Kenya, (-0.99564N, 36.64011E)
# Kericho, Kenya, (-0.36774N, 35.28314E)
# Kerie, Kenya, (-0.57805N, 37.77766E)
# Keringet, Kenya, (1.21294N, 35.04956E)
# Kerisa, Kenya, (-0.28757N, 35.5361E)
# Keroka, Kenya, (-0.77584N, 34.94531E)
# Keruguya, Kenya, (-0.49886N, 37.28031E)
# Keruri, Kenya, (-0.61667N, 36.9E)
# Kesa Guru, Kenya, (-1.55291N, 39.64668E)
# Kesanguri, Kenya, (-1.61667N, 39.71667E)
# Kesses, Kenya, (0.30206N, 35.31441E)
# Keumbu, Kenya, (-0.73503N, 34.84037E)
# Kevanda, Kenya, (-2.36667N, 38.08333E)
# Kevote, Kenya, (-0.43694N, 37.53488E)
# Kholera, Kenya, (0.41694N, 34.47111E)
# Kholokhongo, Kenya, (0.06667N, 33.98333E)
# Khorof Harar, Kenya, (2.20308N, 40.75271E)
# Kiaga, Kenya, (-0.6N, 37.26667E)
# Kiaguthu, Kenya, (-0.75N, 36.96667E)
# Kiahiti, Kenya, (-0.81667N, 37.03333E)
# Kiahuria, Kenya, (-1.22142N, 36.72311E)
# Kiairathe, Kenya, (-0.66667N, 36.95E)
# Kiakanyinga, Kenya, (-0.25829N, 37.69845E)
# Kiamabara, Kenya, (-0.51667N, 37.11667E)
# Kiamaina, Kenya, (-0.45521N, 37.22003E)
# Kiamara, Kenya, (-0.7N, 37.06667E)
# Kiamariga, Kenya, (-0.38524N, 37.08409E)
# Kiamathambo, Kenya, (-0.41667N, 36.88333E)
# Kiambaa, Kenya, (-1.19929N, 36.65659E)
# Kiambere, Kenya, (-0.6922N, 37.7916E)
# Kiambu, Kenya, (-1.16667N, 36.83333E)
# Kiambururu, Kenya, (-1.05N, 36.81667E)
# Kiambuthia, Kenya, (-0.61667N, 36.91667E)
# Kiamucheru, Kenya, (-0.41667N, 37.11667E)
# Kiamunyaka, Kenya, (-1.5223N, 39.99761E)
# Kiamurathe, Kenya, (-0.58333N, 37.03333E)
# Kiamuringa, Kenya, (-0.56976N, 37.53179E)
# Kiamuthambi, Kenya, (-0.56667N, 37.28333E)
# Kiamutugu, Kenya, (-0.46718N, 37.39053E)
# Kiamuturi, Kenya, (-0.61295N, 36.84395E)
# Kiamuya, Kenya, (-0.56667N, 36.96667E)
# Kiamwangi, Kenya, (-1.02299N, 36.8734E)
# Kiamwathi, Kenya, (-0.45N, 36.95E)
# Kiamwenja, Kenya, (-0.53346N, 37.28699E)
# Kiamwenji, Kenya, (-0.68333N, 37.1E)
# Kiamworia, Kenya, (-1.0N, 36.81667E)
# Kianderi, Kenya, (-0.4709N, 37.28448E)
# Kiandongoro, Kenya, (-0.45N, 36.83333E)
# Kiandu, Kenya, (-0.48871N, 36.96653E)
# Kiandumo, Kenya, (-0.4393N, 37.38269E)
# Kiangai, Kenya, (-0.50651N, 37.16397E)
# Kianganda, Kenya, (-0.55N, 36.95E)
# Kiangararu, Kenya, (-0.48333N, 37.13333E)
# Kiangima, Kenya, (-1.06667N, 36.8E)
# Kiangochi, Kenya, (-0.75N, 37.13333E)
# Kiangoma, Kenya, (-0.78333N, 37.03333E)
# Kianguanyi, Kenya, (-0.44714N, 37.29063E)
# Kiangungi, Kenya, (-0.37285N, 37.57208E)
# Kiangunyi, Kenya, (-0.7N, 36.98333E)
# Kiangwe, Kenya, (-1.93117N, 40.97508E)
# Kianiokoma, Kenya, (-0.4N, 37.5E)
# Kianjai, Kenya, (0.16113N, 37.74706E)
# Kianjege, Kenya, (-0.57507N, 37.16765E)
# Kianjiru, Kenya, (-0.53333N, 37.2E)
# Kianjogu, Kenya, (-1.06667N, 36.8E)
# Kianjuki, Kenya, (-0.44315N, 37.50941E)
# Kianyaga, Kenya, (-0.49546N, 37.35027E)
# Kiaria, Kenya, (-1.09226N, 36.78937E)
# Kiaritha, Kenya, (-0.48333N, 37.26667E)
# Kiarukungu, Kenya, (-0.6565N, 37.35604E)
# Kiarutara, Kenya, (-0.85684N, 36.82489E)
# Kiatineni, Kenya, (-1.5524N, 37.36265E)
# Kiawaithanji, Kenya, (-0.48333N, 36.98333E)
# Kiawambeu, Kenya, (-0.73333N, 37.1E)
# Kiawambogo, Kenya, (-0.67049N, 36.88919E)
# Kiawamurathe, Kenya, (-0.58333N, 37.03333E)
# Kiawamururu, Kenya, (-0.5458N, 37.02258E)
# Kiawanjugu, Kenya, (-0.71667N, 37.11667E)
# Kiawanugu, Kenya, (-1.23333N, 36.71667E)
# Kiawarigi, Kenya, (-0.43333N, 37.1E)
# Kibandaongo, Kenya, (-4.04368N, 39.39743E)
# Kibanguini, Kenya, (-1.0N, 36.96667E)
# Kibaoni, Kenya, (-3.71667N, 39.83333E)
# Kibarani, Kenya, (-3.60481N, 39.8587E)
# Kibauni, Kenya, (-4.53418N, 39.14527E)
# Kibaya, Kenya, (-4.47344N, 39.12313E)
# Kibebetiet, Kenya, (0.40989N, 35.05126E)
# Kibera, Kenya, (-1.31667N, 36.78333E)
# Kibera Kichinjio, Kenya, (-1.13333N, 34.55E)
# Kiberengi, Kenya, (1.44779N, 34.87627E)
# Kibigori, Kenya, (-0.08056N, 35.04694E)
# Kibingo, Kenya, (-0.48333N, 37.25E)
# Kibingor, Kenya, (0.51153N, 35.86773E)
# Kibingoti, Kenya, (-0.56667N, 37.18333E)
# Kibirigwi, Kenya, (-0.52863N, 37.17829E)
# Kibirikani, Kenya, (-2.24585N, 40.77617E)
# Kibiriraini, Kenya, (-1.28333N, 36.68333E)
# Kibogi, Kenya, (-0.41522N, 37.51667E)
# Kiboi, Kenya, (-0.74755N, 36.99216E)
# Kibokoni, Kenya, (-2.51439N, 40.35723E)
# Kibos, Kenya, (-0.07N, 34.81092E)
# Kibugu, Kenya, (-0.44462N, 37.43496E)
# Kibuguni, Kenya, (-4.50117N, 39.35863E)
# Kibugwa, Kenya, (-0.36667N, 37.61667E)
# Kiburu, Kenya, (-0.54154N, 37.20954E)
# Kibusu, Kenya, (-2.35151N, 40.14269E)
# Kibutha, Kenya, (-0.69491N, 36.91766E)
# Kibutio, Kenya, (-0.61196N, 37.0786E)
# Kibwezi, Kenya, (-2.40935N, 37.96631E)
# Kichakasimba, Kenya, (-4.34908N, 39.35914E)
# Kichwa Tembo, Kenya, (-1.24869N, 35.01072E)
# Kidaya, Kenya, (-3.43539N, 38.33961E)
# Kidhanga, Kenya, (-2.50934N, 40.41479E)
# Kidimu, Kenya, (-4.54869N, 39.36772E)
# Kidomaya, Kenya, (-4.56888N, 39.1719E)
# Kidono, Kenya, (-1.25N, 36.7E)
# Kiduruni, Kenya, (-1.89892N, 41.21241E)
# Kidutani, Kenya, (-3.88333N, 39.71667E)
# Kidzumbani, Kenya, (-4.46473N, 39.41593E)
# Kidzumu, Kenya, (-4.2101N, 39.58052E)
# Kieni, Kenya, (-0.8542N, 36.67607E)
# Kifumbu, Kenya, (-3.81667N, 38.65E)
# Kifyonzo, Kenya, (-4.20245N, 39.25037E)
# Kigaa, Kenya, (-1.03333N, 36.85E)
# Kigala, Kenya, (-3.36915N, 38.48828E)
# Kiganjo, Kenya, (-0.88333N, 36.86667E)
# Kigato, Kenya, (-4.18853N, 39.55268E)
# Kigio, Kenya, (-0.94928N, 36.95288E)
# Kigogo-ini, Kenya, (-0.45N, 36.88333E)
# Kigomberu, Kenya, (-4.49394N, 39.34686E)
# Kigombo, Kenya, (-3.38274N, 38.45395E)
# Kigongo, Kenya, (-1.02696N, 36.85494E)
# Kigoro, Kenya, (-0.85538N, 36.89565E)
# Kigumo, Kenya, (-0.8021N, 36.92525E)
# Kihara, Kenya, (-1.21661N, 36.76838E)
# Kiharu, Kenya, (-0.71954N, 37.13987E)
# Kihatha, Kenya, (-0.43094N, 36.89188E)
# Kihingo, Kenya, (-0.42017N, 36.86996E)
# Kihome, Kenya, (-0.52574N, 36.90819E)
# Kihoya, Kenya, (-0.65139N, 36.90402E)
# Kihumbuini, Kenya, (-0.92751N, 36.98803E)
# Kihuri, Kenya, (-0.55873N, 36.85774E)
# Kihuyo, Kenya, (-0.38527N, 36.91384E)
# Kiinu, Kenya, (-0.58421N, 36.89994E)
# Kijabe, Kenya, (-0.93304N, 36.57581E)
# Kijangwani, Kenya, (-3.78333N, 39.83333E)
# Kijinitini, Kenya, (-2.0719N, 41.14247E)
# Kijipwa, Kenya, (-3.83333N, 39.8E)
# Kijiwetanga, Kenya, (-3.25N, 40.08333E)
# Kikambala, Kenya, (-3.89732N, 39.79341E)
# Kikima, Kenya, (-1.66208N, 37.4469E)
# Kikoko, Kenya, (-1.80777N, 37.39582E)
# Kikomani, Kenya, (-2.27233N, 40.9224E)
# Kikomo, Kenya, (-2.49317N, 40.29384E)
# Kikoneni, Kenya, (-4.44766N, 39.30998E)
# Kikoni, Kenya, (-2.24035N, 40.86116E)
# Kikumini, Kenya, (-2.04617N, 37.57621E)
# Kikuu, Kenya, (-1.49404N, 38.31246E)
# Kikuyu, Kenya, (-1.24576N, 36.66328E)
# Kikwezani, Kenya, (-4.66667N, 39.2E)
# Kilaguni, Kenya, (-2.91021N, 38.058928E)
# Kilala, Kenya, (-1.77065N, 37.5543E)
# Kilawa, Kenya, (-2.14073N, 38.08113E)
# Kilelengwani, Kenya, (-2.47474N, 40.46382E)
# Kileleshwa, Kenya, (-1.28333N, 36.78333E)
# Kilema Dui, Kenya, (-1.6N, 39.53333E)
# Kilibasi, Kenya, (-3.97158N, 38.94955E)
# Kilifi, Kenya, (-3.63045N, 39.84992E)
# Kilifi Creek, Kenya, (-3.6281N, 39.85994E)
# Kiligis, Kenya, (-0.16667N, 35.15E)
# Kililani, Kenya, (-2.21886N, 40.90923E)
# Kilima Cha Simba, Kenya, (-2.73117N, 40.16538E)
# Kilimangodo, Kenya, (-4.36299N, 39.07575E)
# Kilkoris, Kenya, (-1.0077N, 34.88062E)
# Kilole, Kenya, (-4.36103N, 39.49948E)
# Kilome, Kenya, (-1.80934N, 37.34742E)
# Kilunguni, Kenya, (-2.50049N, 40.46854E)
# Kilweni, Kenya, (-2.03258N, 41.02496E)
# Kima, Kenya, (-1.95759N, 37.25673E)
# Kimaeti, Kenya, (0.60073N, 34.40829E)
# Kimahuri, Kenya, (-0.29261N, 37.11235E)
# ...
# Pemba, Kenya, (-3.95228N, 39.43373E)
# Pemwai, Kenya, (0.57112N, 35.7704E)
# Penda Kula, Kenya, (-3.38333N, 39.93333E)
# Pendeza, Kenya, (-1.48267N, 40.03397E)
# Pengo, Kenya, (-4.24607N, 39.37228E)
# Peponi, Kenya, (-2.0842N, 40.16424E)
# Perani, Kenya, (-4.52471N, 39.17932E)
# Pingilikani, Kenya, (-3.78344N, 39.7802E)
# Poi, Kenya, (0.74175N, 35.81117E)
# Poka, Kenya, (-2.1438N, 37.4619E)
# Pongwe, Kenya, (-4.56055N, 39.34048E)
# Port Southby, Kenya, (-0.2016N, 34.15412E)
# Port Victoria, Kenya, (0.09388N, 33.97559E)
# Poulton, Kenya, (-0.34718N, 35.62124E)
# Puma, Kenya, (-4.14347N, 39.26036E)
# Pumwani, Kenya, (-1.28333N, 36.85E)
# Punda Milima, Kenya, (-1.91555N, 39.80789E)
# Pundo's Village, Kenya, (-0.78047N, 34.30196E)
# Quarry Road, Kenya, (-1.266671N, 36.874065E)
# Rabai, Kenya, (-4.04767N, 39.66644E)
# Rabour, Kenya, (-0.14958N, 34.8249E)
# Racecourse Road, Kenya, (-1.343985N, 36.837158E)
# Ragati, Kenya, (-0.37988N, 37.14891E)
# Raguta, Kenya, (-0.30602N, 37.64949E)
# Raiyani, Kenya, (-1.08674N, 36.8678E)
# Rakwaro, Kenya, (-0.8N, 34.58333E)
# Ramada, Kenya, (-2.89177N, 40.02767E)
# Rambara, Kenya, (-0.06667N, 34.7E)
# Ramisi, Kenya, (-4.52941N, 39.39529E)
# Ramogi, Kenya, (0.0N, 34.05E)
# Ramu, Kenya, (3.93147N, 41.22295E)
# Ramula, Kenya, (0.00106N, 34.52727E)
# Ranalo, Kenya, (-0.37369N, 34.30736E)
# Randani, Kenya, (-1.66667N, 38.56667E)
# Rangala, Kenya, (0.15036N, 34.33187E)
# Rapogi, Kenya, (-0.90807N, 34.47302E)
# Raromombasa, Kenya, (-2.98417N, 39.96982E)
# Rasi, Kenya, (-2.99815N, 40.22022E)
# Ratai, Kenya, (-0.4N, 37.16667E)
# Reketa, Kenya, (-2.43634N, 40.39082E)
# Renguti, Kenya, (-1.22648N, 36.61538E)
# Rhamu Dimtu, Kenya, (4.01873N, 41.06355E)
# Rhoka, Kenya, (-1.27422N, 40.00861E)
# Ria Kalui, Kenya, (-3.95624N, 39.24096E)
# Riabai, Kenya, (-1.16196N, 36.84339E)
# Riakiania, Kenya, (-0.51994N, 37.21314E)
# Riamukurwe, Kenya, (-0.45N, 36.96667E)
# Riana, Kenya, (-0.65575N, 34.66833E)
# Ribe, Kenya, (-3.88536N, 39.63298E)
# Rigmio, Kenya, (-1.15N, 41.01667E)
# Riondonga, Kenya, (-0.75062N, 34.8492E)
# Rironi, Kenya, (-1.15116N, 36.63555E)
# Riruta, Kenya, (-1.28333N, 36.73333E)
# Ritho, Kenya, (-0.96592N, 36.85682E)
# Rititi, Kenya, (-0.44959N, 37.07858E)
# Riuki, Kenya, (-1.10081N, 36.81922E)
# Roka, Kenya, (-1.6N, 39.2E)
# Rombo, Kenya, (-3.04631N, 37.69539E)
# Rongai, Kenya, (-0.17333N, 35.86382E)
# Rongo, Kenya, (-0.7555N, 34.5814E)
# Ruaka, Kenya, (-1.2N, 36.78333E)
# Ruambiti, Kenya, (-0.52685N, 37.3539E)
# Ruanganga, Kenya, (-0.83769N, 37.0927E)
# Ruangondu, Kenya, (-0.48333N, 37.3E)
# Rubu, Kenya, (-1.8757N, 41.3852E)
# Ruchu, Kenya, (-0.9N, 36.98333E)
# Rudacha, Kenya, (0.11667N, 33.98333E)
# Rugumu, Kenya, (-0.39953N, 37.44884E)
# Ruiru, Kenya, (-1.14665N, 36.96087E)
# Rukala, Kenya, (0.06667N, 34.0E)
# Rukanga, Kenya, (-3.81251N, 38.63892E)
# Rukenya, Kenya, (-0.53991N, 37.33916E)
# Rukira, Kenya, (-0.53722N, 36.93664E)
# Ruku, Kenya, (-1.20725N, 36.70759E)
# Rukubi, Kenya, (-1.23333N, 36.7E)
# Rukuriri, Kenya, (-0.37702N, 37.54704E)
# Rumuruti, Kenya, (0.26699N, 36.53886E)
# Rungiri, Kenya, (-1.24465N, 36.67569E)
# Rurii, Kenya, (-0.7N, 37.18333E)
# Ruringu, Kenya, (-0.43056N, 36.98046E)
# Ruruma, Kenya, (-3.9N, 39.6E)
# Rurunguti, Kenya, (-0.56467N, 36.89316E)
# Rutara, Kenya, (-0.26667N, 36.25E)
# Ruthagati, Kenya, (-0.43333N, 37.06667E)
# Rutura, Kenya, (-0.42049N, 36.89113E)
# Rwamburi Kiugu, Kenya, (-1.11667N, 36.58333E)
# Rwambwa, Kenya, (0.11486N, 34.09343E)
# Rwathia, Kenya, (-0.65613N, 36.9101E)
# Rwegetha, Kenya, (-0.91667N, 36.91667E)
# Saadani, Kenya, (-1.9526N, 41.12454E)
# Sabare, Kenya, (-2.06114N, 39.31733E)
# Sabule, Kenya, (0.31194N, 40.19972E)
# Sadani, Kenya, (-4.4527N, 39.32576E)
# Safarisi, Kenya, (-2.20463N, 40.80847E)
# Sagala, Kenya, (-3.50957N, 38.57623E)
# Sagana, Kenya, (-0.66667N, 37.2E)
# Saidibabo, Kenya, (-2.52302N, 40.34212E)
# Sailoni, Kenya, (-2.14924N, 40.18394E)
# Saint Marys, Kenya, (-0.71667N, 37.13333E)
# Saka, Kenya, (-0.14035N, 39.32805E)
# Sakutiek, Kenya, (-0.84887N, 36.14776E)
# Salabani, Kenya, (0.55377N, 36.04941E)
# Samburu, Kenya, (0.63445N, 37.45239E)
# Samicha, Kenya, (-2.51048N, 40.3235E)
# Samikaro, Kenya, (-2.50032N, 40.2941E)
# Samsons Corner, Kenya, (-0.55591N, 37.37043E)
# Samuli, Kenya, (-2.12413N, 37.42715E)
# Sandai, Kenya, (0.40343N, 36.07485E)
# Sang'alo, Kenya, (0.35113N, 35.04991E)
# Sangoleaku, Kenya, (-0.55N, 40.86667E)
# Sarbuye, Kenya, (-2.18333N, 39.9E)
# Sardho, Kenya, (-0.02538N, 40.13556E)
# Sare, Kenya, (-0.9059N, 34.53367E)
# Sarif, Kenya, (0.59431N, 40.59952E)
# Sarim, Kenya, (-0.38333N, 40.96667E)
# Sasak, Kenya, (2.34132N, 34.98081E)
# Sasuri, Kenya, (0.82044N, 34.48748E)
# Sawa Sawa, Kenya, (-4.47166N, 39.48463E)
# Sebit, Kenya, (1.39431N, 35.33816E)
# Secho, Kenya, (-3.49118N, 38.33571E)
# Sega, Kenya, (0.25583N, 34.22583E)
# Selengai, Kenya, (-2.18173N, 37.16554E)
# Sena, Kenya, (-0.47263N, 34.06805E)
# Sera, Kenya, (-2.12766N, 40.12689E)
# Serem, Kenya, (0.0833N, 34.85E)
# Seretunin, Kenya, (0.5535N, 35.78824E)
# Sericho, Kenya, (1.14495N, 39.08681E)
# Serkonghun, Kenya, (0.60063N, 35.76809E)
# Sesia, Kenya, (0.5N, 35.81667E)
# Seyabei, Kenya, (-1.09071N, 35.95128E)
# Shabaltaragwa, Kenya, (-0.5575N, 35.79035E)
# Shakadulo, Kenya, (-3.05811N, 39.85644E)
# Shamakhokho, Kenya, (0.11094N, 34.83074E)
# Shambini, Kenya, (-4.04961N, 39.17526E)
# Shambweni, Kenya, (-3.40578N, 39.61316E)
# Shamenei, Kenya, (0.0509N, 36.28108E)
# Shamenek, Kenya, (0.10857N, 36.31216E)
# Shanga, Kenya, (-2.12778N, 41.06815E)
# Shanzu, Kenya, (-3.96667N, 39.75E)
# Shartuka, Kenya, (-0.96667N, 34.95E)
# Shauri Moyo, Kenya, (-1.278317N, 36.853661E)
# Sheikh bin Dam, Kenya, (-1.85042N, 40.22635E)
# Shela, Kenya, (-2.29292N, 40.91415E)
# Shelemba, Kenya, (-3.43734N, 38.4611E)
# Shigaro, Kenya, (-3.40452N, 38.36608E)
# Shikusa, Kenya, (0.32141N, 34.81349E)
# Shimba Hills, Kenya, (-4.36272N, 39.41546E)
# Shimo la Tewa, Kenya, (-3.95545N, 39.73799E)
# Shimoni, Kenya, (-4.64756N, 39.38175E)
# Shirazi, Kenya, (-4.52942N, 39.42262E)
# Shirikisho, Kenya, (-2.35009N, 40.12709E)
# Shirotsa, Kenya, (0.23449N, 34.57498E)
# Shompole, Kenya, (-2.00311N, 36.03756E)
# Siakago, Kenya, (-0.58333N, 37.63333E)
# Siamufua, Kenya, (0.10746N, 34.07693E)
# Siaya, Kenya, (0.06116N, 34.28823E)
# Sibillo, Kenya, (0.70208N, 35.8988E)
# Sichei, Kenya, (0.71563N, 34.60604E)
# Sidindi, Kenya, (0.15417N, 34.38944E)
# Sigalagala, Kenya, (0.19599N, 34.76059E)
# Sigio, Kenya, (-1.2N, 36.6E)
# Sigomere, Kenya, (0.20032N, 34.35865E)
# Sigor, Kenya, (-0.91667N, 35.3E)
# Sikoma, Kenya, (0.41667N, 34.2E)
# Silaloni, Kenya, (-3.61692N, 39.28692E)
# Simambaya, Kenya, (-1.88576N, 41.37235E)
# Simandaro, Kenya, (-2.17992N, 40.87303E)
# Simba, Kenya, (-2.15792N, 37.59166E)
# Simisi, Kenya, (-2.0N, 38.33333E)
# Sindo, Kenya, (-0.54061N, 34.16891E)
# Singore, Kenya, (0.71365N, 35.51762E)
# Sinoia, Kenya, (-3.16667N, 40.1E)
# Sintagara, Kenya, (-0.99514N, 36.13805E)
# Sio Port, Kenya, (0.22182N, 34.02263E)
# Siongiroi, Kenya, (-0.91667N, 35.21667E)
# Siranga, Kenya, (0.18333N, 34.21667E)
# Siriba, Kenya, (0.0N, 34.6E)
# Sirisia, Kenya, (0.11667N, 34.0E)
# Sisenye, Kenya, (0.15N, 33.98333E)
# Sitaman, Kenya, (1.06667N, 35.25E)
# Siyu, Kenya, (-2.1038N, 41.06064E)
# Skwata, Kenya, (-1.88333N, 38.41667E)
# Sokoke, Kenya, (-3.54078N, 39.81095E)
# Solian, Kenya, (-0.00356N, 35.75689E)
# Sololo, Kenya, (3.56392N, 38.64321E)
# Sombe, Kenya, (-1.45071N, 38.23494E)
# Sondu, Kenya, (-0.39101N, 35.01689E)
# Songa, Kenya, (2.23937N, 38.0104E)
# Songeni, Kenya, (-1.56527N, 37.49203E)
# Sorget, Kenya, (-0.04421N, 35.53483E)
# Sori, Kenya, (-0.8409N, 34.15978E)
# Sosiot, Kenya, (-0.36305N, 35.17179E)
# Sosoni, Kenya, (-2.99205N, 40.05383E)
# Sotik, Kenya, (-0.68333N, 35.11871E)
# South Horr, Kenya, (2.09773N, 36.91851E)
# South Kinangop, Kenya, (-0.7264N, 36.65258E)
# Soy, Kenya, (0.67315N, 35.15771E)
# Spring Valley, Kenya, (-1.253991N, 36.790491E)
# Stesheni, Kenya, (-1.96026N, 41.31516E)
# Suba Kuria, Kenya, (-1.16615N, 34.44523E)
# Subuku, Kenya, (0.1515N, 36.36951E)
# Sukuta Lol Marmar, Kenya, (0.82772N, 36.68979E)
# Sultan Hamud, Kenya, (-2.02042N, 37.37212E)
# Sumai, Kenya, (-1.53333N, 39.31667E)
# Sumat, Kenya, (-1.13333N, 40.06667E)
# Suna, Kenya, (-1.09639N, 34.45421E)
# Sungululu, Kenya, (-3.38882N, 38.35774E)
# Syolima, Kenya, (-1.43333N, 38.08333E)
# Syumbungu, Kenya, (-0.9N, 38.5E)
# Takaba, Kenya, (3.35528N, 40.22278E)
# Takaungu, Kenya, (-3.68367N, 39.85662E)
# Takwa Milinga, Kenya, (-2.29833N, 40.95826E)
# Talai, Kenya, (0.58331N, 35.81277E)
# Talau, Kenya, (1.20312N, 35.12136E)
# Talek, Kenya, (-1.44017N, 35.2135E)
# Talio, Kenya, (-3.53333N, 38.58333E)
# Taloa, Kenya, (-0.35842N, 35.55402E)
# Tamanak, Kenya, (2.66446N, 34.98585E)
# Tambach, Kenya, (0.59169N, 35.5236E)
# Tambaya, Kenya, (-0.52846N, 37.0202E)
# Tamu, Kenya, (-0.10098N, 35.20242E)
# Tana Power Station, Kenya, (-2.52617N, 40.51766E)
# Tandare, Kenya, (0.38133N, 36.29333E)
# Tangulbei, Kenya, (0.8019N, 36.28714E)
# Tarasaa, Kenya, (-2.44188N, 40.17075E)
# Tarbaj, Kenya, (2.2085N, 40.11812E)
# Taru, Kenya, (-3.73634N, 39.15276E)
# Taveta, Kenya, (-3.39879N, 37.68336E)
# Tawa, Kenya, (-1.55542N, 37.46134E)
# Teso, Kenya, (-1.3N, 39.66667E)
# Tezo, Kenya, (-3.5346N, 39.85322E)
# Thaara, Kenya, (-0.79922N, 37.2158E)
# Thagare, Kenya, (-0.83333N, 37.0E)
# Thaita, Kenya, (-0.45439N, 37.26868E)
# Thakwa, Kenya, (-1.06667N, 36.76667E)
# Thamara, Kenya, (-0.83333N, 37.06667E)
# Thangata, Kenya, (-0.2N, 38.31667E)
# Thangathe, Kenya, (-0.5665N, 37.1298E)
# Thange, Kenya, (-2.49302N, 38.01508E)
# Thangi, Kenya, (-2.47324N, 38.04561E)
# Thanju, Kenya, (-0.68333N, 37.23333E)
# Thanu, Kenya, (-0.63333N, 37.11667E)
# Thengeini, Kenya, (-0.51667N, 37.15E)
# Theri, Kenya, (-0.71667N, 36.93333E)
# Thiba, Kenya, (-0.69215N, 37.34024E)
# Thigio, Kenya, (-1.20264N, 36.59673E)
# Thiguku, Kenya, (-0.55N, 37.23333E)
# Thika, Kenya, (-1.03326N, 37.06933E)
# Thika Valley, Kenya, (-0.8N, 36.81667E)
# Thimbigua, Kenya, (-1.18333N, 36.76667E)
# Thogoto, Kenya, (-1.2743N, 36.67474E)
# Thomsons Falls, Kenya, (0.044358N, 36.369458E)
# Thuita, Kenya, (-0.61475N, 37.04862E)
# Thunguma, Kenya, (-0.43747N, 36.98906E)
# Thunguri, Kenya, (-0.56667N, 37.05E)
# Thuthuriki, Kenya, (-0.06667N, 36.76667E)
# Thuva, Kenya, (-3.58333N, 39.7E)
# Tiekunu, Kenya, (-1.11949N, 36.59602E)
# Til Tila, Kenya, (-1.01289N, 39.28672E)
# Timau, Kenya, (0.08904N, 37.24137E)
# Timbila, Kenya, (-3.37061N, 37.71116E)
# Timboiwo, Kenya, (0.42314N, 35.79771E)
# Timboroa, Kenya, (0.0855N, 35.53021E)
# Tindini, Kenya, (-3.64759N, 39.46442E)
# Tinganga, Kenya, (-1.13033N, 36.81358E)
# Tiribe, Kenya, (-4.31949N, 39.25494E)
# Tirimionin, Kenya, (0.65841N, 35.81926E)
# Tiriondonin, Kenya, (0.64724N, 35.76623E)
# Titila, Kenya, (-1.53333N, 39.21667E)
# Tiva, Kenya, (-1.42583N, 37.88113E)
# Tiwi, Kenya, (-4.23934N, 39.57638E)
# Toi, Kenya, (0.60166N, 37.24464E)
# Tokitok, Kenya, (-0.55N, 35.71667E)
# Torikoi, Kenya, (2.40821N, 34.96283E)
# Toritu, Kenya, (-1.16667N, 36.8E)
# Toroveni, Kenya, (-2.97997N, 40.00713E)
# Tot, Kenya, (1.20098N, 35.65754E)
# Township, Kenya, (0.28795N, 34.75019E)
# Tsangalaweni, Kenya, (-3.52167N, 39.70173E)
# Tsangatsini, Kenya, (-3.71089N, 39.45215E)
# Tsavo, Kenya, (-2.982778N, 38.466634E)
# Tserezani, Kenya, (-4.22545N, 39.36804E)
# Tsunguni, Kenya, (-3.81499N, 39.66173E)
# Tukeli, Kenya, (-1.06667N, 40.86667E)
# Tula, Kenya, (-0.8478N, 39.69976E)
# Tulia, Kenya, (-1.1858N, 37.97774E)
# Tulu, Kenya, (-2.2747N, 40.09454E)
# Tumeiyo, Kenya, (0.22814N, 35.53101E)
# Tungu, Kenya, (-0.31375N, 37.62921E)
# Tuni, Kenya, (-1.00645N, 39.89318E)
# Tura, Kenya, (0.53189N, 37.03521E)
# Turasha, Kenya, (-0.47174N, 36.44452E)
# Turbi, Kenya, (3.3N, 38.37656E)
# Turbo, Kenya, (0.63367N, 35.04815E)
# Turi, Kenya, (-0.27922N, 35.76118E)
# Tusha, Kenya, (-0.47177N, 36.82437E)
# Tuthu, Kenya, (-0.66814N, 36.83819E)
# Tuum, Kenya, (2.14752N, 36.77517E)
# Twaandu, Kenya, (-2.14329N, 37.76767E)
# Uholo, Kenya, (0.18889N, 34.33417E)
# Ukunda, Kenya, (-4.2929N, 39.56404E)
# Ukwala, Kenya, (0.19039N, 34.18908E)
# Ulro, Kenya, (-0.84378N, 34.28265E)
# Ulu, Kenya, (-1.81222N, 37.15048E)
# Umbui, Kenya, (-0.61991N, 36.94138E)
# Umoja, Kenya, (-1.41476N, 39.99481E)
# Unjiru, Kenya, (-0.45193N, 37.11212E)
# Unkuno, Kenya, (-2.05355N, 39.46227E)
# Unkuria, Kenya, (-2.07331N, 39.52096E)
# Uplands, Kenya, (-1.024841N, 36.60256E)
# Upper Gilgil, Kenya, (-0.21209N, 36.27248E)
# Uranga, Kenya, (0.11667N, 34.15E)
# Urumathi, Kenya, (-1.05N, 36.83333E)
# Usenge, Kenya, (-0.06731N, 34.0566E)
# Ushingo, Kenya, (-2.76667N, 39.66667E)
# Usire, Kenya, (-0.05771N, 34.22289E)
# Usueni, Kenya, (-0.15576N, 38.20186E)
# Utajo, Kenya, (-0.38017N, 34.21368E)
# Utange, Kenya, (-3.97578N, 39.71891E)
# Utangwa, Kenya, (-1.70775N, 37.44702E)
# Uthiru, Kenya, (-1.25392N, 36.71233E)
# Utithi, Kenya, (-2.53893N, 37.99697E)
# Uvete, Kenya, (-1.85422N, 37.35095E)
# Uwai, Kenya, (0.23974N, 34.16791E)
# Uyombo, Kenya, (-3.39007N, 39.9627E)
# Vaji, Kenya, (-1.29726N, 39.81375E)
# Vanga, Kenya, (-4.65948N, 39.21847E)
# Viangwani, Kenya, (-4.14922N, 39.49333E)
# Vidungeni, Kenya, (-4.45743N, 39.45287E)
# Vifanjoni, Kenya, (-3.94366N, 39.64258E)
# Vigurungani, Kenya, (-4.04032N, 39.1635E)
# Vihiga Town, Kenya, (0.05N, 34.725E)
# Vikinduni, Kenya, (-4.25746N, 39.14288E)
# Vingujini, Kenya, (-4.4648N, 39.48306E)
# Vinuni, Kenya, (-4.19506N, 39.53946E)
# Vipingo, Kenya, (-3.81714N, 39.80878E)
# Viragoni, Kenya, (-3.7N, 39.53333E)
# Vitengeni, Kenya, (-3.36109N, 39.71125E)
# Vitsangalaweni, Kenya, (-4.44117N, 39.19108E)
# Vivini, Kenya, (-4.46387N, 39.34996E)
# Voi, Kenya, (-3.39605N, 38.55609E)
# Voo, Kenya, (-1.66736N, 38.32429E)
# Vuga, Kenya, (-4.18884N, 39.49816E)
# Vulueni, Kenya, (-1.98144N, 37.40989E)
# Vumoni, Kenya, (-4.21048N, 39.55678E)
# Waa, Kenya, (-4.16994N, 39.60279E)
# Wabuga, Kenya, (-1.23333N, 36.71667E)
# Wachakone, Kenya, (-1.44705N, 40.02574E)
# Waguthu, Kenya, (-1.1891N, 36.79329E)
# Waita, Kenya, (-0.7798N, 38.09727E)
# Waithaka, Kenya, (-1.28333N, 36.71667E)
# Wajir, Kenya, (1.7471N, 40.05732E)
# Walanga, Kenya, (0.83333N, 34.41667E)
# Walu, Kenya, (-1.7N, 40.13333E)
# Wamachatha, Kenya, (-0.56667N, 37.01667E)
# Wamagana, Kenya, (-0.47612N, 36.93057E)
# Wamba, Kenya, (0.98333N, 37.31667E)
# Wamitaa, Kenya, (-1.05N, 36.91667E)
# Wamono, Kenya, (0.79056N, 34.43444E)
# Wamumu, Kenya, (-0.75161N, 37.31723E)
# Wamutitu, Kenya, (-0.55N, 37.03333E)
# Wamwangi, Kenya, (-1.00391N, 36.91971E)
# Wandimi, Kenya, (-1.0N, 36.75E)
# Wandumbi, Kenya, (-0.47006N, 36.88248E)
# Wangai, Kenya, (-0.89687N, 37.07121E)
# Wange, Kenya, (-1.99824N, 40.92191E)
# Wangoma, Kenya, (0.76667N, 34.45E)
# Wanjengi, Kenya, (-0.71933N, 36.9824E)
# Wanjereri, Kenya, (-0.65N, 36.85E)
# Wanjii, Kenya, (-0.75N, 37.16667E)
# Wanyaga, Kenya, (-1.23333N, 36.55E)
# War Dirsame, Kenya, (0.77168N, 40.93678E)
# Warable, Kenya, (-0.66667N, 39.8E)
# Waragalla, Kenya, (3.40951N, 41.00899E)
# Waratho, Kenya, (-1.11667N, 36.78333E)
# Waresa, Kenya, (-2.76977N, 39.99463E)
# Wariva, Kenya, (1.03333N, 34.56667E)
# Wasini, Kenya, (-4.65855N, 39.36621E)
# Wasis, Kenya, (-0.55N, 34.73333E)
# Watamu, Kenya, (-3.35429N, 40.02086E)
# Watara, Kenya, (-2.92766N, 39.93233E)
# Waterer, Kenya, (-0.38936N, 35.64854E)
# Wathorego, Kenya, (-0.04998N, 34.79881E)
# Wautu, Kenya, (-1.86224N, 37.40543E)
# Wayu, Kenya, (-1.55229N, 39.55169E)
# Wayu Boro, Kenya, (-1.52534N, 39.54681E)
# Webuye, Kenya, (0.60751N, 34.76966E)
# Welaluit Dardesa, Kenya, (-0.93333N, 40.9E)
# Wema, Kenya, (-2.21062N, 40.17903E)
# Wenje, Kenya, (-1.79264N, 40.11102E)
# Weno, Kenya, (-0.55617N, 34.44796E)
# Weru, Kenya, (-0.36718N, 37.71942E)
# Weruga, Kenya, (-3.38537N, 38.33671E)
# Westlands, Kenya, (-1.26667N, 36.8E)
# Wesu, Kenya, (-3.40831N, 38.34044E)
# Wetima One, Kenya, (-0.55N, 36.98333E)
# Wetima Two, Kenya, (-0.55N, 36.96667E)
# Wishipon, Kenya, (-0.56554N, 36.49889E)
# Witu, Kenya, (-2.38886N, 40.43821E)
# Wmingo, Kenya, (-3.36667N, 38.33333E)
# Woldena, Kenya, (-1.61154N, 39.02743E)
# Wongonyi, Kenya, (-3.31637N, 38.43355E)
# Wote, Kenya, (-1.78079N, 37.62882E)
# Wumari, Kenya, (-3.47774N, 38.32538E)
# Wumingu, Kenya, (-3.35604N, 38.32517E)
# Wundanyi, Kenya, (-3.40193N, 38.36402E)
# Yaka, Kenya, (-1.55N, 39.38333E)
# Yala, Kenya, (0.09906N, 34.53757E)
# Yale, Kenya, (-3.40591N, 38.32399E)
# Yamogo, Kenya, (-1.2N, 36.76667E)
# Yamugwe, Kenya, (-0.76461N, 37.04295E)
# Yatya, Kenya, (0.78735N, 35.92206E)
# Yava, Kenya, (-4.0948N, 39.37214E)
# Yedi, Kenya, (-1.03333N, 39.88333E)
# Yerei, Kenya, (-1.84714N, 40.36707E)
# Yimbo East, Kenya, (0.003N, 34.16999E)
# Zacharia, Kenya, (-0.63333N, 34.83333E)
# Zaikone, Kenya, (-1.46667N, 37.31667E)
# Zaina, Kenya, (-0.42704N, 36.82717E)
# Zare, Kenya, (-3.49261N, 38.32502E)
# Ziwani, Kenya, (-3.38267N, 37.79346E)

# %%
# The location name can be selected from the list returned by print_locations()
# All locations are listed in the file show_forecasts/shapes/locations.py
#   For the case of the same name in different countries, the country can optionally
#   be selected from 'Kenya', 'South Sudan', 'Rwanda', 'Burundi', 'Djibouti',
#   'Eritrea', 'Ethiopia', 'Sudan', 'Somalia', 'Tanzania', 'Uganda'.
# Be carefull. Sometimes there are a few places with the same name.
plot_GAN_local_histograms(data, 'Kirkos', country='Ethiopia', plot_units='mm/6h')

# %%
# Or if you want to specify the latitude and longitude, you can call the location what you like
plot_GAN_local_histograms(data, 'Indian Ocean', latitude=-2.75, longitude=45.35, plot_units='mm/6h')

# %%
# !jupyter nbconvert --to html test_GAN_forecast.ipynb
