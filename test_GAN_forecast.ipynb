# %%
# Demo script to load and plot cGAN forecast data.
import os
from datetime import datetime

# These are the functions that you can use:
from show_forecasts.show_cGAN import (
    load_GAN_forecast,
    plot_GAN_forecast,
    plot_GAN_ensemble,
)    
from show_forecasts.show_cGAN import (
    plot_GAN_threshold_chance,
    plot_GAN_local_histograms,
    plot_location_marker,
)
from show_forecasts.show_cGAN import sort_along_ensemble_axis, plot_GAN_exceedance
from show_forecasts.show_cGAN import load_GAN_forecast, plot_GAN_forecast, plot_GAN_ensemble
from show_forecasts.show_cGAN import plot_GAN_threshold_chance, plot_GAN_local_histograms, plot_location_marker
from show_forecasts.show_cGAN import sort_along_ensemble_axis, plot_GAN_exceedance
from show_forecasts.data_utils import print_locations

# %%
from show_forecasts.data_utils import load_env_file

load_env_file()

mask_region = os.getenv("MASK_REGION", None)
use_ui_fs = os.getenv("USE_UI_FS", "")
cgan_ui_fs = True if use_ui_fs.lower() in ["t", "true", "y", "yes", "1"] else False
data_dir = os.environ["GAN_DATA_DIR"]

print("Mask Region: ", mask_region)
print("Data Dir: ", data_dir)
# Out:
# WARNING: .env file does not exist. Skipping loading of environment variables.
# Mask Region:  None
# Data Dir:  /home/jason/.docker-data/cgan-store/cgan

# %%
# The date that the forecast was initialised
forecast_init_date = datetime(year=2024, month=6, day=12)
# Pick today instead:
# forecast_init_date = datetime.now()
loader_args = {
    "forecast_init_date": forecast_init_date,
    "data_dir": data_dir,
    "cgan_ui_fs": cgan_ui_fs,
}

if mask_region is not None:
    loader_args.update({"mask_region": mask_region})

# %%
# Load the GAN forecast
data = load_GAN_forecast(**loader_args)
# Out:
# /home/jason/.pyenv/versions/show-cgan/lib/python3.13/site-packages/gribapi/__init__.py:23: UserWarning: ecCodes 2.38.0 or higher is recommended. You are running version 2.33.0
#   warnings.warn(

# %%
# Plot the GAN forecast
plot_GAN_forecast(data, style="KMD", region=mask_region)

# %%
# Plot just one time: Options are 6, 12, 18, 0 or 'all'.
# style options: None (default), 'ICPAC', 'ICPAC_heavy', 'KMD', 'EMI', 'EMI_heavy'
# plot_units can be 'mm/h' (default), 'mm/6h', 'mm/day' or 'mm/week'
# region can be 'ICPAC', 'Kenya', 'South Sudan', 'Rwanda', 'Burundi', 'Djibouti',
#               'Eritrea', 'Ethiopia', 'Sudan', 'Somalia', 'Tanzania', 'Uganda'
# A file name can be specified using file_name="my_file.pdf". File types can be
#               png, jpg or pdf.
plot_GAN_forecast(
    data,
    valid_time_start_hour="12",
    style="KMD",
    plot_units="mm/6h",
    region=mask_region,
)

# %%
# Plot the rainfall over 24 hours
plot_GAN_forecast(
    data, accumulation_time="24h", style="KMD", plot_units="mm/h", region=mask_region
)

# %%
# Plot the full ensemble
#   valid_time_start_hour=6 - The hour the valid time starts at. Can either be 6, 12, 18 or 0 UTC.
#   max_num_plots=50        - Maximum number of ensemble members to plot.
plot_GAN_ensemble(
    data,
    valid_time_start_hour=18,
    style="KMD",
    plot_units="mm/6h",
    region="Kenya",
    max_num_plots=15,
)

# %%
# Plot the chance of rainfall at a rate above a specified threshold.
#   threshold=2             - We'll plot the chance of rainfall above this threshold rate. The
#                             default is 2 mm/h. The units of threshold is set by plot_units.
#   plot_units='mm/h'       - Can be 'mm/h' (default), 'mm/6h', 'mm/day' or 'mm/week'
#   valid_time_start_hour=6 - The hour the valid time starts at. Can either be 6, 12, 18 or 0 UTC or 'all'.
#   style=None              - Can be 'ICPAC', 'KMD', 'EMI' or the default.
plot_GAN_threshold_chance(
    data,
    threshold=5,
    plot_units="mm/6h",
    valid_time_start_hour="all",
    style="KMD",
    show_percentages=False,
    region="Kenya",
)

# %%
plot_GAN_threshold_chance(
    data,
    threshold=2,
    plot_units="mm/6h",
    valid_time_start_hour="0",
    show_percentages=False,
    region=mask_region,
)

# %%
# Prints the named locations available for making histograms
# All locations are listed in the file show_forecasts/shapes/locations.py
#   Optionally restrict the country to one of 'Kenya', 'South Sudan', 'Rwanda',
#   'Burundi', 'Djibouti', 'Eritrea', 'Ethiopia', 'Sudan', 'Somalia',
#   'Tanzania', 'Uganda'
print_locations(country=mask_region)
# Out:
# Akimpama, Burundi, (-3.3845N, 30.465E)
# Bahanza, Burundi, (-3.01859N, 30.13689E)
# Bahizi, Burundi, (-2.5335N, 30.2277E)
# Bakashi, Burundi, (-3.6157N, 29.8296E)
# Bake, Burundi, (-3.5318N, 30.1729E)
# Bamba, Burundi, (-3.9359N, 29.7648E)
# Bambo, Burundi, (-2.9047N, 29.26E)
# Bambu, Burundi, (-2.8673N, 29.2207E)
# Banda, Burundi, (-2.6497N, 30.3192E)
# Bandaga, Burundi, (-3.0677N, 29.5941E)
# Bandage, Burundi, (-4.115N, 29.5927E)
# Bandaguro, Burundi, (-3.5748N, 29.8987E)
# Banga, Burundi, (-3.1334N, 29.6444E)
# Bangwe, Burundi, (-4.3227N, 29.5957E)
# Banza, Burundi, (-3.8152N, 29.6999E)
# Barega, Burundi, (-3.9754N, 29.9422E)
# Bareremba, Burundi, (-4.0498N, 30.108E)
# Bariro, Burundi, (-3.7079N, 30.2539E)
# Bariza, Burundi, (-3.5767N, 29.6177E)
# Bartye, Burundi, (-3.9623N, 29.8245E)
# Basaro, Burundi, (-2.5718N, 30.3575E)
# Batamba, Burundi, (-3.7828N, 30.1936E)
# Batsimba, Burundi, (-3.684N, 30.214E)
# Bavumu, Burundi, (-2.7937N, 30.2294E)
# Bayaga, Burundi, (-3.7442N, 30.2181E)
# Bayumbu, Burundi, (-3.7033N, 30.1947E)
# Baziro, Burundi, (-3.5473N, 29.8575E)
# Benga, Burundi, (-2.8859N, 29.6648E)
# Benja, Burundi, (-3.5306N, 29.7742E)
# Bibara, Burundi, (-3.17N, 30.3087E)
# Bibare, Burundi, (-3.3419N, 29.4874E)
# Bibate, Burundi, (-3.7123N, 29.8511E)
# Bibuye, Burundi, (-3.5667N, 29.5542E)
# Biduda, Burundi, (-2.5105N, 30.0517E)
# Bidumu, Burundi, (-2.9524N, 29.7615E)
# Bigabiro, Burundi, (-3.4525N, 30.1487E)
# Bigamba, Burundi, (-3.8685N, 29.8722E)
# Biganda, Burundi, (-3.2507N, 29.6256E)
# Bigarama, Burundi, (-3.2181N, 30.807E)
# Bigaza, Burundi, (-3.4502N, 29.7364E)
# Bigenama, Burundi, (-3.2632N, 30.777E)
# Bigera, Burundi, (-2.5772N, 30.3534E)
# Bigeri, Burundi, (-2.8288N, 29.3206E)
# Bigikura, Burundi, (-3.4665N, 30.2119E)
# Bigina, Burundi, (-3.9867N, 29.9576E)
# Bigoma, Burundi, (-3.3967N, 29.4254E)
# Bigombo, Burundi, (-3.3354N, 30.473E)
# Bigondo, Burundi, (-3.1704N, 30.7941E)
# Bigoti, Burundi, (-3.83889N, 29.52917E)
# Bigugo, Burundi, (-3.0084N, 29.722E)
# Bigwana, Burundi, (-3.2411N, 29.7407E)
# Bihahe, Burundi, (-3.677N, 29.9078E)
# Bihanga, Burundi, (-3.7824N, 29.6409E)
# Bihangare, Burundi, (-2.7036N, 29.9641E)
# Bihari, Burundi, (-3.8407N, 29.6853E)
# Bihemba, Burundi, (-2.8534N, 29.7133E)
# Bihembe, Burundi, (-2.9246N, 29.3521E)
# Bihera, Burundi, (-3.4281N, 30.0861E)
# Biherwa, Burundi, (-3.2125N, 30.0099E)
# Bihindi, Burundi, (-3.7105N, 29.4297E)
# Bihinge, Burundi, (-3.686N, 29.4055E)
# Bihogana, Burundi, (-3.12348N, 30.03007E)
# Bihoge, Burundi, (-3.26833N, 30.56833E)
# Bihogo, Burundi, (-3.26446N, 30.56138E)
# Bihomvora, Burundi, (-3.5869N, 29.7799E)
# Bihororo, Burundi, (-3.2743N, 29.648E)
# Bihunge, Burundi, (-3.1102N, 29.5915E)
# Bijo, Burundi, (-3.6867N, 29.9702E)
# Bikanka, Burundi, (-3.5477N, 29.5627E)
# Bikinga, Burundi, (-2.9237N, 30.0361E)
# Bikingi, Burundi, (-3.5525N, 29.8348E)
# Bikobe, Burundi, (-4.3468N, 29.799E)
# Binyuro, Burundi, (-4.0547N, 29.623E)
# Binzagara, Burundi, (-4.165N, 29.7536E)
# Birambi, Burundi, (-2.8919N, 30.0999E)
# Biravumu, Burundi, (-2.606N, 30.1261E)
# Birayi, Burundi, (-3.5661N, 29.4407E)
# Biriba, Burundi, (-2.5736N, 30.4593E)
# Birimba, Burundi, (-3.9808N, 29.4626E)
# Birohe, Burundi, (-3.4341N, 29.9581E)
# Birongozi, Burundi, (-3.9147N, 29.9899E)
# Bisaka, Burundi, (-3.8187N, 29.3853E)
# Bisenga, Burundi, (-3.5771N, 30.1573E)
# Bisha, Burundi, (-3.5142N, 29.6948E)
# Bishikuzi, Burundi, (-3.4767N, 30.1213E)
# Bishuri, Burundi, (-3.1974N, 29.7515E)
# Bisibe, Burundi, (-2.8969N, 30.3436E)
# Bisigo, Burundi, (-2.6809N, 29.983E)
# Bisinde, Burundi, (-3.5088N, 30.184E)
# Bisiza, Burundi, (-2.8458N, 29.3673E)
# Bisoro, Burundi, (-3.5861N, 29.671E)
# Bitagazwa, Burundi, (-2.8132N, 30.0397E)
# Bitagodoka, Burundi, (-3.1186N, 30.2982E)
# Bitaka, Burundi, (-3.692N, 30.0074E)
# Bitambi, Burundi, (-3.08485N, 30.02118E)
# Bitambwe, Burundi, (-2.6938N, 29.958E)
# Bitare, Burundi, (-3.2313N, 29.9158E)
# Bitega, Burundi, (-2.8581N, 29.2344E)
# Bitege, Burundi, (-3.7835N, 30.1399E)
# Biteka, Burundi, (-3.886N, 29.8795E)
# Bitezi, Burundi, (-3.7422N, 29.734E)
# Bitwe, Burundi, (-3.6264N, 29.376E)
# Biyorwa, Burundi, (-2.712N, 30.3855E)
# Biziya, Burundi, (-3.5724N, 29.7877E)
# Bogogwa, Burundi, (-4.3384N, 29.604E)
# Bogora, Burundi, (-2.9902N, 29.3976E)
# Bomba, Burundi, (-2.966N, 30.0869E)
# Bona, Burundi, (-3.346N, 29.4823E)
# Bonero, Burundi, (-3.0153N, 30.039E)
# Bubaji, Burundi, (-3.453N, 29.4857E)
# Bubanda, Burundi, (-3.3118N, 29.7424E)
# Bubanga, Burundi, (-3.04555N, 30.2942E)
# Bubanza, Burundi, (-3.0804N, 29.391E)
# Bubari, Burundi, (-3.5183N, 29.6151E)
# Bubenga, Burundi, (-3.1342N, 29.4714E)
# Bubera, Burundi, (-3.91111N, 29.51528E)
# Bubezi, Burundi, (-2.9264N, 29.6461E)
# Bubogora, Burundi, (-2.9931N, 29.6676E)
# Bubu, Burundi, (-3.2271N, 29.6728E)
# Bubunga, Burundi, (-3.806N, 29.608E)
# Buburu, Burundi, (-3.6833N, 29.6935E)
# Bucahana, Burundi, (-2.4827N, 30.2982E)
# Bucamihigo, Burundi, (-2.8029N, 30.3095E)
# Bucana, Burundi, (-2.6394N, 30.2396E)
# Bucanda, Burundi, (-2.9719N, 29.4324E)
# Bucarenga, Burundi, (-3.1381N, 30.31559E)
# Bucuzi, Burundi, (-2.9086N, 29.1909E)
# Budaga, Burundi, (-2.9807N, 30.1109E)
# Budahigwa, Burundi, (-3.2587N, 29.3966E)
# Budahuga, Burundi, (-2.9917N, 30.5971E)
# Budahunga, Burundi, (-2.5597N, 30.3293E)
# Budajunikwa, Burundi, (-3.3915N, 29.9898E)
# Budatekwa, Burundi, (-4.3957N, 29.7849E)
# Budida, Burundi, (-3.5496N, 29.905E)
# Budonde, Burundi, (-3.4576N, 29.5775E)
# Buga, Burundi, (-3.5432N, 29.9402E)
# Bugabira, Burundi, (-2.5314N, 30.0706E)
# Bugabiro, Burundi, (-3.2075N, 30.593E)
# Bugagi, Burundi, (-2.9488N, 30.3818E)
# Buganda, Burundi, (-2.8527N, 30.2609E)
# Buganuka, Burundi, (-3.0428N, 29.9547E)
# Bugarama, Burundi, (-3.5183N, 30.2036E)
# Bugari, Burundi, (-2.7593N, 30.0827E)
# Bugarure, Burundi, (-2.6N, 30.0854E)
# Bugega, Burundi, (-3.7044N, 29.8655E)
# Bugendajoro, Burundi, (-3.0313N, 30.6155E)
# Bugendana, Burundi, (-3.2458N, 29.9024E)
# Bugeni, Burundi, (-4.0635N, 29.6457E)
# Bugenyuzi, Burundi, (-3.09557N, 30.06169E)
# Bugera, Burundi, (-3.4144N, 29.7382E)
# Bugiga, Burundi, (-3.9926N, 30.022E)
# Bugobora, Burundi, (-2.8515N, 29.1938E)
# Bugogo, Burundi, (-2.9014N, 30.1003E)
# Bugoma, Burundi, (-2.4341N, 30.4298E)
# Bugomba, Burundi, (-3.4067N, 29.462E)
# Bugombe, Burundi, (-3.8986N, 29.941E)
# Bugomora, Burundi, (-2.8682N, 30.2972E)
# Bugondo, Burundi, (-3.8078N, 30.2243E)
# Bugongo, Burundi, (-3.4676N, 29.4406E)
# Bugongo I, Burundi, (-3.7266N, 30.2908E)
# Bugongo II, Burundi, (-3.7147N, 30.3393E)
# Bugonza, Burundi, (-3.0741N, 30.30117E)
# Bugorora, Burundi, (-2.654N, 30.2914E)
# Bugumbasha, Burundi, (-3.6403N, 29.9768E)
# Bugume, Burundi, (-3.2457N, 29.4768E)
# Bugunga, Burundi, (-3.814N, 29.9893E)
# Bugungu, Burundi, (-2.9563N, 30.4117E)
# Buguye, Burundi, (-3.25056N, 29.50452E)
# Bugwana, Burundi, (-3.0143N, 30.1278E)
# Buhabwa, Burundi, (-3.6183N, 29.7894E)
# Buhagara, Burundi, (-3.91737N, 30.19412E)
# Buhama, Burundi, (-2.8769N, 30.1035E)
# Buhana, Burundi, (-4.0762N, 29.6194E)
# Buhanda, Burundi, (-2.7857N, 29.799E)
# Buhandagaza, Burundi, (-3.1025N, 29.3256E)
# Buhanga, Burundi, (-3.6514N, 29.9878E)
# Buhangara, Burundi, (-2.4475N, 30.4668E)
# Buhangura, Burundi, (-3.2509N, 29.7355E)
# Buhangwa, Burundi, (-2.6235N, 30.0182E)
# Buhanza, Burundi, (-3.7417N, 29.3432E)
# Buharagata, Burundi, (-3.383N, 29.6442E)
# Buhasa, Burundi, (-2.9897N, 30.2619E)
# Buhayira, Burundi, (-2.9511N, 29.2737E)
# Buhemba, Burundi, (-3.0625N, 30.3496E)
# Buheranyi, Burundi, (-3.09494N, 30.3094E)
# Buhevyi, Burundi, (-3.0384N, 29.9832E)
# Buhiga, Burundi, (-3.12361N, 30.18333E)
# Buhigiranka, Burundi, (-2.7967N, 29.8696E)
# Buhigwe, Burundi, (-3.3625N, 30.1162E)
# Buhimba, Burundi, (-2.5634N, 30.2739E)
# Buhina, Burundi, (-3.4523N, 29.438E)
# Buhinda, Burundi, (-3.5646N, 29.3587E)
# Buhindo, Burundi, (-2.8355N, 29.1978E)
# Buhindye, Burundi, (-3.04315N, 30.02793E)
# Buhinga, Burundi, (-4.045N, 29.7321E)
# Buhinyuza, Burundi, (-3.3282N, 29.372E)
# Buhogo, Burundi, (-3.801N, 30.2329E)
# Buhomba, Burundi, (-3.3018N, 29.3362E)
# Buhonga, Burundi, (-3.4328N, 29.4094E)
# Buhongegwa, Burundi, (-3.541N, 30.1274E)
# Buhorana, Burundi, (-2.7093N, 30.1224E)
# Buhoro, Burundi, (-3.0295N, 30.726E)
# Buhororo, Burundi, (-3.418N, 29.5714E)
# Buhorwa, Burundi, (-3.1893N, 29.6702E)
# Buhoyo, Burundi, (-3.4355N, 29.8169E)
# Buhu, Burundi, (-3.3656N, 30.0713E)
# Buhuma, Burundi, (-2.7818N, 30.1101E)
# Buhumbi, Burundi, (-3.94129N, 30.18786E)
# Buhurana, Burundi, (-2.8345N, 30.4063E)
# Buhurika, Burundi, (-3.088N, 29.439E)
# Buhwamyi, Burundi, (-4.0162N, 30.1217E)
# Bujaga, Burundi, (-2.5161N, 30.3162E)
# Bujuru, Burundi, (-3.5688N, 30.2062E)
# Bukamba, Burundi, (-3.357N, 30.1011E)
# Bukanda, Burundi, (-4.052N, 29.6079E)
# Bukanya, Burundi, (-3.13862N, 30.20303E)
# Bukemba, Burundi, (-3.9853N, 29.9161E)
# Bukera, Burundi, (-2.9109N, 29.1436E)
# Bukeye, Burundi, (-4.3345N, 29.61972E)
# Bukinanyana, Burundi, (-2.8973N, 29.3256E)
# Bukinga, Burundi, (-3.2383N, 30.4515E)
# Bukinisha, Burundi, (-2.8061N, 30.2665E)
# Bukinja, Burundi, (-2.9812N, 30.3735E)
# Bukiramvyiro, Burundi, (-2.7555N, 30.1772E)
# Bukiranzuki, Burundi, (-3.0881N, 29.6116E)
# Bukirasazi, Burundi, (-2.83N, 30.3838E)
# Bukobe, Burundi, (-2.4985N, 30.4653E)
# Bukoro, Burundi, (-3.5464N, 29.8673E)
# Bukorora, Burundi, (-2.8903N, 29.1725E)
# Bukuba, Burundi, (-2.6832N, 30.0797E)
# Bukurana, Burundi, (-3.2663N, 30.5156E)
# Bukwavu, Burundi, (-3.3593N, 29.6461E)
# Bukwazo, Burundi, (-3.4434N, 30.0291E)
# Bukweto, Burundi, (-3.1463N, 29.5765E)
# Bukwiye, Burundi, (-2.5177N, 30.4835E)
# Bumba, Burundi, (-2.8072N, 29.1529E)
# Bumbiri, Burundi, (-2.97N, 29.2051E)
# Bungere, Burundi, (-3.5195N, 29.9886E)
# Bungozi, Burundi, (-2.9154N, 29.6847E)
# Buniha, Burundi, (-3.1494N, 30.2138E)
# Bunogera, Burundi, (-2.8044N, 30.0391E)
# Bunorana, Burundi, (-2.6062N, 30.3842E)
# Bunya, Burundi, (-3.8431N, 30.0813E)
# Bunyambo, Burundi, (-3.459N, 30.54E)
# Bunyange, Burundi, (-3.4509N, 29.6492E)
# Bunyarukiga, Burundi, (-2.7446N, 30.1943E)
# Bunyuka, Burundi, (-3.749N, 29.9521E)
# Bunyuro, Burundi, (-3.1684N, 30.6648E)
# Bunywana, Burundi, (-2.7969N, 30.0496E)
# Bunywera, Burundi, (-2.4999N, 30.3856E)
# Bupfizi, Burundi, (-3.58361N, 30.44528E)
# Bupfunda, Burundi, (-3.307N, 29.7304E)
# Bura, Burundi, (-3.772N, 29.5446E)
# Buraga, Burundi, (-2.7369N, 30.3821E)
# Buramata, Burundi, (-3.1507N, 29.3474E)
# Buramba, Burundi, (-3.5874N, 30.0199E)
# Burambana, Burundi, (-3.2887N, 29.5955E)
# Burambi, Burundi, (-3.81985N, 29.54262E)
# Burambira, Burundi, (-2.7408N, 30.1459E)
# Buranga, Burundi, (-3.7907N, 30.0322E)
# Burangwa, Burundi, (-3.7025N, 29.338E)
# Buraniro, Burundi, (-3.1003N, 29.6635E)
# Burara, Burundi, (-2.4923N, 30.2275E)
# Burarana, Burundi, (-4.0016N, 29.6914E)
# Buraruka, Burundi, (-3.9788N, 29.8439E)
# Burasira, Burundi, (-2.9707N, 30.3069E)
# Buraza, Burundi, (-3.7639N, 29.8918E)
# Burazi, Burundi, (-3.5742N, 29.4045E)
# Burembera, Burundi, (-3.3358N, 30.008E)
# Burenge, Burundi, (-2.7301N, 30.0119E)
# Burengo, Burundi, (-3.0725N, 29.6192E)
# Burenza, Burundi, (-3.0216N, 30.366E)
# Burenza I, Burundi, (-2.8239N, 29.8431E)
# Burenza II, Burundi, (-2.8477N, 29.7946E)
# Buriba, Burundi, (-3.4385N, 30.4743E)
# Burima, Burundi, (-2.9568N, 30.2818E)
# Burimbi, Burundi, (-2.9479N, 29.4034E)
# Burindi, Burundi, (-3.3237N, 29.7055E)
# Burindira, Burundi, (-2.6744N, 30.1492E)
# Buringa, Burundi, (-3.6365N, 29.4094E)
# Buringanire, Burundi, (-2.5473N, 29.986E)
# Buriza, Burundi, (-3.788N, 29.869E)
# Buruhukiro, Burundi, (-3.3808N, 29.6141E)
# Burume, Burundi, (-3.7579N, 30.0534E)
# Burunga, Burundi, (-3.6865N, 29.8972E)
# Bururi, Burundi, (-3.94877N, 29.62438E)
# Busabe, Burundi, (-3.8115N, 30.2348E)
# Busaga, Burundi, (-3.8591N, 29.4226E)
# Busaka, Burundi, (-3.01564N, 30.06233E)
# Busambo, Burundi, (-2.978N, 29.5639E)
# Busangana, Burundi, (-3.179N, 29.5924E)
# Busangira, Burundi, (-2.6621N, 30.3697E)
# Busango, Burundi, (-4.0786N, 29.9618E)
# Busanza, Burundi, (-2.9431N, 29.9326E)
# Busarira, Burundi, (-2.719N, 30.3375E)
# Busaro, Burundi, (-2.9825N, 30.3066E)
# Busasa, Burundi, (-2.9076N, 29.2897E)
# Busekera, Burundi, (-3.2383N, 29.5507E)
# Busenge, Burundi, (-3.5911N, 29.3946E)
# Busenyi, Burundi, (-2.6416N, 30.084E)
# Busesa, Burundi, (-3.87222N, 29.43889E)
# Busesamvu, Burundi, (-3.0879N, 29.4653E)
# Bushabashi, Burundi, (-3.5011N, 29.9498E)
# Bushembo, Burundi, (-2.6561N, 30.1647E)
# Bushikira, Burundi, (-2.4905N, 30.4238E)
# Bushirambeho, Burundi, (-3.1048N, 30.226E)
# Bushoka, Burundi, (-3.0943N, 29.808E)
# Busiga, Burundi, (-2.87873N, 29.73883E)
# Busigo, Burundi, (-3.9008N, 29.9795E)
# Busimba, Burundi, (-3.2628N, 29.5813E)
# Businde, Burundi, (-3.2894N, 29.7289E)
# Busokoza, Burundi, (-3.0887N, 29.7552E)
# Busongoye, Burundi, (-2.5464N, 30.3E)
# Busoni, Burundi, (-2.8616N, 30.105E)
# Busoro, Burundi, (-3.22751N, 30.41185E)
# Busoza, Burundi, (-3.258N, 30.2325E)
# Busumanyi, Burundi, (-3.0634N, 30.6339E)
# Busura, Burundi, (-3.7931N, 29.5066E)
# Busyana, Burundi, (-3.3599N, 30.5584E)
# Buta, Burundi, (-3.9565N, 29.7108E)
# Butaganda, Burundi, (-2.8893N, 29.9582E)
# Butaganzwa, Burundi, (-3.1034N, 29.7225E)
# Butagazwa, Burundi, (-3.3953N, 29.573E)
# Butaha, Burundi, (-3.1248N, 29.4797E)
# Butahana, Burundi, (-2.73326N, 29.25131E)
# Butambara, Burundi, (-3.7583N, 30.1766E)
# Butambuka, Burundi, (-2.4886N, 30.4671E)
# Butamenwa, Burundi, (-3.2484N, 30.1214E)
# Butamuheba, Burundi, (-3.4434N, 29.875E)
# Butana, Burundi, (-3.0993N, 30.326E)
# Butanganika, Burundi, (-2.9585N, 29.8512E)
# Butangaza, Burundi, (-3.02566N, 30.07467E)
# Butanuka, Burundi, (-3.1491N, 29.4365E)
# Butanya, Burundi, (-3.7587N, 30.1338E)
# Butanyerera, Burundi, (-3.2431N, 29.4693E)
# Butara, Burundi, (-2.8845N, 29.3362E)
# Butaramuka, Burundi, (-2.7252N, 30.2207E)
# Butarangira, Burundi, (-3.4383N, 30.6231E)
# Butare, Burundi, (-3.22365N, 30.29645E)
# Butaro, Burundi, (-3.9737N, 29.6527E)
# Butarugera, Burundi, (-2.6586N, 30.3799E)
# Butarumanga, Burundi, (-2.4799N, 30.472E)
# Butavuka, Burundi, (-3.2134N, 29.4223E)
# Butazi, Burundi, (-3.4005N, 29.7802E)
# Butebe, Burundi, (-3.2462N, 30.625E)
# Butega, Burundi, (-2.96265N, 29.39313E)
# Butegama, Burundi, (-3.5498N, 29.637E)
# Butegana, Burundi, (-2.8672N, 29.6478E)
# Butemba, Burundi, (-3.7666N, 29.9822E)
# Butembe, Burundi, (-3.1573N, 29.4586E)
# Buterama, Burundi, (-3.6857N, 29.8472E)
# Buteyege, Burundi, (-3.4426N, 29.8052E)
# Butezi, Burundi, (-3.39604N, 30.15473E)
# Butihinda, Burundi, (-2.8419N, 30.2768E)
# Butimbo, Burundi, (-3.1931N, 29.655E)
# Butirabura, Burundi, (-2.8619N, 30.1966E)
# Butobwe, Burundi, (-3.6426N, 29.9342E)
# Butoga, Burundi, (-2.8009N, 30.2572E)
# Butora, Burundi, (-3.5127N, 29.6427E)
# Butsimba, Burundi, (-2.7574N, 30.1237E)
# Butuhurana, Burundi, (-3.1503N, 29.4812E)
# Butwe, Burundi, (-3.2309N, 29.8343E)
# Buvumbi, Burundi, (-2.6716N, 30.1852E)
# Buvumo, Burundi, (-2.8191N, 29.4847E)
# Buvuzo, Burundi, (-3.384N, 29.8037E)
# Buvyuko, Burundi, (-3.0578N, 29.3308E)
# Buyaga, Burundi, (-3.2376N, 29.7291E)
# Buyagara, Burundi, (-2.634N, 30.321E)
# Buyagira, Burundi, (-4.1857N, 29.7913E)
# Buye, Burundi, (-2.865N, 29.819E)
# Buyenzi, Burundi, (-3.6275N, 29.3894E)
# Buyimba, Burundi, (-3.3841N, 29.5121E)
# Buyogoma, Burundi, (-3.28409N, 30.3993E)
# Buyogora, Burundi, (-3.2608N, 30.1691E)
# Buyongwe, Burundi, (-2.9997N, 30.6617E)
# Buyori, Burundi, (-3.3627N, 29.7324E)
# Buyumpu, Burundi, (-2.8144N, 29.4676E)
# Buzamana, Burundi, (-3.8861N, 29.5488E)
# Buzige, Burundi, (-3.4111N, 29.4224E)
# Buzigo, Burundi, (-2.6326N, 30.2175E)
# Buziracanda, Burundi, (-3.3723N, 29.7465E)
# Buziragahama, Burundi, (-2.7996N, 29.7762E)
# Buziraguhindwa, Burundi, (-3.0317N, 29.4449E)
# Buziramabinga, Burundi, (-3.1177N, 30.5161E)
# Buzirambenga, Burundi, (-3.6664N, 29.8353E)
# Buzirampfunya, Burundi, (-3.1409N, 29.8277E)
# Buziramugayo, Burundi, (-2.8314N, 30.2285E)
# Buzirawangwe, Burundi, (-2.6381N, 30.328E)
# Bwakira, Burundi, (-3.5663N, 29.7372E)
# Bwasale, Burundi, (-2.8248N, 30.2131E)
# Bwasare, Burundi, (-3.14401N, 30.19465E)
# Bwashisha, Burundi, (-2.4407N, 30.5112E)
# Bwatemba, Burundi, (-4.0822N, 29.6344E)
# Bwato, Burundi, (-3.3765N, 29.6225E)
# Bwayi, Burundi, (-3.4608N, 29.6754E)
# Bwegera, Burundi, (-2.9552N, 29.2553E)
# Bwena, Burundi, (-3.3031N, 29.8762E)
# Bwera, Burundi, (-4.0749N, 29.9247E)
# Bweru, Burundi, (-3.3233N, 30.46995E)
# Bwica, Burundi, (-2.8974N, 30.2845E)
# Bwinjira, Burundi, (-3.5448N, 30.0406E)
# Bwinyana, Burundi, (-2.6816N, 30.0083E)
# Bwirakare, Burundi, (-2.7307N, 29.9865E)
# Bwire, Burundi, (-3.3225N, 29.8836E)
# Bwisange, Burundi, (-3.1057N, 29.6354E)
# Bwisha, Burundi, (-2.7891N, 30.1464E)
# Bwitoyi, Burundi, (-2.9097N, 30.0047E)
# Bwiza, Burundi, (-3.2826N, 29.9423E)
# Bwiza-Bweranka, Burundi, (-2.9496N, 29.8848E)
# Bwoga, Burundi, (-3.4057N, 29.8837E)
# Bwome, Burundi, (-3.6284N, 30.2583E)
# Bwona, Burundi, (-3.3092N, 29.7919E)
# Bwonko, Burundi, (-3.182N, 30.5109E)
# Bwumanyi, Burundi, (-3.3642N, 30.1387E)
# Cabira, Burundi, (-3.0859N, 29.3511E)
# Cabumba, Burundi, (-3.7706N, 29.8641E)
# Caga, Burundi, (-2.8799N, 29.7404E)
# Cagizo, Burundi, (-2.6776N, 30.293E)
# Cagura, Burundi, (-3.0401N, 29.9163E)
# Cagwa, Burundi, (-2.7872N, 30.0205E)
# Cahi, Burundi, (-2.7922N, 29.8381E)
# Cakaka, Burundi, (-3.3921N, 29.7656E)
# Camazi, Burundi, (-3.2127N, 30.7627E)
# Cambogwe, Burundi, (-4.0633N, 29.5251E)
# Camizi, Burundi, (-3.0098N, 29.6136E)
# Campazi, Burundi, (-2.9767N, 29.5942E)
# Camugani, Burundi, (-2.9224N, 29.8349E)
# Camumandu, Burundi, (-3.3326N, 29.768E)
# Cana, Burundi, (-3.5019N, 29.9894E)
# Canamo, Burundi, (-2.8882N, 30.0902E)
# Canda, Burundi, (-3.57732N, 29.38835E)
# Cangugu, Burundi, (-2.986N, 29.1917E)
# Cangwe, Burundi, (-3.9242N, 29.5717E)
# Canika, Burundi, (-3.0763N, 30.7646E)
# Cankuzo, Burundi, (-3.2186N, 30.5528E)
# Canzara, Burundi, (-2.8756N, 29.6017E)
# Canzikiro, Burundi, (-3.09141N, 30.11741E)
# Canzu, Burundi, (-3.6573N, 30.0789E)
# Caragata, Burundi, (-3.5966N, 30.1867E)
# Caranka, Burundi, (-3.3654N, 29.474E)
# Caratsi, Burundi, (-2.8225N, 29.6209E)
# Cari, Burundi, (-3.2937N, 29.9925E)
# Carire, Burundi, (-3.2609N, 29.8564E)
# Carubambo, Burundi, (-2.5625N, 29.9649E)
# Cashi, Burundi, (-3.6807N, 29.3358E)
# Cayi, Burundi, (-2.8874N, 30.0369E)
# Cendajuru, Burundi, (-2.6829N, 30.1397E)
# Cera, Burundi, (-2.8863N, 29.8841E)
# Ceramunda, Burundi, (-3.1217N, 29.5963E)
# Cero, Burundi, (-3.7326N, 30.0316E)
# Ceru, Burundi, (-2.4551N, 30.1043E)
# Cewe, Burundi, (-3.812N, 29.5183E)
# Ceyerezi, Burundi, (-3.024N, 29.7604E)
# Cezi, Burundi, (-3.22513N, 30.06741E)
# Cibari, Burundi, (-2.8175N, 30.3688E)
# Cibitoke, Burundi, (-3.3418N, 29.3716E)
# Cibwire, Burundi, (-3.7739N, 29.6499E)
# Cigati, Burundi, (-2.9878N, 30.2456E)
# Cigome, Burundi, (-3.6228N, 29.5445E)
# Cigumije, Burundi, (-2.9659N, 29.799E)
# Cihisho, Burundi, (-3.0997N, 30.5223E)
# Cihonda, Burundi, (-2.8374N, 30.1373E)
# Cimabare, Burundi, (-3.9826N, 29.5477E)
# Cimba, Burundi, (-3.5497N, 29.8984E)
# Cimo, Burundi, (-2.3457N, 29.9747E)
# Cinga, Burundi, (-3.161N, 29.7088E)
# Cingwa, Burundi, (-3.17708N, 30.11963E)
# Cingwe-Nyamata, Burundi, (-2.4631N, 30.0085E)
# Cinywera, Burundi, (-3.00623N, 30.49437E)
# Cirambo, Burundi, (-2.9205N, 30.1844E)
# Ciri, Burundi, (-2.8175N, 29.9392E)
# Cirisha, Burundi, (-3.3636N, 29.4946E)
# Cishwa, Burundi, (-3.047N, 29.8617E)
# Civugiza, Burundi, (-3.2061N, 29.7583E)
# Ciya, Burundi, (-3.0274N, 29.4159E)
# Ciyando, Burundi, (-3.3985N, 30.0912E)
# Ciyubake, Burundi, (-3.4274N, 29.9672E)
# Coga, Burundi, (-3.3933N, 29.4148E)
# Coganyi, Burundi, (-3.2344N, 29.6775E)
# Cogo, Burundi, (-3.08089N, 30.12587E)
# Colline Lugombi, Burundi, (-3.392667N, 29.386499E)
# Colline Yamagendera, Burundi, (-3.812251N, 29.901833E)
# Coma, Burundi, (-3.6444N, 29.5895E)
# Cona, Burundi, (-3.126N, 29.3689E)
# Condi, Burundi, (-3.8073N, 29.8279E)
# Conga, Burundi, (-3.7653N, 30.2809E)
# Congori, Burundi, (-2.7008N, 29.9372E)
# Cowe, Burundi, (-4.19733N, 29.74854E)
# Cuba, Burundi, (-3.0847N, 30.13191E)
# Cugaro, Burundi, (-3.1189N, 30.0384E)
# Cugi, Burundi, (-3.4887N, 30.141E)
# Cuhu, Burundi, (-3.7202N, 30.2706E)
# Cukiro, Burundi, (-2.9572N, 29.6512E)
# Cumba, Burundi, (-2.8814N, 30.1189E)
# Cumva, Burundi, (-2.6371N, 30.1047E)
# Cunamwe, Burundi, (-4.0796N, 29.8008E)
# Cunda, Burundi, (-3.9279N, 29.4377E)
# Cunguza, Burundi, (-3.7554N, 29.8751E)
# Cunyu, Burundi, (-2.9236N, 29.2149E)
# Cunywe, Burundi, (-3.2392N, 29.8938E)
# Cura, Burundi, (-2.7649N, 30.2064E)
# Curabugufi, Burundi, (-3.5093N, 30.1106E)
# Curiza, Burundi, (-3.6335N, 29.7912E)
# Cuzwe, Burundi, (-2.8287N, 29.1626E)
# Dabambe, Burundi, (-3.9398N, 30.0073E)
# Dangara, Burundi, (-3.8278N, 29.9392E)
# Donge-Burasira, Burundi, (-3.665N, 29.5672E)
# Donge-Ruzi, Burundi, (-3.7115N, 29.5338E)
# Donzi, Burundi, (-3.7402N, 29.4698E)
# Duhiro, Burundi, (-3.2821N, 30.6189E)
# Duli, Burundi, (-3.8949N, 29.4817E)
# Dunga, Burundi, (-4.1514N, 29.9327E)
# Dusasa, Burundi, (-2.8287N, 29.4643E)
# Dutwaro, Burundi, (-3.3208N, 29.8603E)
# Foko, Burundi, (-2.3568N, 30.0188E)
# Fota, Burundi, (-3.44043N, 29.70556E)
# Fuku, Burundi, (-3.868N, 29.6441E)
# Funzwe, Burundi, (-3.7029N, 30.3628E)
# G@ufu, Burundi, (-3.2311N, 29.4433E)
# Gabaniro, Burundi, (-3.6064N, 29.3555E)
# Gabuke, Burundi, (-3.3454N, 29.9702E)
# Gacabwoya, Burundi, (-2.6439N, 30.1209E)
# Gacaca, Burundi, (-3.2876N, 29.9319E)
# Gacamihigo, Burundi, (-2.5418N, 30.2204E)
# Gacokwe, Burundi, (-2.9003N, 30.2837E)
# Gaconge, Burundi, (-2.9103N, 30.2857E)
# Gacu, Burundi, (-2.4675N, 30.4441E)
# Gacuba, Burundi, (-3.0384N, 29.3733E)
# Gafunzo, Burundi, (-3.3082N, 30.1614E)
# Gafuri, Burundi, (-3.41543N, 30.43875E)
# Gahabura, Burundi, (-2.8998N, 29.2874E)
# Gahabwa, Burundi, (-2.8924N, 29.2212E)
# Gahaga, Burundi, (-3.1845N, 29.6381E)
# Gahagaze, Burundi, (-3.6579N, 29.5675E)
# Gahago, Burundi, (-4.0622N, 29.6817E)
# Gahahe, Burundi, (-3.3309N, 29.8238E)
# Gahama, Burundi, (-3.7873N, 29.7524E)
# Gahanda, Burundi, (-3.8484N, 29.7656E)
# Gahandu, Burundi, (-4.1342N, 29.6799E)
# Gahanga, Burundi, (-3.5181N, 30.28385E)
# Gahara, Burundi, (-2.5652N, 30.3656E)
# Gahararo, Burundi, (-2.7716N, 30.2645E)
# Gaharata, Burundi, (-2.5683N, 30.0992E)
# Gaharo, Burundi, (-3.22388N, 30.09099E)
# Gahashi, Burundi, (-2.9733N, 30.2614E)
# Gahe, Burundi, (-2.6832N, 30.0491E)
# Gaheba, Burundi, (-2.9609N, 29.8309E)
# Gaheka, Burundi, (-3.0109N, 29.9641E)
# Gahembe, Burundi, (-4.0147N, 29.876E)
# Gahengeri, Burundi, (-2.9439N, 29.8197E)
# Gahera, Burundi, (-3.5696N, 29.743E)
# Gahetsi, Burundi, (-3.4426N, 29.6195E)
# Gahinasazi, Burundi, (-2.9626N, 29.45245E)
# Gahinda, Burundi, (-3.8475N, 29.4206E)
# Gahinga, Burundi, (-4.2302N, 29.729E)
# Gahini, Burundi, (-2.8203N, 29.6728E)
# Gahise, Burundi, (-3.0641N, 29.4477E)
# Gahisi, Burundi, (-3.2242N, 29.7733E)
# Gaho, Burundi, (-2.9588N, 30.1512E)
# Gahogo, Burundi, (-2.8444N, 30.2426E)
# Gahoko, Burundi, (-3.2387N, 30.6013E)
# Gahoma, Burundi, (-2.7854N, 29.2768E)
# Gahombo, Burundi, (-2.9653N, 29.7332E)
# Gahondo, Burundi, (-3.4392N, 29.672E)
# Gahongore, Burundi, (-3.0955N, 29.3819E)
# Gahororo, Burundi, (-3.7311N, 30.0806E)
# Gahosha, Burundi, (-4.1104N, 29.8128E)
# Gahuma, Burundi, (-2.94N, 29.7393E)
# Gahumba, Burundi, (-3.1203N, 29.9854E)
# Gahuna, Burundi, (-3.9399N, 29.9896E)
# Gahuni, Burundi, (-3.7856N, 30.1219E)
# Gahuro, Burundi, (-3.3995N, 29.8314E)
# Gahuru, Burundi, (-2.9197N, 29.1731E)
# Gahwazi, Burundi, (-2.9078N, 29.7924E)
# Gahwenzi, Burundi, (-2.9615N, 29.69E)
# Gahweza, Burundi, (-3.3759N, 29.6622E)
# Gahwije, Burundi, (-2.4392N, 30.0143E)
# Gakana, Burundi, (-2.6166N, 30.1639E)
# Gakangaga, Burundi, (-3.4607N, 30.5927E)
# Gakara, Burundi, (-4.216N, 29.7136E)
# Gakarakara, Burundi, (-2.9323N, 30.149E)
# Gakaranka, Burundi, (-3.6201N, 29.5554E)
# Gakaze, Burundi, (-3.2639N, 30.4054E)
# Gakeceri, Burundi, (-2.8957N, 29.7729E)
# Gakenke, Burundi, (-3.336N, 29.5412E)
# Gakere, Burundi, (-2.85417N, 30.04306E)
# Gakindo, Burundi, (-3.0567N, 29.3978E)
# Gakobe, Burundi, (-3.8958N, 30.0387E)
# Gakoko, Burundi, (-2.9221N, 29.3226E)
# Gakombe, Burundi, (-3.5504N, 30.0894E)
# Gakombero, Burundi, (-3.5306N, 29.3599E)
# Gakome, Burundi, (-3.754N, 30.0162E)
# Gakomero, Burundi, (-2.9287N, 29.4107E)
# Gakoni, Burundi, (-2.5453N, 30.3725E)
# Gakonko, Burundi, (-3.8175N, 29.4508E)
# Gakore, Burundi, (-3.4225N, 30.5871E)
# Gakowe, Burundi, (-3.04056N, 29.43611E)
# Gakuba, Burundi, (-3.74535N, 29.81196E)
# Gakungu, Burundi, (-3.7631N, 30.3298E)
# Gakungwe, Burundi, (-3.4948N, 29.3538E)
# Gakuro, Burundi, (-2.9939N, 29.7259E)
# Gakuyo, Burundi, (-3.6182N, 29.3789E)
# Gakuza, Burundi, (-3.8312N, 29.4562E)
# Gakwende, Burundi, (-3.9599N, 29.883E)
# Gamba, Burundi, (-3.113N, 29.4755E)
# Ganga, Burundi, (-3.5164N, 29.3851E)
# Ganigwa, Burundi, (-2.9851N, 30.0643E)
# Gasaba, Burundi, (-4.3737N, 29.8531E)
# Gasabira, Burundi, (-3.1313N, 29.7578E)
# Gasabo, Burundi, (-3.0374N, 30.7021E)
# Gasagara, Burundi, (-2.4121N, 30.0023E)
# Gasaka, Burundi, (-3.8692N, 30.1278E)
# Gasakuza, Burundi, (-3.8615N, 30.0236E)
# Gasamba, Burundi, (-3.8819N, 29.4379E)
# Gasana, Burundi, (-4.0508N, 30.1427E)
# Gasanda, Burundi, (-4.1934N, 29.9077E)
# Gasanga, Burundi, (-3.8448N, 29.8172E)
# Gasange, Burundi, (-3.8206N, 29.9519E)
# Gasaraga, Burundi, (-3.5578N, 29.8695E)
# Gasarara, Burundi, (-3.4049N, 29.4278E)
# Gasare, Burundi, (-3.059N, 29.6041E)
# Gasarende, Burundi, (-3.9884N, 29.8624E)
# Gasaro, Burundi, (-3.796N, 29.5521E)
# Gasarwe, Burundi, (-3.5151N, 29.4224E)
# Gasasa, Burundi, (-3.1599N, 30.7431E)
# Gasasira, Burundi, (-3.5818N, 29.4521E)
# Gasate, Burundi, (-2.9434N, 29.8693E)
# Gasave, Burundi, (-2.9535N, 30.4265E)
# Gasebeye, Burundi, (-2.5407N, 29.9462E)
# Gasebeyi, Burundi, (-3.58285N, 29.4139E)
# Gasegerwa, Burundi, (-2.8267N, 29.8769E)
# Gasegwa, Burundi, (-2.81611N, 30.05528E)
# Gasekanya, Burundi, (-2.9079N, 29.9533E)
# Gasekebuye, Burundi, (-3.407N, 29.3748E)
# Gasekera, Burundi, (-2.9799N, 30.0898E)
# Gasema, Burundi, (-3.7691N, 29.5739E)
# Gaseme, Burundi, (-2.5699N, 30.2365E)
# Gasemo, Burundi, (-3.0685N, 30.26396E)
# Gasenga, Burundi, (-4.2413N, 29.9689E)
# Gasenyi, Burundi, (-3.4008N, 29.4668E)
# Gaserege, Burundi, (-2.8974N, 29.5807E)
# Gaseri, Burundi, (-3.9122N, 29.9327E)
# Gaseru, Burundi, (-3.5202N, 29.3985E)
# Gasezerwa, Burundi, (-2.8966N, 30.1063E)
# Gashanga, Burundi, (-3.2858N, 29.8051E)
# Gashara, Burundi, (-2.7096N, 30.0139E)
# Gashari, Burundi, (-2.8847N, 29.99E)
# Gashasha, Burundi, (-4.0878N, 29.5164E)
# Gashashara, Burundi, (-3.1853N, 29.5171E)
# Gashawe, Burundi, (-3.34104N, 30.39036E)
# Gasheke, Burundi, (-2.9571N, 29.3316E)
# Gashibuka, Burundi, (-3.0251N, 29.8548E)
# Gashiha, Burundi, (-3.5983N, 29.6886E)
# Gashikanwa, Burundi, (-2.908N, 29.89975E)
# Gashinga, Burundi, (-3.7247N, 30.2263E)
# Gashinge, Burundi, (-3.48N, 29.8908E)
# Gashingi, Burundi, (-3.0098N, 29.3568E)
# Gashingura, Burundi, (-3.6505N, 29.8414E)
# Gashingwa, Burundi, (-3.3503N, 29.7434E)
# Gashingwe, Burundi, (-3.6597N, 30.0639E)
# Gashiru, Burundi, (-2.8424N, 29.5136E)
# Gashirwe, Burundi, (-3.3597N, 30.591E)
# Gashishima, Burundi, (-3.1332N, 29.5702E)
# Gashoho, Burundi, (-2.8017N, 30.1335E)
# Gashoka, Burundi, (-3.0787N, 29.7567E)
# Gashonge, Burundi, (-2.9411N, 30.2978E)
# Gashubi, Burundi, (-2.6686N, 30.264E)
# Gashwi, Burundi, (-2.9416N, 29.7573E)
# Gasi, Burundi, (-3.4794N, 29.4444E)
# Gasibe, Burundi, (-3.723N, 29.7361E)
# Gasigati, Burundi, (-3.9473N, 29.751E)
# Gasigwa, Burundi, (-3.2699N, 29.9136E)
# Gasivya, Burundi, (-3.676N, 29.7026E)
# Gasobane, Burundi, (-2.5355N, 30.4477E)
# Gasongati, Burundi, (-3.4458N, 29.8233E)
# Gasorwe, Burundi, (-2.852N, 30.2207E)
# Gasorwe Refugee Camp, Burundi, (-2.85338N, 30.21961E)
# Gasozi, Burundi, (-3.6576N, 30.2216E)
# Gasozwa, Burundi, (-3.6483N, 29.7417E)
# Gasumba, Burundi, (-3.107N, 30.6621E)
# Gasumo, Burundi, (-3.5094N, 30.0504E)
# Gasunu, Burundi, (-3.3449N, 29.9603E)
# Gasura, Burundi, (-2.6876N, 30.1035E)
# Gasuru, Burundi, (-2.6968N, 30.152E)
# Gasurubwe, Burundi, (-2.9534N, 29.2936E)
# Gaswera, Burundi, (-3.174N, 30.1944E)
# Gasyangiri, Burundi, (-3.34465N, 30.41917E)
# Gataba, Burundi, (-3.6944N, 30.3476E)
# Gatabo, Burundi, (-2.9096N, 29.8643E)
# Gatagura, Burundi, (-3.1755N, 29.4426E)
# Gataka, Burundi, (-3.6869N, 29.6347E)
# Gatakazi, Burundi, (-2.462N, 30.3787E)
# Gatanga, Burundi, (-4.0096N, 29.7204E)
# Gatanganikwa, Burundi, (-3.14841N, 30.14655E)
# Gatara, Burundi, (-2.9951N, 29.6561E)
# Gatare, Burundi, (-2.9827N, 29.9885E)
# Gatare-Gasenyi, Burundi, (-3.6065N, 30.2434E)
# Gataro, Burundi, (-2.6713N, 30.2753E)
# Gatebe, Burundi, (-3.2875N, 29.5285E)
# Gatega, Burundi, (-3.5455N, 29.8061E)
# Gateke, Burundi, (-2.8494N, 30.0231E)
# Gateko, Burundi, (-2.8191N, 29.5592E)
# Gatemere, Burundi, (-2.5851N, 30.2374E)
# Gaterama, Burundi, (-3.6534N, 30.0484E)
# Gaterera, Burundi, (-3.3541N, 30.533E)
# Gateri, Burundi, (-2.9488N, 29.1718E)
# Gatete, Burundi, (-4.0446N, 29.4803E)
# Gatika, Burundi, (-2.9123N, 29.7324E)
# Gatimbiri, Burundi, (-3.6225N, 30.2867E)
# Gatobo, Burundi, (-3.8507N, 29.4562E)
# Gatoke, Burundi, (-2.6195N, 30.2237E)
# Gatonde, Burundi, (-3.1721N, 29.95E)
# Gatonga, Burundi, (-2.327N, 30.3993E)
# Gatonganika, Burundi, (-3.9343N, 29.5077E)
# Gatongati, Burundi, (-3.02878N, 30.27895E)
# Gatongo, Burundi, (-2.9575N, 29.8826E)
# Gatonyangira, Burundi, (-4.3691N, 29.6445E)
# Gatoza, Burundi, (-3.6333N, 29.9108E)
# Gatozo, Burundi, (-3.0053N, 29.7893E)
# Gatsinda, Burundi, (-2.8242N, 29.8118E)
# Gatsinga, Burundi, (-3.422N, 29.6854E)
# Gatsiro, Burundi, (-3.6555N, 29.8838E)
# Gatukuza, Burundi, (-3.2164N, 29.6552E)
# Gatumba, Burundi, (-3.33333N, 29.25E)
# Gatumbura, Burundi, (-3.7055N, 30.2292E)
# Gatumbuzi, Burundi, (-3.0638N, 29.8172E)
# Gatungaboro, Burundi, (-2.8749N, 30.1247E)
# Gatunguru, Burundi, (-3.2186N, 29.9764E)
# Gatungurwe, Burundi, (-3.1752N, 30.5971E)
# Gatuntu, Burundi, (-3.199N, 30.7458E)
# Gatura, Burundi, (-3.3585N, 30.5731E)
# Gaturanda, Burundi, (-2.401N, 30.0351E)
# Gatutwe, Burundi, (-2.8584N, 30.1934E)
# Gatwa, Burundi, (-3.6609N, 30.1737E)
# Gatwaro, Burundi, (-3.5329N, 29.8239E)
# Gatwe, Burundi, (-3.8507N, 29.3783E)
# Gatwenge, Burundi, (-3.8272N, 29.8211E)
# Gatwenzi, Burundi, (-2.9455N, 30.0229E)
# Gendo, Burundi, (-3.9577N, 29.7602E)
# Gerangabo, Burundi, (-3.0983N, 29.8686E)
# Gerero, Burundi, (-3.191N, 30.7132E)
# Gicaca, Burundi, (-2.7626N, 29.1003E)
# Gicike, Burundi, (-3.6007N, 30.4038E)
# Gicombe, Burundi, (-2.6298N, 30.1738E)
# Gicu, Burundi, (-2.8085N, 29.8629E)
# Gicumbi, Burundi, (-3.706N, 29.9248E)
# Gicumboro, Burundi, (-3.1954N, 30.3927E)
# Gicungwe, Burundi, (-3.7061N, 29.5363E)
# Gifugutu, Burundi, (-3.7156N, 29.613E)
# Gifunzo, Burundi, (-3.9112N, 29.9658E)
# Gifurwe, Burundi, (-3.1761N, 29.4173E)
# Gihama, Burundi, (-2.6267N, 30.2913E)
# Gihamagara, Burundi, (-3.6267N, 30.0223E)
# Gihamba, Burundi, (-3.5512N, 30.0379E)
# Gihambwe, Burundi, (-3.5712N, 30.3157E)
# Gihanga, Burundi, (-3.8137N, 30.0025E)
# Gihango, Burundi, (-3.35058N, 29.96027E)
# Gihanjo, Burundi, (-3.702N, 29.604E)
# Giharo, Burundi, (-3.7791N, 30.2348E)
# Gihasha, Burundi, (-4.0736N, 29.9399E)
# Gihehe, Burundi, (-3.324N, 29.8537E)
# Giheko, Burundi, (-3.8559N, 30.2001E)
# Gihera, Burundi, (-3.7875N, 30.1702E)
# Gihere, Burundi, (-2.9466N, 30.0036E)
# Gihero, Burundi, (-4.1233N, 29.8804E)
# Giheru, Burundi, (-3.0199N, 30.40226E)
# Giheta, Burundi, (-3.3637N, 29.8582E)
# Gihigi, Burundi, (-2.5788N, 30.4272E)
# Gihinda, Burundi, (-3.1348N, 30.7138E)
# Gihindwe, Burundi, (-2.9113N, 29.9071E)
# Gihinga, Burundi, (-3.4866N, 29.7229E)
# Gihingo, Burundi, (-2.7013N, 30.2899E)
# Gihitansi, Burundi, (-2.5921N, 30.4287E)
# Gihiza, Burundi, (-3.4862N, 29.8804E)
# Gihofi, Burundi, (-3.9855N, 30.1275E)
# Gihofi-Bareremba, Burundi, (-4.0615N, 30.1265E)
# Gihogazi, Burundi, (-3.1126N, 29.9962E)
# Gihohe, Burundi, (-2.6381N, 29.9664E)
# Gihoma, Burundi, (-3.4317N, 29.7577E)
# Gihomba, Burundi, (-2.843N, 29.0857E)
# Gihondo, Burundi, (-3.5942N, 29.4073E)
# Gihongo, Burundi, (-2.9405N, 30.3349E)
# Gihongoro, Burundi, (-4.1419N, 29.8272E)
# Gihoro, Burundi, (-3.6048N, 29.8567E)
# Gihororo, Burundi, (-2.6896N, 29.9554E)
# Gihosha, Burundi, (-2.6048N, 30.1432E)
# Gihosho, Burundi, (-3.3389N, 29.4158E)
# Gihovu, Burundi, (-3.6766N, 30.035E)
# Gihuga, Burundi, (-3.2935N, 29.8472E)
# Gihungwe, Burundi, (-3.15N, 29.25E)
# Gihushi, Burundi, (-2.5706N, 30.2247E)
# Gikama, Burundi, (-2.651N, 30.3939E)
# Gikana, Burundi, (-3.9392N, 29.8173E)
# Gikangaga, Burundi, (-3.4208N, 29.3998E)
# Gikarama, Burundi, (-3.5116N, 30.4838E)
# Gikebuka, Burundi, (-3.4132N, 29.6323E)
# Gikende, Burundi, (-3.8195N, 30.2993E)
# Gikinga, Burundi, (-3.8963N, 29.89E)
# Gikingo, Burundi, (-2.8423N, 29.5677E)
# Giko, Burundi, (-3.0701N, 29.3822E)
# Gikobe, Burundi, (-3.6737N, 29.9422E)
# Gikokoma, Burundi, (-3.8999N, 29.608E)
# Gikokora, Burundi, (-3.04825N, 30.20709E)
# Gikombe, Burundi, (-4.0942N, 29.7689E)
# Gikomero, Burundi, (-3.1427N, 29.8231E)
# Gikonge, Burundi, (-3.2419N, 29.6512E)
# Gikongo, Burundi, (-3.27021N, 30.44526E)
# Gikongoro, Burundi, (-3.6126N, 29.4598E)
# Gikonko, Burundi, (-2.9359N, 30.1978E)
# Gikore, Burundi, (-2.8047N, 29.8612E)
# Gikoto, Burundi, (-3.4104N, 29.3856E)
# Gikuka, Burundi, (-3.6828N, 29.9051E)
# Gikundamvura, Burundi, (-2.9804N, 29.8343E)
# Gikungere, Burundi, (-3.1255N, 29.7057E)
# Gikunu, Burundi, (-2.9642N, 30.2007E)
# Gikurazo, Burundi, (-4.2142N, 29.8267E)
# Gikuyo, Burundi, (-3.1324N, 29.7041E)
# Gikuzi, Burundi, (-4.1544N, 29.7216E)
# Gikwazo, Burundi, (-3.8008N, 29.8334E)
# Gikwiye, Burundi, (-2.8645N, 30.2215E)
# Gipfizi, Burundi, (-3.7282N, 29.3508E)
# Gipfuvya, Burundi, (-3.1291N, 29.7726E)
# Gisaba, Burundi, (-2.8539N, 29.1376E)
# Gisabazuba, Burundi, (-2.7601N, 30.1462E)
# Gisagara, Burundi, (-3.2026N, 30.6894E)
# Gisagazuba, Burundi, (-3.7248N, 29.4482E)
# Gisanze, Burundi, (-3.0292N, 30.7147E)
# Gisanze-Muzingi, Burundi, (-2.7734N, 30.1988E)
# Gisanze-Rugerero, Burundi, (-2.7909N, 30.1729E)
# Gisara, Burundi, (-3.0465N, 29.8115E)
# Gisarenda, Burundi, (-3.7686N, 29.7166E)
# Gisarwe, Burundi, (-3.4232N, 29.5394E)
# Gisasa, Burundi, (-2.984N, 30.6362E)
# Gisatura, Burundi, (-3.9717N, 29.5299E)
# Gisebeyi, Burundi, (-2.8131N, 30.1682E)
# Gisebuzi, Burundi, (-3.3707N, 29.8428E)
# Gisegwa, Burundi, (-4.1884N, 29.8683E)
# Giseke, Burundi, (-3.0601N, 30.7209E)
# Gisekuro, Burundi, (-2.7512N, 29.9806E)
# Gisenga, Burundi, (-3.0317N, 30.552E)
# Giseno, Burundi, (-2.9812N, 29.3289E)
# Gisenyi, Burundi, (-3.9822N, 29.8829E)
# Giserama, Burundi, (-2.8368N, 29.4204E)
# Giseza, Burundi, (-3.1733N, 29.5304E)
# Gisezerwa, Burundi, (-2.8579N, 29.7833E)
# Gisha, Burundi, (-2.9161N, 29.9693E)
# Gishambusha, Burundi, (-2.8208N, 30.1527E)
# Gishami, Burundi, (-3.2129N, 30.7122E)
# Gishanga, Burundi, (-3.7227N, 30.0767E)
# Gishehe, Burundi, (-2.587N, 30.3531E)
# Gishenyi, Burundi, (-2.3628N, 30.3865E)
# Gishiha, Burundi, (-4.1067N, 29.7092E)
# Gishikanwa, Burundi, (-3.05947N, 30.01709E)
# Gishingano, Burundi, (-3.3573N, 29.4258E)
# Gishinge, Burundi, (-3.6911N, 29.3745E)
# Gishingwe, Burundi, (-3.4242N, 30.3762E)
# Gishirwe, Burundi, (-3.8406N, 29.8476E)
# Gishishima, Burundi, (-3.6396N, 29.5502E)
# Gishubi, Burundi, (-3.8051N, 30.0506E)
# Gishuha, Burundi, (-2.7894N, 30.2176E)
# Gishungo, Burundi, (-3.0668N, 30.6829E)
# Gishunzi, Burundi, (-2.926N, 29.7447E)
# Gishurushuru, Burundi, (-3.9403N, 29.5863E)
# Gisibe, Burundi, (-3.7437N, 30.0765E)
# Gisikara, Burundi, (-3.668N, 30.0637E)
# Gisimbawaga, Burundi, (-3.1454N, 30.2285E)
# Gisirtye, Burundi, (-3.396N, 29.8535E)
# Gisisye, Burundi, (-3.788N, 29.6731E)
# Gisitwe, Burundi, (-2.6339N, 29.9506E)
# Gisivya, Burundi, (-2.9806N, 30.3235E)
# Gisiza, Burundi, (-2.8912N, 29.8963E)
# Gisizi, Burundi, (-3.7652N, 29.7518E)
# Gisogwe, Burundi, (-3.5081N, 29.5332E)
# Gisoko, Burundi, (-2.6343N, 30.23E)
# Gisoma, Burundi, (-3.6054N, 29.8804E)
# Gisonzoka, Burundi, (-2.9807N, 29.9678E)
# Gisoro, Burundi, (-3.2671N, 30.6188E)
# Gisorora, Burundi, (-3.41282N, 30.30105E)
# Gisorwe, Burundi, (-3.8963N, 29.8678E)
# Gisovu, Burundi, (-3.4406N, 29.3931E)
# Gisozi, Burundi, (-2.5107N, 30.4104E)
# Gisuka, Burundi, (-2.8298N, 29.949E)
# Gisukiro, Burundi, (-2.8369N, 30.0918E)
# Gisuma, Burundi, (-2.8428N, 29.927E)
# Gisura, Burundi, (-2.9366N, 29.9876E)
# Gisure, Burundi, (-3.91389N, 29.44444E)
# Gisuriro, Burundi, (-3.7458N, 30.068E)
# Gisuru, Burundi, (-3.4509N, 30.5098E)
# Gisyo, Burundi, (-3.0367N, 29.6642E)
# Gitaba, Burundi, (-3.5699N, 29.9816E)
# Gitabi, Burundi, (-4.0625N, 29.9456E)
# Gitabo, Burundi, (-3.7589N, 29.9083E)
# Gitambutso, Burundi, (-4.0088N, 29.8932E)
# Gitamo, Burundi, (-3.0816N, 29.8237E)
# Gitandu, Burundi, (-2.9629N, 30.2633E)
# Gitanga, Burundi, (-2.9434N, 29.2848E)
# Gitanganika, Burundi, (-3.8212N, 29.7432E)
# Gitangaro, Burundi, (-3.1865N, 29.6956E)
# Gitara, Burundi, (-3.5628N, 29.6455E)
# Gitarama, Burundi, (-3.7998N, 30.0311E)
# Gitaramuka, Burundi, (-3.8436N, 29.9186E)
# Gitare, Burundi, (-3.8019N, 30.0951E)
# Gitaro, Burundi, (-2.6542N, 30.2756E)
# Gitarurwa, Burundi, (-3.5184N, 29.6445E)
# Gitasi, Burundi, (-2.8725N, 29.7986E)
# Gitaza, Burundi, (-3.6165N, 29.358E)
# Gitebe, Burundi, (-2.7082N, 29.0876E)
# Gitega, Burundi, (-3.4264N, 29.9308E)
# Gitema, Burundi, (-3.3959N, 30.1424E)
# Gitemba, Burundi, (-3.3619N, 29.7438E)
# Gitemezi, Burundi, (-2.8587N, 29.6651E)
# Gitenga, Burundi, (-3.5302N, 29.3942E)
# Gitengeri, Burundi, (-3.1576N, 29.5928E)
# Gitera, Burundi, (-2.9743N, 29.3189E)
# Giterama, Burundi, (-3.5808N, 30.1015E)
# Giteranyi, Burundi, (-2.5238N, 30.4588E)
# Gitete, Burundi, (-2.4785N, 30.3425E)
# Gitezi, Burundi, (-3.3599N, 29.4337E)
# Gitibiza, Burundi, (-4.1654N, 29.7925E)
# Gitibu, Burundi, (-3.1855N, 30.5758E)
# Gitobe, Burundi, (-2.64823N, 30.20128E)
# Gitobo, Burundi, (-3.9825N, 29.8235E)
# Gitobwe, Burundi, (-3.0498N, 29.7406E)
# Gitohera, Burundi, (-2.9073N, 29.1819E)
# Gitohwe, Burundi, (-3.4786N, 29.5997E)
# Gitondo, Burundi, (-3.34913N, 30.46083E)
# Gitonganikwa, Burundi, (-3.0483N, 29.4316E)
# Gitongo, Burundi, (-4.1293N, 30.0489E)
# Gitongwe, Burundi, (-2.8118N, 30.3414E)
# Gitora, Burundi, (-3.3069N, 29.9657E)
# Gitovu, Burundi, (-3.3621N, 30.5975E)
# Gitsiro, Burundi, (-3.42041N, 30.34101E)
# Gituguta, Burundi, (-4.2895N, 29.9388E)
# Gitukura, Burundi, (-2.6783N, 29.2558E)
# Gitumba, Burundi, (-3.8093N, 29.6641E)
# Gitundo, Burundi, (-3.6154N, 29.3768E)
# Gitundwe, Burundi, (-2.7744N, 29.793E)
# Gitunga, Burundi, (-3.4993N, 29.8091E)
# Gitunguru, Burundi, (-4.1564N, 29.6268E)
# Gitura, Burundi, (-3.2767N, 30.6466E)
# Giturwe, Burundi, (-2.9634N, 29.9617E)
# Gitwa, Burundi, (-3.4886N, 29.6566E)
# Gitwaro, Burundi, (-3.6866N, 29.3518E)
# Gitwe, Burundi, (-3.3331N, 29.506E)
# Gitwe I, Burundi, (-4.0117N, 29.5123E)
# Gitwe II, Burundi, (-3.7641N, 29.3525E)
# Gitwenge, Burundi, (-3.036N, 29.702E)
# Gitwenzi, Burundi, (-2.9706N, 29.7803E)
# Goga, Burundi, (-3.6582N, 29.8096E)
# Gogoma, Burundi, (-3.45648N, 30.36584E)
# Gomba, Burundi, (-2.9254N, 30.3286E)
# Gomvyi, Burundi, (-3.5538N, 29.4064E)
# Gozi, Burundi, (-3.7557N, 29.6124E)
# Gukamba, Burundi, (-2.859N, 30.065E)
# Gungu, Burundi, (-3.4541N, 29.7167E)
# Gutundere, Burundi, (-2.9769N, 29.3107E)
# Gwagongwe, Burundi, (-3.6488N, 30.1482E)
# Gwahona, Burundi, (-4.2018N, 29.8544E)
# Gwanira, Burundi, (-2.8375N, 29.1375E)
# Gwaniro, Burundi, (-3.07705N, 30.15341E)
# Gwanumpu, Burundi, (-3.9035N, 29.9943E)
# Gwasanga, Burundi, (-3.781N, 29.7285E)
# Gwingiri, Burundi, (-3.3398N, 29.9148E)
# Gwingwa, Burundi, (-3.1025N, 30.8194E)
# Gwiri, Burundi, (-3.0298N, 29.624E)
# Gwiti, Burundi, (-3.13477N, 30.70525E)
# Gwiyagiro, Burundi, (-3.6862N, 29.5306E)
# Gwiyange, Burundi, (-3.00169N, 30.1197E)
# Haga, Burundi, (-2.4296N, 30.0841E)
# Hangarizo, Burundi, (-2.8316N, 29.7621E)
# Hayi, Burundi, (-3.7908N, 29.5925E)
# Hayiro, Burundi, (-3.3859N, 29.6821E)
# Higiro, Burundi, (-2.7864N, 29.9302E)
# Hina, Burundi, (-2.9182N, 29.7586E)
# Hindaniro, Burundi, (-2.9414N, 29.1644E)
# Horezo, Burundi, (-3.8702N, 29.5745E)
# Humure, Burundi, (-3.1037N, 30.5934E)
# Ibuga, Burundi, (-3.5313N, 30.4565E)
# Ihangiro, Burundi, (-3.2871N, 30.3905E)
# Ijenda, Burundi, (-3.4721N, 29.5823E)
# Ijuru, Burundi, (-3.6804N, 29.6431E)
# Impare, Burundi, (-2.8213N, 29.6551E)
# Ingwa, Burundi, (-3.2733N, 30.6372E)
# Intamba, Burundi, (-2.9243N, 30.1675E)
# Irimwa, Burundi, (-3.4026N, 29.6158E)
# Isale, Burundi, (-3.3489N, 29.4839E)
# Isigi, Burundi, (-3.5901N, 29.5086E)
# Itaba, Burundi, (-3.503N, 30.3758E)
# Itahe, Burundi, (-3.4449N, 30.5367E)
# Iteka, Burundi, (-3.4959N, 29.6939E)
# Itwe, Burundi, (-3.5462N, 29.625E)
# Ivi, Burundi, (-3.6272N, 29.7445E)
# Iyogera, Burundi, (-3.5192N, 30.4439E)
# Jabiro, Burundi, (-2.6636N, 29.9937E)
# Janda, Burundi, (-3.6986N, 29.4545E)
# Janga, Burundi, (-3.2713N, 29.7108E)
# Jani, Burundi, (-2.813N, 30.1846E)
# Janja, Burundi, (-3.5308N, 29.9353E)
# Jarama, Burundi, (-2.9977N, 30.2866E)
# Jenda, Burundi, (-4.0437N, 29.8086E)
# Jene, Burundi, (-2.84979N, 29.62942E)
# Jerama, Burundi, (-3.7452N, 29.8799E)
# Jimbi, Burundi, (-3.0542N, 29.7625E)
# Jobe, Burundi, (-3.904N, 29.9723E)
# Jogo, Burundi, (-3.2185N, 30.1772E)
# Jomati, Burundi, (-3.9145N, 30.0329E)
# Jongwe, Burundi, (-4.1144N, 29.6957E)
# Jugwe, Burundi, (-3.5261N, 29.8888E)
# Jungwe, Burundi, (-3.9673N, 29.7826E)
# Jurugati, Burundi, (-3.8386N, 30.1598E)
# Kababi, Burundi, (-3.1291N, 30.4576E)
# Kabagabaga, Burundi, (-2.5449N, 30.1123E)
# Kabagara, Burundi, (-4.0576N, 29.646E)
# Kabagari, Burundi, (-3.0481N, 30.7828E)
# Kabageni, Burundi, (-3.2689N, 30.5919E)
# Kabago, Burundi, (-3.6793N, 30.0595E)
# Kabakuro, Burundi, (-3.5849N, 30.114E)
# Kabamba, Burundi, (-2.8759N, 29.851E)
# Kabande, Burundi, (-3.08132N, 30.03837E)
# Kabanga, Burundi, (-4.02972N, 30.08944E)
# Kabangira, Burundi, (-3.18733N, 30.25856E)
# Kabaniganyi, Burundi, (-3.383N, 29.8634E)
# Kabarabara, Burundi, (-2.9051N, 30.1336E)
# Kabarambi, Burundi, (-3.7348N, 29.4371E)
# Kabarazaga, Burundi, (-4.2817N, 29.8411E)
# Kabaremera, Burundi, (-2.9214N, 30.0712E)
# Kabari, Burundi, (-3.11005N, 30.47974E)
# Kabarimbi, Burundi, (-2.8908N, 29.5664E)
# Kabarore, Burundi, (-2.8505N, 29.5374E)
# Kabasa, Burundi, (-3.8076N, 29.8967E)
# Kabasazi, Burundi, (-2.8703N, 29.7908E)
# Kabashi, Burundi, (-2.9539N, 30.1586E)
# Kabata, Burundi, (-2.9813N, 29.2408E)
# Kabataha, Burundi, (-2.8165N, 29.836E)
# Kabatwa, Burundi, (-2.8492N, 29.5479E)
# Kabayanda, Burundi, (-2.9858N, 29.6742E)
# Kabazana, Burundi, (-2.8176N, 29.7905E)
# Kabazo, Burundi, (-3.9518N, 29.8312E)
# Kabebe, Burundi, (-3.2507N, 30.8207E)
# Kabenga, Burundi, (-3.2331N, 29.6039E)
# Kabere, Burundi, (-2.7083N, 29.219E)
# Kaberenge, Burundi, (-4.1168N, 29.5657E)
# Kabeza, Burundi, (-3.1404N, 29.76E)
# Kabezi, Burundi, (-3.7877N, 29.373E)
# Kabimba, Burundi, (-3.6017N, 29.8099E)
# Kabingo, Burundi, (-3.8562N, 30.0888E)
# Kabira, Burundi, (-2.5366N, 30.1728E)
# Kabirizi, Burundi, (-2.6336N, 30.1692E)
# Kabirumba, Burundi, (-3.2316N, 29.6236E)
# Kabizi, Burundi, (-3.02309N, 30.14771E)
# Kabo, Burundi, (-3.7873N, 29.3445E)
# Kabogi, Burundi, (-3.3972N, 29.9245E)
# Kabogo, Burundi, (-2.5653N, 30.4612E)
# Kabogora, Burundi, (-3.9874N, 29.7113E)
# Kabogoye, Burundi, (-3.2886N, 30.6639E)
# Kabombo, Burundi, (-3.1256N, 30.2576E)
# Kabonaburundi, Burundi, (-3.2904N, 30.6802E)
# Kabonde, Burundi, (-2.5342N, 30.0862E)
# Kabondo, Burundi, (-4.3462N, 29.6077E)
# Kabonga, Burundi, (-4.41659N, 29.68447E)
# Kaboro, Burundi, (-3.7345N, 29.5425E)
# Kaboza, Burundi, (-2.7509N, 29.0876E)
# Kabuga, Burundi, (-3.1957N, 30.6065E)
# Kabugu, Burundi, (-3.1651N, 30.1919E)
# Kabuguzo, Burundi, (-3.2865N, 29.7725E)
# Kabukaro, Burundi, (-3.5866N, 29.9915E)
# Kabumba, Burundi, (-3.4307N, 29.3909E)
# Kabumbe, Burundi, (-3.7495N, 29.9189E)
# Kabundugu, Burundi, (-3.5301N, 29.8441E)
# Kabungere, Burundi, (-3.3482N, 29.8722E)
# Kabungo, Burundi, (-3.6916N, 30.1222E)
# Kaburanjwiri, Burundi, (-3.47555N, 30.37067E)
# Kaburantwa, Burundi, (-2.9985N, 29.2191E)
# Kaburanzwiri, Burundi, (-2.9768N, 30.4109E)
# Kabureye, Burundi, (-2.892N, 29.6428E)
# Kaburi, Burundi, (-4.2871N, 29.7737E)
# Kaburire, Burundi, (-3.48465N, 30.45308E)
# Kaburungu, Burundi, (-3.5798N, 29.5727E)
# Kabuturiro, Burundi, (-2.7595N, 29.1777E)
# Kabuye, Burundi, (-3.1563N, 29.7333E)
# Kabuye-Gitanga, Burundi, (-2.7098N, 30.1398E)
# Kabuye-Shororo, Burundi, (-2.765N, 30.109E)
# Kabuyekere, Burundi, (-3.0601N, 29.4488E)
# Kabuyenge, Burundi, (-3.3928N, 30.6255E)
# Kabuyogoma, Burundi, (-2.7318N, 30.3076E)
# Kabwayi, Burundi, (-4.0354N, 29.5561E)
# Kabweru, Burundi, (-3.01421N, 30.32521E)
# Kabwira, Burundi, (-2.7243N, 30.2779E)
# Kabwirika, Burundi, (-3.2759N, 29.6777E)
# Kabwitika, Burundi, (-3.058N, 29.3778E)
# Kadende, Burundi, (-3.8886N, 29.8251E)
# Kadimbagu, Burundi, (-2.8555N, 30.0774E)
# Kadina, Burundi, (-3.8986N, 29.7117E)
# Kaduha, Burundi, (-3.2015N, 30.7984E)
# Kagamba, Burundi, (-3.5161N, 29.827E)
# Kaganda, Burundi, (-3.5217N, 29.9015E)
# Kagano, Burundi, (-3.3949N, 29.7058E)
# Kaganza, Burundi, (-4.0851N, 29.5946E)
# Kagarama, Burundi, (-2.8418N, 30.0612E)
# Kagari, Burundi, (-2.9197N, 29.3033E)
# Kagaruka, Burundi, (-3.1718N, 29.7961E)
# Kagarura, Burundi, (-2.9579N, 29.9215E)
# Kagati, Burundi, (-3.3738N, 29.8291E)
# Kagazo, Burundi, (-3.099N, 29.7932E)
# Kagege, Burundi, (-3.6358N, 29.9884E)
# Kagendo, Burundi, (-3.4095N, 29.5472E)
# Kagera, Burundi, (-3.4342N, 30.5877E)
# Kageruke, Burundi, (-3.3084N, 29.4115E)
# Kageyo, Burundi, (-3.3339N, 30.5588E)
# Kagezi, Burundi, (-3.1229N, 30.33591E)
# Kagimbu, Burundi, (-3.7675N, 29.8474E)
# Kagina, Burundi, (-3.1087N, 30.26738E)
# Kagiraconi, Burundi, (-2.5682N, 30.2042E)
# Kagogo, Burundi, (-2.7753N, 29.1113E)
# Kagoma, Burundi, (-3.5258N, 29.6696E)
# Kagomogomo, Burundi, (-3.1447N, 30.7242E)
# Kagona, Burundi, (-3.7029N, 29.3784E)
# Kagondo, Burundi, (-3.30198N, 30.68032E)
# Kagongo, Burundi, (-3.6695N, 29.6544E)
# Kagongoro, Burundi, (-3.6383N, 30.1623E)
# Kagote, Burundi, (-2.6646N, 29.9524E)
# Kagoti, Burundi, (-2.9096N, 29.3996E)
# Kagozi, Burundi, (-2.8487N, 29.764E)
# Kagugo, Burundi, (-2.4773N, 30.4282E)
# Kaguhu, Burundi, (-2.8359N, 30.1756E)
# Kagunga, Burundi, (-3.6696N, 30.1335E)
# Kagunguma, Burundi, (-2.6838N, 29.9417E)
# Kagunguzi, Burundi, (-3.9778N, 29.5094E)
# Kagunuzi, Burundi, (-3.0669N, 29.26342E)
# Kagurutsi, Burundi, (-2.6347N, 29.1719E)
# Kagurwe, Burundi, (-2.8783N, 30.1828E)
# Kagwema, Burundi, (-2.8666N, 30.2653E)
# Kagwena, Burundi, (-3.1278N, 29.2616E)
# Kajabure, Burundi, (-3.985N, 29.5656E)
# Kajaga, Burundi, (-3.350806N, 29.277534E)
# Kajego, Burundi, (-2.4478N, 30.3103E)
# Kajeke, Burundi, (-3.1008N, 29.353E)
# Kajeri, Burundi, (-3.1692N, 30.1184E)
# Kajondi, Burundi, (-3.8868N, 29.7718E)
# Kajumba, Burundi, (-2.7017N, 29.1791E)
# Kakumu, Burundi, (-3.0959N, 29.9288E)
# Kamahijo, Burundi, (-3.0738N, 29.3365E)
# Kamakoko, Burundi, (-3.3046N, 29.7818E)
# Kamanga, Burundi, (-3.3627N, 29.8933E)
# Kamaramagambo, Burundi, (-3.7364N, 30.0768E)
# Kamayi, Burundi, (-2.4656N, 30.0777E)
# Kambati, Burundi, (-2.9495N, 29.7757E)
# Kame, Burundi, (-3.7649N, 29.9082E)
# Kamenge, Burundi, (-3.34449N, 29.38933E)
# Kamenya, Burundi, (-2.5899N, 30.0228E)
# Kamesa, Burundi, (-3.4198N, 29.3863E)
# Kamigara, Burundi, (-2.8202N, 29.7241E)
# Kamigisha, Burundi, (-3.043N, 29.8983E)
# Kamira, Burundi, (-2.9176N, 30.1406E)
# Kamiranzogera, Burundi, (-2.4746N, 30.0665E)
# Kamisave, Burundi, (-3.4119N, 29.5083E)
# Kamonge, Burundi, (-3.709N, 29.5785E)
# Kamonyi, Burundi, (-3.0492N, 30.7449E)
# Kamoye, Burundi, (-3.5611N, 29.9457E)
# Kampezi, Burundi, (-3.7692N, 29.7933E)
# Kampunga, Burundi, (-3.6779N, 30.3956E)
# Kamukike, Burundi, (-3.368N, 29.557E)
# Kamuna, Burundi, (-3.3055N, 30.2948E)
# Kamusase, Burundi, (-3.7398N, 29.9346E)
# Kamusenyi, Burundi, (-3.1808N, 30.0331E)
# Kamushiha, Burundi, (-3.348N, 29.7893E)
# Kamvumvu, Burundi, (-3.9339N, 29.7176E)
# Kanabugiri, Burundi, (-2.6323N, 30.0171E)
# Kanama, Burundi, (-3.0592N, 29.3903E)
# Kanangu, Burundi, (-2.9582N, 30.0554E)
# Kananira, Burundi, (-3.4954N, 29.5192E)
# Kanazi, Burundi, (-3.1073N, 30.0359E)
# Kandaro, Burundi, (-2.8553N, 29.8094E)
# Kanegwa, Burundi, (-3.315N, 29.6946E)
# Kanenga, Burundi, (-3.1381N, 29.455E)
# Kangange, Burundi, (-4.0434N, 29.7131E)
# Kange, Burundi, (-4.1119N, 29.9107E)
# Kangoma, Burundi, (-3.4989N, 29.675E)
# Kangozi, Burundi, (-3.7309N, 29.9351E)
# Kaniga, Burundi, (-3.28889N, 29.75833E)
# Kaniha, Burundi, (-3.085N, 30.6919E)
# Kanindi, Burundi, (-3.21872N, 29.57653E)
# Kaniro, Burundi, (-3.49035N, 30.39895E)
# Kanka, Burundi, (-3.6016N, 29.7599E)
# Kankima, Burundi, (-3.4457N, 29.5207E)
# Kanombe, Burundi, (-2.9203N, 29.41E)
# Kanonora, Burundi, (-3.0558N, 29.4156E)
# Kanoso, Burundi, (-2.9454N, 30.5334E)
# Kanumba, Burundi, (-2.6535N, 30.3569E)
# Kanunga, Burundi, (-2.8993N, 30.0092E)
# Kanyabitumwe, Burundi, (-3.8874N, 29.5286E)
# Kanyamazi, Burundi, (-3.5351N, 29.3475E)
# Kanyami, Burundi, (-3.3674N, 29.6483E)
# Kanyamiyoka, Burundi, (-3.847N, 29.7841E)
# Kanyange, Burundi, (-3.1371N, 29.6962E)
# Kanyangwe, Burundi, (-2.5567N, 30.0109E)
# Kanyankuru, Burundi, (-2.9451N, 29.7097E)
# Kanyaru, Burundi, (-2.79953N, 29.66169E)
# Kanyegenyege, Burundi, (-2.5697N, 30.1484E)
# Kanyembwa, Burundi, (-3.066N, 29.9737E)
# Kanyenumbu, Burundi, (-3.3812N, 30.1229E)
# Kanyeregete, Burundi, (-2.9203N, 29.8821E)
# Kanyererwe, Burundi, (-3.761N, 30.2141E)
# Kanyereza, Burundi, (-2.9644N, 30.2854E)
# Kanyinya, Burundi, (-3.6613N, 29.668E)
# Kanyomvyi, Burundi, (-2.797N, 30.0782E)
# Kanyonga, Burundi, (-3.4946N, 30.0376E)
# Kanyosha, Burundi, (-3.4148N, 29.4082E)
# Kanyundo, Burundi, (-2.9966N, 29.7907E)
# Kanyunya, Burundi, (-3.5207N, 29.5349E)
# Kanyuzwa, Burundi, (-3.819N, 29.8262E)
# Kanzege, Burundi, (-4.1391N, 29.7805E)
# Kara, Burundi, (-2.9733N, 30.2904E)
# Karagabazi, Burundi, (-4.1239N, 29.6669E)
# Karagara, Burundi, (-4.0337N, 29.5148E)
# Karago, Burundi, (-2.5075N, 30.0731E)
# Karahura, Burundi, (-2.9678N, 29.6999E)
# Karama, Burundi, (-3.13956N, 30.4108E)
# Karamagi, Burundi, (-2.6284N, 30.0881E)
# Karamba, Burundi, (-3.07729N, 30.21495E)
# Karambi, Burundi, (-3.1776N, 29.804E)
# Karambira, Burundi, (-3.6979N, 29.3528E)
# Karambo, Burundi, (-2.4407N, 30.3868E)
# Karangara, Burundi, (-4.34502N, 29.78855E)
# Kararanama, Burundi, (-2.5399N, 30.4199E)
# Karari, Burundi, (-3.3012N, 30.3467E)
# ...
# Sesera, Uganda, (0.78466N, 34.00973E)
# Sesiriba, Uganda, (0.47972N, 32.43624E)
# Seta, Uganda, (0.38957N, 32.70408E)
# Seyira, Uganda, (0.14831N, 32.94301E)
# Shikoye, Uganda, (0.94725N, 34.21884E)
# Shilongo, Uganda, (0.97784N, 34.22819E)
# Shiteka, Uganda, (0.99479N, 34.3954E)
# Shuku, Uganda, (-0.67083N, 30.32389E)
# Si, Uganda, (0.16559N, 32.97045E)
# Sibanga, Uganda, (0.90507N, 34.23724E)
# Sibanyikwa, Uganda, (0.61375N, 30.13643E)
# Sibembe, Uganda, (0.88128N, 34.24277E)
# Sibodohi, Uganda, (0.28367N, 33.91297E)
# Sidimbire, Uganda, (0.52031N, 34.01623E)
# Sidome, Uganda, (0.34271N, 33.89272E)
# Sifugwe, Uganda, (0.25437N, 33.92703E)
# Sifuyo, Uganda, (0.37137N, 33.98446E)
# Siggi, Uganda, (0.25N, 32.23333E)
# Sigogwesere, Uganda, (1.01667N, 32.21667E)
# Sigumo, Uganda, (0.33276N, 33.8899E)
# Siira, Uganda, (0.99586N, 34.14181E)
# Sijagajo, Uganda, (0.41242N, 33.87194E)
# Sikakoko, Uganda, (0.96667N, 31.2E)
# Sikela, Uganda, (0.93584N, 34.32193E)
# Sikhomosi, Uganda, (0.92661N, 34.31184E)
# Sikhubira, Uganda, (0.27813N, 33.92227E)
# Sikuda, Uganda, (0.48333N, 34.05E)
# Sikunga, Uganda, (0.96667N, 34.35E)
# Sikwala, Uganda, (0.8501N, 34.00809E)
# Sikye, Uganda, (1.31667N, 32.4E)
# Silangirere, Uganda, (0.56379N, 33.98474E)
# Silobera, Uganda, (0.63333N, 32.03333E)
# Simba, Uganda, (0.24174N, 32.16788E)
# Simbili Settlement, Uganda, (3.14291N, 31.2642E)
# Simbli, Uganda, (3.27441N, 30.88116E)
# Simbya, Uganda, (0.67273N, 30.01082E)
# Sime, Uganda, (0.92986N, 34.35682E)
# Simigini, Uganda, (0.37073N, 33.90145E)
# Simu, Uganda, (1.3N, 34.3E)
# Simwengi, Uganda, (0.77363N, 33.96209E)
# Sinde, Uganda, (0.30369N, 33.81819E)
# Singi, Uganda, (0.50167N, 34.02172E)
# Singo-Galigatya, Uganda, (0.29148N, 33.28188E)
# Singya, Uganda, (1.31667N, 32.25E)
# Sinya, Uganda, (0.83419N, 34.24104E)
# Sinyu, Uganda, (2.7N, 34.3E)
# Sipi, Uganda, (1.30972N, 34.37417E)
# Siranga, Uganda, (0.3178N, 33.95628E)
# Sirere, Uganda, (0.30603N, 33.90465E)
# Sirika, Uganda, (0.91992N, 33.42139E)
# Sirikano, Uganda, (0.34551N, 33.98865E)
# Sirisiri, Uganda, (1.64155N, 31.80337E)
# Sironko, Uganda, (1.23132N, 34.24773E)
# Sisiyi, Uganda, (1.27167N, 34.32968E)
# Situ, Uganda, (2.26131N, 31.32403E)
# Situi, Uganda, (0.88333N, 34.33333E)
# Siwa, Uganda, (0.79489N, 33.98499E)
# Sobya, Uganda, (1.26667N, 32.85E)
# Sogolelo, Uganda, (0.66667N, 32.03333E)
# Sokokho, Uganda, (0.94471N, 34.37582E)
# Sokolo, Uganda, (0.19816N, 32.4021E)
# Somba, Uganda, (0.90614N, 33.82226E)
# Sonde, Uganda, (0.39477N, 32.70257E)
# Soni, Uganda, (0.76667N, 33.95E)
# Soni-Ogwangi, Uganda, (0.76408N, 33.97332E)
# Sono, Uganda, (0.8538N, 34.43266E)
# Sonso, Uganda, (1.65468N, 31.57897E)
# Soona, Uganda, (0.56041N, 33.00964E)
# Sopsop, Uganda, (0.81817N, 34.07592E)
# Soroti, Uganda, (1.71464N, 33.61113E)
# South East, Uganda, (0.46353N, 34.0947E)
# Sporter, Uganda, (0.64442N, 33.02182E)
# Ssala, Uganda, (0.40087N, 32.44606E)
# Ssemokombe, Uganda, (0.00216N, 32.08038E)
# Ssenero, Uganda, (0.11775N, 32.22606E)
# Ssenya, Uganda, (-0.38333N, 31.65E)
# Sserunyabbi, Uganda, (0.08924N, 32.21825E)
# Ssese, Uganda, (0.36698N, 33.20782E)
# Sseta, Uganda, (0.26061N, 32.2531E)
# Ssigi, Uganda, (0.2835N, 32.34258E)
# Ssisa, Uganda, (0.17901N, 32.49477E)
# Ssunga, Uganda, (0.36791N, 33.11006E)
# Suam, Uganda, (1.21667N, 34.71667E)
# Sugezi, Uganda, (0.25454N, 32.12117E)
# Sugu, Uganda, (0.16167N, 32.93804E)
# Sugu-Lugala, Uganda, (0.22228N, 32.69213E)
# Suguru, Uganda, (1.78854N, 33.82536E)
# Suhesi, Uganda, (0.61417N, 30.18389E)
# Sula, Uganda, (0.39388N, 32.17113E)
# Suliya, Uganda, (0.45211N, 32.11736E)
# Sumba, Uganda, (0.24714N, 32.46763E)
# Sumbwe, Uganda, (0.32364N, 32.49158E)
# Sunga, Uganda, (-0.1N, 31.85E)
# Suni, Uganda, (0.9566N, 33.89635E)
# Sunu, Uganda, (0.91696N, 34.20231E)
# Supa, Uganda, (1.16667N, 33.73333E)
# Suruti, Uganda, (0.83881N, 34.14966E)
# Suugu-Kirangira, Uganda, (0.26852N, 32.95094E)
# Suugu-Mutwa, Uganda, (0.26256N, 32.96706E)
# Swagere, Uganda, (1.55001N, 33.0029E)
# Swololo, Uganda, (0.30552N, 33.93411E)
# Syamalede, Uganda, (0.33361N, 33.9762E)
# Syamukunga, Uganda, (0.91913N, 34.36411E)
# Syanyonjo, Uganda, (0.55542N, 34.04299E)
# Syanyunja, Uganda, (0.32514N, 33.78868E)
# Syawule, Uganda, (0.53678N, 34.0242E)
# Syeba, Uganda, (0.90462N, 34.21345E)
# Syonga, Uganda, (0.4661N, 33.99386E)
# Taan Valley, Uganda, (3.80202N, 33.8346E)
# Taba, Uganda, (0.18055N, 32.68157E)
# Tabagonyi, Uganda, (1.46667N, 34.4E)
# Tabongo, Uganda, (0.51881N, 34.06794E)
# Tademeri, Uganda, (0.99028N, 33.96972E)
# Takajunge, Uganda, (0.26031N, 32.60446E)
# Takwa, Uganda, (2.8991N, 31.31751E)
# Tamu, Uganda, (0.38533N, 32.10308E)
# Tanda, Uganda, (0.38725N, 32.12754E)
# Tangala, Uganda, (3.04687N, 31.1359E)
# Tapak, Uganda, (2.49795N, 34.8319E)
# Tara, Uganda, (3.3102N, 31.0334E)
# Tarogali, Uganda, (1.82772N, 32.3381E)
# Tata, Uganda, (2.50827N, 31.09143E)
# Tawojwoki, Uganda, (0.76963N, 34.03007E)
# Te'bito, Uganda, (2.40884N, 31.75066E)
# Te-Okot, Uganda, (2.50628N, 31.58676E)
# Te-Okuto, Uganda, (2.34394N, 31.59984E)
# Tebalowoza, Uganda, (0.37811N, 32.98688E)
# Tebankiza, Uganda, (0.03111N, 32.34317E)
# Teboke, Uganda, (1.81428N, 32.31268E)
# Tega, Uganda, (0.34956N, 32.99654E)
# Tegaligwa, Uganda, (0.15N, 31.61667E)
# Tegeress, Uganda, (1.38333N, 34.4E)
# Tegga, Uganda, (0.273N, 32.47906E)
# Teginya, Uganda, (0.23333N, 31.96667E)
# Teilwa, Uganda, (1.88841N, 32.68084E)
# Tekala, Uganda, (-0.43333N, 31.81667E)
# Tekwa, Uganda, (0.73073N, 34.28476E)
# Telamot, Uganda, (1.77237N, 33.69646E)
# Temangalo, Uganda, (0.35479N, 32.46286E)
# Temele, Uganda, (1.79672N, 33.60849E)
# Tendo, Uganda, (2.28774N, 31.12382E)
# Tente, Uganda, (0.5043N, 34.03389E)
# Terego, Uganda, (3.14155N, 31.00712E)
# Terere, Uganda, (0.20652N, 32.8464E)
# Tete, Uganda, (0.46152N, 33.8965E)
# Theyaro, Uganda, (2.52674N, 31.39818E)
# Tianyu, Uganda, (3.32096N, 31.80975E)
# Tibumara, Uganda, (0.68731N, 30.4426E)
# Tibwamulala, Uganda, (0.95067N, 33.03621E)
# Ticaf, Uganda, (0.65584N, 34.16799E)
# Tidwer, Uganda, (2.45814N, 31.1576E)
# Tiira, Uganda, (0.51329N, 34.07756E)
# Tilling, Uganda, (1.41667N, 33.71667E)
# Timba, Uganda, (0.65N, 32.71667E)
# Tindo, Uganda, (0.77943N, 33.97254E)
# Tiribogo, Uganda, (0.36929N, 32.30729E)
# Tirinyi, Uganda, (0.99667N, 33.79204E)
# Tiriri, Uganda, (1.89852N, 33.45906E)
# Titim, Uganda, (3.42434N, 33.66555E)
# Tokaru, Uganda, (3.36667N, 31.46212E)
# Tolwe, Uganda, (1.59902N, 32.22315E)
# Tombwe, Uganda, (0.61737N, 29.99431E)
# Tomi, Uganda, (0.68333N, 32.75E)
# Tondegejerako, Uganda, (0.46667N, 31.9E)
# Tondola, Uganda, (0.16667N, 31.9E)
# Tondolo, Uganda, (3.20047N, 31.10875E)
# Tongo, Uganda, (0.78333N, 32.73333E)
# Tongolo, Uganda, (0.38654N, 33.23064E)
# Tonya, Uganda, (1.58525N, 31.08834E)
# Tooma, Uganda, (0.90567N, 34.19565E)
# Torom, Uganda, (1.78031N, 33.96742E)
# Toroma, Uganda, (1.75364N, 33.95743E)
# Torome, Uganda, (3.24517N, 30.99658E)
# Tororo, Uganda, (0.69299N, 34.18085E)
# Torote, Uganda, (3.35N, 33.48333E)
# Totokidwe, Uganda, (0.79431N, 34.20336E)
# Ttaba, Uganda, (0.18597N, 32.38825E)
# Ttomi, Uganda, (0.33416N, 32.45813E)
# Tuba, Uganda, (0.79826N, 34.17213E)
# Tuburu, Uganda, (1.9857N, 33.52019E)
# Tugumu, Uganda, (1.43333N, 34.53333E)
# Tukum, Uganda, (1.82143N, 33.79892E)
# Tula, Uganda, (0.39342N, 32.56112E)
# Tumangu, Uganda, (3.22313N, 32.75677E)
# Tumba, Uganda, (1.55141N, 32.39317E)
# Tumbo, Uganda, (0.33447N, 32.18967E)
# Turukang, Uganda, (1.64704N, 32.73858E)
# Turupok, Uganda, (1.56667N, 32.63333E)
# Turutoko, Uganda, (2.46167N, 34.21167E)
# Tuskini, Uganda, (1.41667N, 34.53333E)
# Twabakoberanga, Uganda, (0.92956N, 33.03909E)
# Twalek, Uganda, (1.35N, 34.7E)
# Tweyambe, Uganda, (0.97495N, 33.05858E)
# Tweyanze, Uganda, (0.73333N, 32.56667E)
# Tyabire, Uganda, (0.11337N, 32.3281E)
# Ubalya, Uganda, (0.5673N, 33.99343E)
# Uderi, Uganda, (3.41788N, 31.83719E)
# Uduk, Uganda, (2.30247N, 31.1586E)
# Udupi, Uganda, (3.29629N, 31.17532E)
# Udurutu, Uganda, (2.86581N, 31.03688E)
# Ujwanga, Uganda, (2.4505N, 31.18228E)
# Ukadakya, Uganda, (2.05N, 34.05E)
# Uleppi, Uganda, (2.77407N, 31.03696E)
# Uluko, Uganda, (3.0145N, 30.94729E)
# Umi, Uganda, (3.54386N, 31.81105E)
# Umvure, Uganda, (2.56841N, 31.22632E)
# Uniababa, Uganda, (2.99371N, 31.26154E)
# Unyama, Uganda, (2.81699N, 32.33814E)
# Upper-Kabowa, Uganda, (0.38775N, 32.94219E)
# Usigu, Uganda, (2.58174N, 31.2522E)
# Usuku, Uganda, (1.98833N, 33.97167E)
# Utrutru, Uganda, (2.78046N, 31.17848E)
# Utumbari, Uganda, (3.27093N, 31.14472E)
# Uturu, Uganda, (2.76322N, 31.14982E)
# Uzu, Uganda, (3.05486N, 30.84428E)
# Vangalei, Uganda, (2.32805N, 31.23391E)
# Villa Maria, Uganda, (-0.20444N, 31.71917E)
# Virika, Uganda, (0.63547N, 30.26984E)
# Vugamira, Uganda, (0.3749N, 32.3883E)
# Vuluga, Uganda, (0.33513N, 33.06197E)
# Vumba, Uganda, (0.36192N, 32.26776E)
# Vumbe, Uganda, (0.32656N, 32.14523E)
# Vunda, Uganda, (0.30217N, 32.25484E)
# Vurr, Uganda, (2.52139N, 31.18284E)
# Vurra, Uganda, (2.90906N, 30.88248E)
# Vvulu, Uganda, (0.40065N, 32.96328E)
# Wabibo, Uganda, (0.1N, 31.81667E)
# Wabigali, Uganda, (1.0N, 32.71667E)
# Wabigalo, Uganda, (1.26667N, 32.45E)
# Wabinwa, Uganda, (1.52483N, 32.59264E)
# Wabinyira, Uganda, (0.32981N, 32.86886E)
# Wabinyonyi, Uganda, (1.3N, 32.46667E)
# Wabirongo, Uganda, (0.63352N, 33.03185E)
# Wabisi, Uganda, (1.43333N, 32.45E)
# Wabisisa, Uganda, (1.2N, 32.38333E)
# Wabitembe, Uganda, (0.49456N, 32.53835E)
# Wabitoki, Uganda, (1.73062N, 32.0303E)
# Wabiyinja, Uganda, (0.4802N, 33.10945E)
# Wabogwe, Uganda, (0.27383N, 33.0811E)
# Wabukala, Uganda, (1.52087N, 32.22846E)
# Wabukwa, Uganda, (0.57261N, 33.0082E)
# Wabulenga, Uganda, (0.50154N, 33.20214E)
# Wabulongo, Uganda, (0.4742N, 32.88119E)
# Wabulungu, Uganda, (0.48333N, 33.31667E)
# Wabusana, Uganda, (1.11667N, 32.6E)
# Wabusanke, Uganda, (0.48642N, 33.03735E)
# Wabusolo, Uganda, (0.27252N, 33.01629E)
# Wabusonko, Uganda, (0.79744N, 33.0232E)
# Wadelai, Uganda, (2.72425N, 31.39243E)
# Wadundara, Uganda, (1.66763N, 31.29824E)
# Wagaba, Uganda, (0.46034N, 32.36088E)
# Wagala, Uganda, (0.42344N, 32.90413E)
# Wagodo, Uganda, (0.74417N, 33.45278E)
# Wagona, Uganda, (0.57366N, 33.3763E)
# Waguru, Uganda, (1.68205N, 31.34875E)
# Waibalaibi, Uganda, (1.60225N, 32.72897E)
# Waibale, Uganda, (0.48075N, 33.35919E)
# Waibuga, Uganda, (0.63272N, 33.3844E)
# Waiga, Uganda, (0.3356N, 33.39688E)
# Waigasa, Uganda, (1.51735N, 31.32183E)
# Waikalakaka, Uganda, (0.39221N, 33.72737E)
# Wainya, Uganda, (0.55518N, 33.4073E)
# Wairagala, Uganda, (0.64057N, 33.57261E)
# Wairaka, Uganda, (0.4757N, 33.26457E)
# Wairama, Uganda, (0.57169N, 33.53065E)
# Waiswa, Uganda, (0.55N, 33.51667E)
# Waita, Uganda, (0.40891N, 33.52978E)
# Waitambogwe, Uganda, (0.53246N, 33.39492E)
# Wajala, Uganda, (1.38333N, 32.53333E)
# Waka, Uganda, (3.1095N, 31.43215E)
# Wakaliga, Uganda, (0.29211N, 32.54549E)
# Wakasiki, Uganda, (0.70515N, 33.96022E)
# Wakasimba, Uganda, (1.15N, 32.48333E)
# Wakatanga, Uganda, (0.66667N, 33.6E)
# Wakawaka, Uganda, (0.35113N, 33.76125E)
# Wakawungu, Uganda, (0.41516N, 33.52344E)
# Wakayiba, Uganda, (0.63333N, 31.61667E)
# Waki, Uganda, (1.72033N, 31.39322E)
# Wakimesi, Uganda, (0.28706N, 32.49677E)
# Wakisani, Uganda, (1.63398N, 32.01862E)
# Wakisi-Wakikoola, Uganda, (0.51206N, 33.11183E)
# Wakiso, Uganda, (0.40444N, 32.45944E)
# Wakitaka, Uganda, (0.47709N, 33.22106E)
# Wakiwungu, Uganda, (0.34271N, 33.5614E)
# Wakyato, Uganda, (0.87444N, 32.20472E)
# Walabungo, Uganda, (1.45N, 32.26667E)
# Walanga, Uganda, (0.56867N, 33.55446E)
# Walibo, Uganda, (0.60368N, 33.39724E)
# Walubo, Uganda, (0.9007N, 33.19129E)
# Waluga, Uganda, (0.45061N, 32.81346E)
# Walugere, Uganda, (0.37543N, 32.84352E)
# Walukoko, Uganda, (0.37957N, 33.59607E)
# Walukota, Uganda, (1.18333N, 32.63333E)
# Walukuba, Uganda, (0.44045N, 33.24072E)
# Walukunyu, Uganda, (0.30381N, 32.30025E)
# Walumbe, Uganda, (0.40666N, 33.37331E)
# Walumbugu, Uganda, (0.6059N, 33.3551E)
# Walusibi, Uganda, (0.39044N, 32.84447E)
# Waluvule, Uganda, (0.76667N, 32.5E)
# Walykubya, Uganda, (1.82605N, 31.37322E)
# Wamala, Uganda, (0.15137N, 32.5213E)
# Wambete, Uganda, (0.37418N, 33.48375E)
# Wambirigwe, Uganda, (0.98974N, 33.49422E)
# Wambogo, Uganda, (0.32237N, 33.48581E)
# Wambwa, Uganda, (0.38194N, 32.94316E)
# Wamengo, Uganda, (0.34107N, 33.18498E)
# Wamfuru, Uganda, (0.91667N, 30.53333E)
# Wamiga, Uganda, (1.52574N, 31.77204E)
# Wampala, Uganda, (0.4225N, 33.14657E)
# Wampewo, Uganda, (0.42391N, 32.60053E)
# Wampologoma, Uganda, (0.79666N, 33.01133E)
# Wamukende, Uganda, (1.35N, 32.25E)
# Wamulongo, Uganda, (0.49678N, 33.52577E)
# Wamusenyi, Uganda, (1.79415N, 32.15605E)
# Wananda, Uganda, (0.15654N, 32.12696E)
# Wandagi, Uganda, (0.85N, 32.1E)
# Wandago, Uganda, (0.99339N, 33.31072E)
# Wandala, Uganda, (0.5N, 33.51667E)
# Wandawa, Uganda, (0.40095N, 33.62071E)
# Wandegeya, Uganda, (0.33102N, 32.56992E)
# Wandera, Uganda, (2.28578N, 31.41181E)
# Wandi, Uganda, (3.10122N, 30.9784E)
# Wandulu, Uganda, (0.7N, 32.83333E)
# Wanenga, Uganda, (0.62574N, 33.77235E)
# Wanfufu, Uganda, (0.96667N, 32.71667E)
# Wanga, Uganda, (0.87736N, 33.82737E)
# Wangale, Uganda, (0.91759N, 34.10454E)
# Wangobo, Uganda, (0.7N, 33.68333E)
# Wanica, Uganda, (3.06394N, 31.09898E)
# Wanjagi, Uganda, (0.8N, 32.65E)
# Wanjeyo, Uganda, (0.40012N, 32.82657E)
# Wankaka, Uganda, (1.4N, 32.16667E)
# Wankanani, Uganda, (1.96557N, 31.7073E)
# Wankata, Uganda, (0.26486N, 32.90317E)
# Wankoba, Uganda, (0.3508N, 32.82816E)
# Wankole, Uganda, (0.74379N, 33.18274E)
# Wankongolo, Uganda, (0.39071N, 32.67332E)
# Wanseko, Uganda, (2.17753N, 31.3821E)
# Wansiimba, Uganda, (0.58552N, 33.12029E)
# Wansolo, Uganda, (1.68333N, 32.5E)
# Wantayi, Uganda, (0.39212N, 32.87274E)
# Wante, Uganda, (0.54163N, 33.43993E)
# Wantembo, Uganda, (1.79124N, 31.36426E)
# Wantsira, Uganda, (0.9821N, 34.16851E)
# Wantumbi, Uganda, (0.3649N, 33.12353E)
# Wantunda, Uganda, (0.62866N, 33.33181E)
# Wanyama, Uganda, (0.47291N, 33.2291E)
# Wanyange, Uganda, (0.47191N, 33.25551E)
# Wanyange Settlement, Uganda, (3.09691N, 31.34996E)
# War, Uganda, (2.60038N, 30.88884E)
# Wasa, Uganda, (0.78333N, 30.25E)
# Wasimba, Uganda, (0.47333N, 33.61882E)
# Wasozi, Uganda, (0.0225N, 32.03957E)
# Wasu, Uganda, (0.89779N, 33.85151E)
# Waswa, Uganda, (0.42885N, 32.95103E)
# Watakhuna, Uganda, (0.91905N, 34.23776E)
# Watoke, Uganda, (1.61613N, 32.27859E)
# Watsongole, Uganda, (0.95742N, 34.19386E)
# Watuba, Uganda, (0.0N, 31.93333E)
# Wega, Uganda, (0.94246N, 34.05745E)
# Wekomire, Uganda, (0.45N, 31.01667E)
# Wera, Uganda, (1.86704N, 33.75514E)
# Were, Uganda, (0.74443N, 34.00952E)
# West Opejo, Uganda, (3.45898N, 31.6906E)
# Wesunire, Uganda, (1.23333N, 33.16667E)
# Wianaka, Uganda, (2.57533N, 31.78246E)
# Wiawer, Uganda, (2.68167N, 33.66944E)
# Wichama, Uganda, (0.72522N, 33.9776E)
# Widayanga, Uganda, (2.50755N, 31.22725E)
# Wigweng, Uganda, (1.92123N, 32.69206E)
# Wikusi-Nyakasusa, Uganda, (0.80404N, 33.9571E)
# Wila, Uganda, (2.1N, 33.65E)
# Winyaka-Iyapoki, Uganda, (0.75128N, 33.91868E)
# Wipolo, Uganda, (2.51364N, 31.91305E)
# Wiria, Uganda, (3.05192N, 31.42927E)
# Wiyola, Uganda, (0.76804N, 33.99448E)
# Wobulenzi, Uganda, (0.72833N, 32.51222E)
# Wokukiri, Uganda, (0.86962N, 34.17329E)
# Wol, Uganda, (3.13658N, 33.19768E)
# Wolo, Uganda, (3.3942N, 31.2406E)
# Wotsongole, Uganda, (0.97926N, 34.16028E)
# Wumbwa, Uganda, (0.71557N, 33.89585E)
# Wumbwe, Uganda, (0.39666N, 33.86846E)
# Wunga, Uganda, (0.98333N, 32.91667E)
# Yakinemvi, Uganda, (3.25332N, 31.55375E)
# Yakiniji, Uganda, (3.25551N, 31.54331E)
# Yamu, Uganda, (2.58666N, 30.91942E)
# Yenga, Uganda, (0.84798N, 30.01381E)
# Yidu, Uganda, (3.22757N, 31.12236E)
# Yilo, Uganda, (2.86974N, 32.1668E)
# Yira, Uganda, (3.16075N, 32.36343E)
# Yivu, Uganda, (3.28816N, 30.99822E)
# Yoboke, Uganda, (0.6154N, 34.07117E)
# Yogayoga, Uganda, (0.44794N, 32.16915E)
# Yokolo, Uganda, (0.71871N, 33.9339E)
# Yole, Uganda, (3.07618N, 30.96196E)
# Yoro, Uganda, (3.40703N, 31.99536E)
# Yoyo, Uganda, (3.3983N, 31.31324E)
# Yuka, Uganda, (0.65911N, 33.15117E)
# Yumbe, Uganda, (3.46506N, 31.24689E)
# Zanyiro, Uganda, (0.76667N, 31.8E)
# Zengebe, Uganda, (1.48333N, 32.51667E)
# Zesui, Uganda, (1.13093N, 34.4062E)
# Zeu, Uganda, (2.5092N, 30.8034E)
# Ziba, Uganda, (0.09177N, 32.36628E)
# Zigoti, Uganda, (0.38389N, 32.145E)
# Zigulu, Uganda, (0.53333N, 32.86667E)
# Zimuddi, Uganda, (0.41667N, 32.31667E)
# Zimwe, Uganda, (-0.51667N, 31.75E)
# Zinga Island, Uganda, (0.27322N, 33.34741E)
# Zintengeze, Uganda, (0.5N, 32.98333E)
# Zira, Uganda, (0.44509N, 32.1608E)
# Ziranumba, Uganda, (0.22104N, 32.60467E)
# Zirobwe, Uganda, (0.67944N, 32.68944E)
# Ziru, Uganda, (0.14106N, 32.52202E)
# Zitwe, Uganda, (0.11072N, 32.94795E)
# Ziwungwe, Uganda, (0.19635N, 32.32114E)
# Zoka, Uganda, (3.21183N, 31.69429E)
# Zombo, Uganda, (2.51355N, 30.90909E)

# %%
# Shows where the location is on the map
plot_location_marker(location_name="Andiwo's Village", region="Kenya", file_name=None)

# %%
# Use a latitude and longitude to specify a custom location
plot_location_marker(
    location_name="Made up name",
    latitude=-1,
    longitude=38,
    region="Kenya",
    file_name=None,
)

# %%
# The location name can be selected from the list returned by print_locations()
# All locations are listed in the file show_forecasts/shapes/locations.py
#   For the case of the same name in different countries, the country can optionally
#   be selected from 'Kenya', 'South Sudan', 'Rwanda', 'Burundi', 'Djibouti',
#   'Eritrea', 'Ethiopia', 'Sudan', 'Somalia', 'Tanzania', 'Uganda'.
# Be carefull. Sometimes there are a few places with the same name.
plot_GAN_local_histograms(data, "Kirkos", country="Ethiopia", plot_units="mm/6h")

# %%
# Or if you want to specify the latitude and longitude, you can call the location what you like
# Specify the number of equally spaced bins (columns) in the histogram.
# Plot a line indicating the amount of rain that will be exceeded with a given probability.
plot_GAN_local_histograms(
    data,
    "Indian Ocean",
    latitude=-2.75,
    longitude=45.35,
    plot_units="mm/6h",
    num_bins=25,
    probability=1 / 20,
)

# %%
# Before plot_GAN_exceedance can be used, we must sort the data
# This might be slow, so we only want to do it once.
data_sorted = sort_along_ensemble_axis(data)

# %%
# Plot the amount of rain that will be exceeded with a given probability.
plot_GAN_exceedance(
    data_sorted,
    probability=1 / 20,
    valid_time_start_hour="all",
    style="EMI",
    plot_units="mm/6h",
    file_name=None,
)

# %%
# !jupyter nbconvert --to html test_GAN_forecast.ipynb
