# %%
# Demo script to load and plot ECMWF forecast open data.
import os
from datetime import datetime

# These are the five functions that you can use:
from show_forecasts.show_IFS_open_data import (
    load_forecast,
    plot_forecast,
    plot_forecast_ensemble,
)
from show_forecasts.show_IFS_open_data import (
    print_forecast_info,
    get_possible_variables,
)
from show_forecasts.data_utils import load_env_file

load_env_file()

mask_region = os.getenv("MASK_REGION", None)
use_ui_fs = os.getenv("USE_UI_FS", "")
cgan_ui_fs = True if use_ui_fs.lower() in ["t", "true", "y", "yes", "1"] else False
data_dir = os.environ["GAN_DATA_DIR"]

print("Mask Region: ", mask_region)
print("Data Dir: ", data_dir)
# Out:
# WARNING: .env file does not exist. Skipping loading of environment variables.
# Mask Region:  East Africa
# Data Dir:  /home/jason/.docker-data/cgan-data/ftp

# %%
# The date that the forecast was initialised
forecast_init_date = datetime(year=2025, month=2, day=17)
# Pick today instead:
# forecast_init_date = datetime.now()

# See what variables are available
get_possible_variables()
# Out:
# Available variables to plot are the following:
# tp    - Total precipitation (mm/day)
# sp    - Surface pressure (hPa)
# msl   - Pressure at mean sea level (hPa)
# t2m   - Two metre temperature (deg. C)
# wind  - Wind speed (m/s)
# ro    - Surface runoff water (m)
# ['tp', 'sp', 'msl', 't2m', 'wind', 'ro']

# %%
# Load some forecast data
# Options given by possible_variables() are
#    'sp'   - Surface pressure (hPa)
#    'msl'  - Pressure at mean sea level (hPa)
#    't2m'  - Two metre temperature (deg. C)
#    'wind' - Wind speed (m/s)
#    'tp'   - Total precipitation (mm/h)
#    'ro'   - Surface runoff water (m)
loader_args = {
    "key": "tp",
    "forecast_init_date": forecast_init_date,
    "data_dir": f"{data_dir}/open-ifs",
    "cgan_ui_fs": cgan_ui_fs,
}

if mask_region is not None:
    loader_args.update({"mask_region": mask_region.title()})

data = load_forecast(**loader_args)
# Out:
# Loading tp with lead time 30h from east_africa-open_ifs-20250217000000-30h-enfo-ef.nc
# Loading tp with lead time 54h from east_africa-open_ifs-20250217000000-54h-enfo-ef.nc

# %%
# Print some information about the forecast
print_forecast_info(forecast_init_date)
# Out:
# Forecast average: 2025-02-18 06:00:00 - 2025-02-19 06:00:00
# Forecast initialisation: 2025-02-17 00:00:00

# %%
# Plot the current data
plot_forecast(data, plot_units="mm/day", region=mask_region)

# %%
# style options: None (default), 'ICPAC', 'ICPAC_heavy', 'KMD', 'EMI', 'EMI_heavy'
# plot_units are only meaningfull for precipitation and can be 'mm/h' (default),
#               'mm/6h', 'mm/day' or 'mm/week'
# region can be 'ICPAC', 'Kenya', 'South Sudan', 'Rwanda', 'Burundi', 'Djibouti',
#               'Eritrea', 'Ethiopia', 'Sudan', 'Somalia', 'Tanzania', 'Uganda'
plot_forecast(data, style="EMI_heavy", plot_units="mm/h", region=mask_region)

# %%
# Plot the ensemble
plot_forecast_ensemble(data, style="KMD", plot_units="mm/6h", region=mask_region)

# %%
# Show the other variables
loader_args["key"] = "msl"
data = load_forecast(**loader_args)
plot_forecast(data, region=mask_region)

loader_args["key"] = "t2m"
data = load_forecast(**loader_args)
plot_forecast(data, region=mask_region)

loader_args["key"] = "wind"
data = load_forecast(**loader_args)
plot_forecast(data, region=mask_region)

loader_args["key"] = "tp"
data = load_forecast(**loader_args)
plot_forecast(data, region=mask_region)

loader_args["key"] = "ro"
data = load_forecast(**loader_args)
plot_forecast(data, region=mask_region)
# Out:
# Loading msl with lead time 30h from east_africa-open_ifs-20250217000000-30h-enfo-ef.nc
# Loading msl with lead time 33h from east_africa-open_ifs-20250217000000-33h-enfo-ef.nc
# Loading msl with lead time 36h from east_africa-open_ifs-20250217000000-36h-enfo-ef.nc
# Loading msl with lead time 39h from east_africa-open_ifs-20250217000000-39h-enfo-ef.nc
# Loading msl with lead time 42h from east_africa-open_ifs-20250217000000-42h-enfo-ef.nc
# Loading msl with lead time 45h from east_africa-open_ifs-20250217000000-45h-enfo-ef.nc
# Loading msl with lead time 48h from east_africa-open_ifs-20250217000000-48h-enfo-ef.nc
# Loading msl with lead time 51h from east_africa-open_ifs-20250217000000-51h-enfo-ef.nc
# Loading msl with lead time 54h from east_africa-open_ifs-20250217000000-54h-enfo-ef.nc
# Warning: Styles are only available for total precipitation
# Loading t2m with lead time 30h from east_africa-open_ifs-20250217000000-30h-enfo-ef.nc
# Loading t2m with lead time 33h from east_africa-open_ifs-20250217000000-33h-enfo-ef.nc
# Loading t2m with lead time 36h from east_africa-open_ifs-20250217000000-36h-enfo-ef.nc
# Loading t2m with lead time 39h from east_africa-open_ifs-20250217000000-39h-enfo-ef.nc
# Loading t2m with lead time 42h from east_africa-open_ifs-20250217000000-42h-enfo-ef.nc
# Loading t2m with lead time 45h from east_africa-open_ifs-20250217000000-45h-enfo-ef.nc
# Loading t2m with lead time 48h from east_africa-open_ifs-20250217000000-48h-enfo-ef.nc
# Loading t2m with lead time 51h from east_africa-open_ifs-20250217000000-51h-enfo-ef.nc
# Loading t2m with lead time 54h from east_africa-open_ifs-20250217000000-54h-enfo-ef.nc
# Warning: Styles are only available for total precipitation
# Loading wind with lead time 30h from east_africa-open_ifs-20250217000000-30h-enfo-ef.nc
# Loading wind with lead time 33h from east_africa-open_ifs-20250217000000-33h-enfo-ef.nc
# Loading wind with lead time 36h from east_africa-open_ifs-20250217000000-36h-enfo-ef.nc
# Loading wind with lead time 39h from east_africa-open_ifs-20250217000000-39h-enfo-ef.nc
# Loading wind with lead time 42h from east_africa-open_ifs-20250217000000-42h-enfo-ef.nc
# Loading wind with lead time 45h from east_africa-open_ifs-20250217000000-45h-enfo-ef.nc
# Loading wind with lead time 48h from east_africa-open_ifs-20250217000000-48h-enfo-ef.nc
# Loading wind with lead time 51h from east_africa-open_ifs-20250217000000-51h-enfo-ef.nc
# Loading wind with lead time 54h from east_africa-open_ifs-20250217000000-54h-enfo-ef.nc
# Warning: Styles are only available for total precipitation
# Loading tp with lead time 30h from east_africa-open_ifs-20250217000000-30h-enfo-ef.nc
# Loading tp with lead time 54h from east_africa-open_ifs-20250217000000-54h-enfo-ef.nc
# Loading ro with lead time 30h from east_africa-open_ifs-20250217000000-30h-enfo-ef.nc
# Loading ro with lead time 33h from east_africa-open_ifs-20250217000000-33h-enfo-ef.nc
# Loading ro with lead time 36h from east_africa-open_ifs-20250217000000-36h-enfo-ef.nc
# Loading ro with lead time 39h from east_africa-open_ifs-20250217000000-39h-enfo-ef.nc
# Loading ro with lead time 42h from east_africa-open_ifs-20250217000000-42h-enfo-ef.nc
# Loading ro with lead time 45h from east_africa-open_ifs-20250217000000-45h-enfo-ef.nc
# Loading ro with lead time 48h from east_africa-open_ifs-20250217000000-48h-enfo-ef.nc
# Loading ro with lead time 51h from east_africa-open_ifs-20250217000000-51h-enfo-ef.nc
# Loading ro with lead time 54h from east_africa-open_ifs-20250217000000-54h-enfo-ef.nc
# Warning: Styles are only available for total precipitation
